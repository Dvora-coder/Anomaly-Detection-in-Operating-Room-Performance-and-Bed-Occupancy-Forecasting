# %% [markdown]
# # Exploratory Data Analysis of Assuta Ramat HaHayal 2017
# In this notebook, we perform a comprehensive Exploratory Data Analysis (EDA) on the 2017 operating room and bed-occupancy records provided by Assuta Ramat HaHayal. Our goal is to understand the structure, quality, and key characteristics of the data before moving on to predictive modeling and anomaly detection.
#
# **Data Sources and Loading**
# - Loaded multiple Excel files, including "Assuta Translated 2017.xlsx" and "patients_one_row_per_id_correct_types_END2017.xlsx," into pandas DataFrames.
# - Inspected the first rows, column names, and data types to verify that dates, times, and categorical fields were parsed correctly.
#
# **Initial Data Cleaning and Preparation**
# - Created a working copy of the DataFrame and handled missing values by dropping or imputing where appropriate.
# - Converted time columns (e.g., "Closure Time" and "End of Surgery Time") to proper datetime objects and extracted only the relevant time component.
#
# **Exploratory Analysis**
# - Computed basic summary statistics (mean, median, standard deviation) for numeric variables.
# - Visualized distributions with histograms and boxplots to detect outliers and skewness.
# - Computed correlation matrices and pair plots for key numeric features to identify potential multicollinearity or interesting relationships.
# - Applied Shapiro- Wilk tests for normality and t-tests to compare surgical durations and turnover times across groups.
#
# **Time-Based Feature Engineering**
# - Defined a custom function to calculate time differences (in minutes) between surgery exit and room closure times.
# - Flagged and exported any records where the exit time preceded the closure time to a separate Excel file ("surgery_time_conflicts2017.xlsx") for further investigation.
#
# **Automated Profiling**
# - Installed and ran the ydata-profiling toolkit to generate an interactive HTML report summarizing data completeness, value distributions, and high-level correlations.
# - Saved the cleaned and profiled dataset to "2017_data_Assuta_nomissings_for_stat_final_1105.xlsx" for downstream statistical analysis.
#
# By the end of this EDA, we have:
# 1. Cleaned and validated the core dataset.
# 2. Identified and saved time-sequence conflicts for manual review.
# 3. Generated both programmatic and interactive summaries of data quality and distributions.
#
# These steps lay the groundwork for developing robust predictive models for bed occupancy forecasting and anomaly detection in operating room performance.

# %%
#Importing the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import warnings
import itertools
from pandas.api.types import is_numeric_dtype
from scipy.stats import shapiro
from tqdm import tqdm

# %%
file_path = r"/content/Assuta Translated 2017.xlsx"
df = pd.read_excel(file_path)
print(df.head())
# Out:
#    Site Code  Main Surgeon Code Activity Code  Activity Type Code  \
# 0         20               -999         81.51                  15
# 1         20               -999         81.51                  15
# 2         20               -999         65.21                  22
# 3         20                  0          86.4                   8
# 4         20                  0          86.4                   8
#
#    Planned SU Time (Large/Medium/Small)  Pre-Surgery Patient File (External)  \
# 0                                  20.0                           23457403.0
# 1                                  20.0                           23457403.0
# 2                                  20.0                           23457802.0
# 3                                  19.0                           23453184.0
# 4                                  19.0                           23453184.0
#
#   Pre-Surgery Admission Date  Height  Weight  Patient Age (on Surgery Day)  \
# 0                 2017-06-08    1.57    63.0                          60.0
# 1                 2017-06-08    1.57    63.0                          60.0
# 2                 2017-06-15    1.70    79.0                          64.0
# 3                 2017-03-15    1.68    60.0                          53.0
# 4                 2017-03-15    1.68    60.0                          53.0
#
#    ... Recovery Room Entry Time Recovery Room Exit Date  \
# 0  ...                 13:14:00              2017-06-18
# 1  ...                 13:14:00              2017-06-18
# 2  ...                 22:32:00              2017-06-28
# 3  ...                 13:44:00              2017-03-17
# 4  ...                 13:44:00              2017-03-17
#
#   Recovery Room Exit Time Post-Surgery Discharge Date  \
# 0                14:21:00                  2017-06-21
# 1                14:21:00                  2017-06-21
# 2                23:58:00                  2017-06-29
# 3                14:59:00                  2017-03-19
# 4                14:59:00                  2017-03-19
#
#   Post-Surgery Discharge Time  Planned Start Date for Doctor Block  \
# 0                    12:49:00                                  NaT
# 1                    12:49:00                                  NaT
# 2                    18:09:00                                  NaT
# 3                    11:16:00                                  NaT
# 4                    11:16:00                                  NaT
#
#   Planned Start Time for Doctor Block Planned End Date for Doctor Block  \
# 0                                 NaN                               NaT
# 1                                 NaN                               NaT
# 2                                 NaN                               NaT
# 3                                 NaN                               NaT
# 4                                 NaN                               NaT
#
#   Planned End Time for Doctor Block  Readmission
# 0                               NaN            0
# 1                               NaN            0
# 2                               NaN            0
# 3                               NaN            0
# 4                               NaN            0
#
# [5 rows x 43 columns]

# %%
print(df.columns)
# Out:
# Index(['Site Code', 'Main Surgeon Code', 'Activity Code', 'Activity Type Code',
#        'Planned SU Time (Large/Medium/Small)',
#        'Pre-Surgery Patient File (External)', 'Pre-Surgery Admission Date',
#        'Height', 'Weight', 'Patient Age (on Surgery Day)',
#        'Background Diseases/Diagnoses', 'Planned Surgery Date',
#        'Planned Surgery Time', 'Surgery Admission Date',
#        'Administrative Admission Time', 'Planned Operating Room Number',
#        'Pre-Surgery Hospitalization Admission Date',
#        'Pre-Surgery Hospitalization Admission Time',
#        'Pre-Surgical Admission Time Before Surgery', 'Surgical Team Codes',
#        'Anesthesiologist Code', 'Anesthesia Code', 'Type of Anesthesia',
#        'Cancellation Reason on Surgery Day', 'Actual Operating Room Number',
#        'Actual Surgery Room Entry Date', 'Actual Surgery Room Entry Time',
#        'Incision Time', 'Closure Time', 'End of Surgery Date (Exit from OR)',
#        'End of Surgery Time (Exit from OR)', 'Planned Surgery Duration',
#        'Recovery Room Entry Date', 'Recovery Room Entry Time',
#        'Recovery Room Exit Date', 'Recovery Room Exit Time',
#        'Post-Surgery Discharge Date', 'Post-Surgery Discharge Time',
#        'Planned Start Date for Doctor Block',
#        'Planned Start Time for Doctor Block',
#        'Planned End Date for Doctor Block',
#        'Planned End Time for Doctor Block', 'Readmission'],
#       dtype='object')

# %%
print(df.dtypes)
# Out:
# Site Code                                              int64
# Main Surgeon Code                                      int64
# Activity Code                                         object
# Activity Type Code                                     int64
# Planned SU Time (Large/Medium/Small)                 float64
# Pre-Surgery Patient File (External)                  float64
# Pre-Surgery Admission Date                    datetime64[ns]
# Height                                               float64
# Weight                                               float64
# Patient Age (on Surgery Day)                         float64
# Background Diseases/Diagnoses                         object
# Planned Surgery Date                          datetime64[ns]
# Planned Surgery Time                                  object
# Surgery Admission Date                        datetime64[ns]
# Administrative Admission Time                         object
# Planned Operating Room Number                        float64
# Pre-Surgery Hospitalization Admission Date    datetime64[ns]
# Pre-Surgery Hospitalization Admission Time            object
# Pre-Surgical Admission Time Before Surgery            object
# Surgical Team Codes                                  float64
# Anesthesiologist Code                                float64
# Anesthesia Code                                      float64
# Type of Anesthesia                                    object
# Cancellation Reason on Surgery Day                   float64
# Actual Operating Room Number                           int64
# Actual Surgery Room Entry Date                datetime64[ns]
# Actual Surgery Room Entry Time                        object
# Incision Time                                         object
# Closure Time                                          object
# End of Surgery Date (Exit from OR)            datetime64[ns]
# End of Surgery Time (Exit from OR)                    object
# Planned Surgery Duration                             float64
# Recovery Room Entry Date                      datetime64[ns]
# Recovery Room Entry Time                              object
# Recovery Room Exit Date                       datetime64[ns]
# Recovery Room Exit Time                               object
# Post-Surgery Discharge Date                   datetime64[ns]
# Post-Surgery Discharge Time                           object
# Planned Start Date for Doctor Block           datetime64[ns]
# Planned Start Time for Doctor Block                   object
# Planned End Date for Doctor Block             datetime64[ns]
# Planned End Time for Doctor Block                     object
# Readmission                                            int64
# dtype: object

# %%
df_copy=df.copy()

# %%
print(df_copy.head(10))
# Out:
#    Site Code  Main Surgeon Code Activity Code  Activity Type Code  \
# 0         20               -999         81.51                  15
# 1         20               -999         81.51                  15
# 2         20               -999         65.21                  22
# 3         20                  0          86.4                   8
# 4         20                  0          86.4                   8
# 5         20                184            35                  14
# 6         20                184            35                  14
# 7         20                184            35                  14
# 8         20                184            35                  14
# 9         20               -999         81.51                  15
#
#    Planned SU Time (Large/Medium/Small)  Pre-Surgery Patient File (External)  \
# 0                                  20.0                           23457403.0
# 1                                  20.0                           23457403.0
# 2                                  20.0                           23457802.0
# 3                                  19.0                           23453184.0
# 4                                  19.0                           23453184.0
# 5                                   NaN                                  NaN
# 6                                   NaN                                  NaN
# 7                                   NaN                                  NaN
# 8                                   0.0                           23457806.0
# 9                                  20.0                           23457403.0
#
#   Pre-Surgery Admission Date  Height  Weight  Patient Age (on Surgery Day)  \
# 0                 2017-06-08    1.57    63.0                          60.0
# 1                 2017-06-08    1.57    63.0                          60.0
# 2                 2017-06-15    1.70    79.0                          64.0
# 3                 2017-03-15    1.68    60.0                          53.0
# 4                 2017-03-15    1.68    60.0                          53.0
# 5                        NaT    1.55    73.3                          55.0
# 6                        NaT    1.55    73.3                          55.0
# 7                        NaT    1.75    84.0                          69.0
# 8                 2017-06-15    1.64    74.6                          60.0
# 9                 2017-06-08    1.57    63.0                          60.0
#
#    ... Recovery Room Entry Time Recovery Room Exit Date  \
# 0  ...                 13:14:00              2017-06-18
# 1  ...                 13:14:00              2017-06-18
# 2  ...                 22:32:00              2017-06-28
# 3  ...                 13:44:00              2017-03-17
# 4  ...                 13:44:00              2017-03-17
# 5  ...                      NaN                     NaT
# 6  ...                      NaN                     NaT
# 7  ...                      NaN                     NaT
# 8  ...                      NaN                     NaT
# 9  ...                 13:14:00              2017-06-18
#
#   Recovery Room Exit Time Post-Surgery Discharge Date  \
# 0                14:21:00                  2017-06-21
# 1                14:21:00                  2017-06-21
# 2                23:58:00                  2017-06-29
# 3                14:59:00                  2017-03-19
# 4                14:59:00                  2017-03-19
# 5                     NaN                  2017-12-18
# 6                     NaN                  2017-12-18
# 7                     NaN                  2017-09-18
# 8                     NaN                  2017-06-25
# 9                14:21:00                  2017-06-21
#
#   Post-Surgery Discharge Time  Planned Start Date for Doctor Block  \
# 0                    12:49:00                                  NaT
# 1                    12:49:00                                  NaT
# 2                    18:09:00                                  NaT
# 3                    11:16:00                                  NaT
# 4                    11:16:00                                  NaT
# 5                    14:47:00                           2017-12-11
# 6                    14:47:00                           2017-12-11
# 7                    14:57:00                           2017-09-13
# 8                    14:01:00                           2017-06-19
# 9                    12:49:00                                  NaT
#
#   Planned Start Time for Doctor Block Planned End Date for Doctor Block  \
# 0                                 NaN                               NaT
# 1                                 NaN                               NaT
# 2                                 NaN                               NaT
# 3                                 NaN                               NaT
# 4                                 NaN                               NaT
# 5                            19:00:00                        2017-12-11
# 6                            19:00:00                        2017-12-11
# 7                            15:00:00                        2017-09-13
# 8                            15:00:00                        2017-06-19
# 9                                 NaN                               NaT
#
#   Planned End Time for Doctor Block  Readmission
# 0                               NaN            0
# 1                               NaN            0
# 2                               NaN            0
# 3                               NaN            0
# 4                               NaN            0
# 5                          22:40:00            0
# 6                          22:40:00            0
# 7                          22:43:00            0
# 8                          22:55:00            0
# 9                               NaN            0
#
# [10 rows x 43 columns]

# %%
#Setting up date and time columns
date_cols = [
    'Planned Surgery Date',
    'Pre-Surgery Admission Date',
    'Pre-Surgery Hospitalization Admission Date',
    'Actual Surgery Room Entry Date',
    'End of Surgery Date (Exit from OR)',
    'Recovery Room Entry Date',
    'Recovery Room Exit Date',
    'Post-Surgery Discharge Date',
    'Surgery Admission Date',
    'Planned Start Date for Doctor Block',
    'Planned End Date for Doctor Block'
]

time_cols = [
    'Actual Surgery Room Entry Time',
    'End of Surgery Time (Exit from OR)',
    'Incision Time',
    'Closure Time',
    'Recovery Room Entry Time',
    'Recovery Room Exit Time',
    'Post-Surgery Discharge Time',
    'Administrative Admission Time'
]

#Convert to real dates (without converting to str)
for col in date_cols:
    if col in df_copy.columns:
        df_copy[col] = pd.to_datetime(df_copy[col], errors='coerce')

# Convert to time only (to save only time without date)
for col in time_cols:
    if col in df_copy.columns:
        df_copy[col] = pd.to_datetime(df_copy[col], format='%H:%M:%S', errors='coerce').dt.time


for col in time_cols:
    if col in df_copy.columns:
        df_copy[col] = pd.to_datetime(df_copy[col], format='%H:%M:%S', errors='coerce').dt.strftime('%H:%M:%S')

# Create a unique strong signature (each field is converted to pre-written text)
df_copy['strict_signature'] = (
    df_copy['Height'].astype(str) + "_" +
    df_copy['Weight'].astype(str) + "_" +
    df_copy['Patient Age (on Surgery Day)'].astype(str) + "_" +
    df_copy['Actual Operating Room Number'].astype(str) + "_" +
    df_copy['Actual Surgery Room Entry Date'].astype(str) + "_" +
    df_copy['Actual Surgery Room Entry Time'].astype(str) + "_" +
    df_copy['End of Surgery Time (Exit from OR)'].astype(str) + "_" +
    df_copy['Incision Time'].astype(str) + "_" +
    df_copy['Closure Time'].astype(str) + "_" +
    df_copy['Recovery Room Entry Time'].astype(str) + "_" +
    df_copy['Recovery Room Exit Time'].astype(str) + "_" +
    df_copy['Post-Surgery Discharge Date'].astype(str) + "_" +
    df_copy['Post-Surgery Discharge Time'].astype(str)
)

# Create a unique identifier for each signature (patient-operating room)
df_copy['patient_id'] = df_copy.groupby('strict_signature', sort=False).ngroup() + 1

# Sort by ID and percentage of deficiencies (so we can complete later by the complete row)
df_copy['null_count'] = df_copy.isnull().sum(axis=1)
df_copy = df_copy.sort_values(by=['patient_id', 'null_count'])
df_copy.drop(columns=['null_count'], inplace=True)

df_copy.to_excel("patients_with_ids_and_signatures2017.xlsx", index=False)

# %%
df_copy['Pre-Surgery Admission Date'].dt.year.value_counts()
# Out:
# Pre-Surgery Admission Date
# 2017.0    199525
# 2016.0      3029
# 2010.0        77
# 2012.0        12
# 2009.0        12
# 2011.0         3
# Name: count, dtype: int64

# %% [markdown]
# Creating a column for a no-Show:

# %%
file_path = r"/content/patients_with_ids_and_signatures2017.xlsx"
df_no_show = pd.read_excel(file_path)

# We will define the critical columns for carrying out the actual analysis
surgery_real_cols = [
    'Actual Surgery Room Entry Date',
    'Actual Surgery Room Entry Time',
    'Incision Time',
    'Closure Time',
    'End of Surgery Date (Exit from OR)',
    'End of Surgery Time (Exit from OR)'
]

# We will create a new column called 'No Show' – if all these fields are missing, we will mark True
df_no_show['No Show'] = df_no_show[surgery_real_cols].isnull().all(axis=1)

print(f"Number of patients marked as No Show: {df_no_show['No Show'].sum()} of {len(df_no_show)}")
df_no_show.to_excel("patients_with_id_NS2017.xlsx", index=False)
# Out:
# Number of patients marked as No Show: 211 of 394471

# %% [markdown]
# ###  **Chronological Conflict Cleaner for Surgery Timelines**
#
# This code performs automated cleaning of surgical scheduling data to ensure logical consistency between critical timestamps:
#
# 1. **Datetime Parsing**
#    Converts the columns `Entry DateTime`, `Incision DateTime`, `Closure DateTime`, and `Exit DateTime` to proper datetime format.
#
# 2. **Internal Conflict Detection (within the same row)**
#    Ensures that the sequence of timestamps within each surgery is chronologically correct:
#
#
#    Entry < Incision < Closure < Exit
#
#
#    If a conflict is found (e.g., Incision is earlier than Entry), the most suspicious timestamp is removed (`NaT`), based on its position and surrounding values.
#
# 3. **Forward Inter-row Conflict Detection (current Exit vs. next Entry)**
#    Ensures that one patient does not leave the OR after the next patient has already entered. If such an overlap is found, the `Exit DateTime` of the current row is removed.
#
# 4. **Backward Inter-row Conflict Detection (previous Exit vs. current Entry)**
#    Ensures that a patient does not enter the OR before the previous one has exited. If such an overlap is detected, the `Exit DateTime` of the **previous row** is removed.
#
# 5. **Logging and Reporting**
#    All removed values are stored in a list called `deleted_cells`, and a summary is printed showing how many issues were fixed, with a preview of up to 5 removed values.

# %%
import pandas as pd

file_path = r"/content/patients_with_id_NS2017.xlsx"
df_copy = pd.read_excel(file_path)

df_copy["Entry DateTime"] = df_copy["Actual Surgery Room Entry Date"] + pd.to_timedelta(df_copy["Actual Surgery Room Entry Time"].astype(str), errors='coerce')
df_copy["Incision DateTime"] = df_copy["Actual Surgery Room Entry Date"] + pd.to_timedelta(df_copy["Incision Time"].astype(str), errors='coerce')
df_copy["Closure DateTime"] = df_copy["End of Surgery Date (Exit from OR)"] + pd.to_timedelta(df_copy["Closure Time"].astype(str), errors='coerce')
df_copy["Exit DateTime"] = df_copy["End of Surgery Date (Exit from OR)"] + pd.to_timedelta(df_copy["End of Surgery Time (Exit from OR)"].astype(str), errors='coerce')

# List of datetime columns to be validated
time_cols = ["Entry DateTime", "Incision DateTime", "Closure DateTime", "Exit DateTime"]

# Ensure datetime columns are parsed correctly
for col in time_cols:
    df_copy[col] = pd.to_datetime(df_copy[col], errors='coerce')

# Counters and log of removed invalid cells
internal_corrections = 0
external_corrections = 0
deleted_cells = []

#Resolve internal chronological conflicts within a single row
def clean_internal_conflicts(row):
    global internal_corrections
    for i in range(len(time_cols) - 1):
        col1 = time_cols[i]
        col2 = time_cols[i + 1]
        t1 = row[col1]
        t2 = row[col2]

        if pd.notnull(t1) and pd.notnull(t2) and t1 > t2:
            prev_time = row[time_cols[i - 1]] if i > 0 else None
            next_time = row[time_cols[i + 2]] if i + 2 < len(time_cols) else None

            if prev_time is not None and pd.notnull(prev_time) and prev_time > t1:
                bad_col = col1
            elif next_time is not None and pd.notnull(next_time) and t2 > next_time:
                bad_col = col2
            else:
                bad_col = col1  # default choice if context is unclear

            deleted_cells.append((row.name, bad_col, row[bad_col]))
            row[bad_col] = pd.NaT
            internal_corrections += 1
    return row

df_copy = df_copy.apply(clean_internal_conflicts, axis=1)

#Resolve conflict where current row's Exit is after the next row's Entry
df_copy["next_Entry DateTime"] = df_copy["Entry DateTime"].shift(-1)

def fix_external_conflict(row):
    global external_corrections
    if pd.notnull(row["Exit DateTime"]) and pd.notnull(row["next_Entry DateTime"]):
        if row["Exit DateTime"] > row["next_Entry DateTime"]:
            deleted_cells.append((row.name, "Exit DateTime", row["Exit DateTime"]))
            row["Exit DateTime"] = pd.NaT
            external_corrections += 1
    return row

df_copy = df_copy.apply(fix_external_conflict, axis=1)
df_copy.drop(columns=["next_Entry DateTime"], inplace=True)

# Resolve conflict where Entry of current row is before Exit of previous row → always delete Exit of previous row
df_copy["prev_Exit DateTime"] = df_copy["Exit DateTime"].shift(1)

def fix_inter_row_conflict_strict(row):
    global external_corrections
    entry = row["Entry DateTime"]
    prev_exit = row["prev_Exit DateTime"]

    if pd.notnull(entry) and pd.notnull(prev_exit) and entry < prev_exit:
        idx_prev = row.name - 1
        deleted_cells.append((idx_prev, "Exit DateTime", df_copy.at[idx_prev, "Exit DateTime"]))
        df_copy.at[idx_prev, "Exit DateTime"] = pd.NaT
        external_corrections += 1

    return row

df_copy = df_copy.apply(fix_inter_row_conflict_strict, axis=1)
df_copy.drop(columns=["prev_Exit DateTime"], inplace=True)

# Summary
print(f" Cleaning completed:")
print(f" {internal_corrections} internal conflicts resolved within rows.")
print(f" {external_corrections} inter-row conflicts resolved.")

# Display sample of removed values
if deleted_cells:
    print("\n Sample of removed values (up to 5 shown):")
    for row_idx, col, val in deleted_cells[:5]:
        print(f" Row {row_idx}, Column '{col}', Removed Value: {val}")
else:
    print("No values were removed.")

df_copy.to_excel("Chronological_Conflict_Cleaner2017.xlsx", index=False)
# Out:
#  Cleaning completed:
#  19420 internal conflicts resolved within rows.
#  346198 inter-row conflicts resolved.
#
#  Sample of removed values (up to 5 shown):
#  Row 76, Column 'Closure DateTime', Removed Value: 2017-06-19 23:26:00
#  Row 77, Column 'Closure DateTime', Removed Value: 2017-06-19 23:26:00
#  Row 78, Column 'Closure DateTime', Removed Value: 2017-06-19 23:26:00
#  Row 79, Column 'Closure DateTime', Removed Value: 2017-06-19 23:26:00
#  Row 80, Column 'Closure DateTime', Removed Value: 2017-06-19 23:26:00

# %% [markdown]
# Step 1: Completing missing values ​​from other rows of the same patient
# How to do it:
# Group by patient_id.
#
# For each column with missing values ​​(NaN):
#
# Check if other rows of the same patient in the same column have a valid value.
#
# If so → fill the missing row with that value.
#
# If there is more than one different value → select the most common value (or identify an exception if necessary).
#
# Texts (such as Background Diseases/Diagnoses):
# Find the longest version (with the most words or characters).
#
# If there are multiple different versions → combine them into a long sentence with a separator (e.g. ; or |).
#
# A new colum of possible imputation was made for clarity.

# %% [markdown]
# If there are missing values ​​in the columns, and an identical value is found for the same patient and the same surgeon, we will use it to complete the missing values.

# %% [markdown]
# Look at neighbors (different ID) on the same day in the operating room - if it is possible to complete neighbors, for example completing a closing time when it is known that the next ID in line started surgery at a certain time. This also applies to the start time of surgery, etc.

# %% [markdown]
# In addition, if there is a date scheduled for surgery, I want to check what % of the times there were no emergency rooms and the surgery was actually performed. At most, it can be completed from there if it is a case where there is really no one to complete from the neighbors, let's say only 1 patient was in surgery that day in the same room...

# %%
# Calculating success rates – analysis of what actually took place from what was planned
def calculate_surgery_plan_success_rate(df_copy,
                                        planned_date_col='Planned Surgery Date',
                                        actual_date_col='Actual Surgery Room Entry Date'):

    df_check = df_copy[[planned_date_col, actual_date_col]].dropna(subset=[planned_date_col])
    df_check['same_day'] = df_check[planned_date_col] == df_check[actual_date_col]

    total_with_planned = len(df_check)
    actually_done_same_day = df_check['same_day'].sum()

    success_rate = (actually_done_same_day / total_with_planned) * 100 if total_with_planned > 0 else 0

    print(f"Percentage of actual planned surgery date realization: {success_rate:.1f}% ({actually_done_same_day}/{total_with_planned})")

    return success_rate

# %%
calculate_surgery_plan_success_rate(df_copy)
# Out:
# Percentage of actual planned surgery date realization: 95.2% (348908/366631)
# np.float64(95.1659843275664)

# %%
#To the end of a date! Calculating success rates – an analysis of what actually took place from what was planned
def calculate_surgery_plan_success_rate2(df_copy,
                                        planned_date_col='Planned End Date for Doctor Block',
                                        actual_date_col='End of Surgery Date (Exit from OR)'):

    df_check = df_copy[[planned_date_col, actual_date_col]].dropna(subset=[planned_date_col])
    df_check['same_day'] = df_check[planned_date_col] == df_check[actual_date_col]

    total_with_planned = len(df_check)
    actually_done_same_day = df_check['same_day'].sum()

    success_rate = (actually_done_same_day / total_with_planned) * 100 if total_with_planned > 0 else 0

    print(f"Percentage of actual planned surgery date realization: {success_rate:.1f}% ({actually_done_same_day}/{total_with_planned})")

    return success_rate

# %%
calculate_surgery_plan_success_rate2(df_copy)
# Out:
# Percentage of actual planned surgery date realization: 94.5% (346406/366530)
# np.float64(94.50958993806783)

# %%
file_path = r"/content/Chronological_Conflict_Cleaner2017.xlsx"
df_input = pd.read_excel(file_path)

def fill_actual_dates_from_block(df,
                                 start_actual_col='Actual Surgery Room Entry Date',
                                 start_planned_col='Planned Start Date for Doctor Block',
                                 end_actual_col='End of Surgery Date (Exit from OR)',
                                 end_planned_col='Planned End Date for Doctor Block',
                                 no_show_col='No Show'):
    df_filled = df.copy()

# Completion of start date – only for those who are No Show
    start_mask = (
        df_filled[start_actual_col].isnull() &
        df_filled[start_planned_col].notnull() &
        (~df_filled[no_show_col])  # Only if it's not a No Show
    )
    df_filled.loc[start_mask, start_actual_col] = df_filled.loc[start_mask, start_planned_col]
    print(f"Completed {start_mask.sum()} Start dates from Planned Start Date for Doctor Block.")

    # Completion of end date – only for those who are not No Show
    end_mask = (
        df_filled[end_actual_col].isnull() &
        df_filled[end_planned_col].notnull() &
        (~df_filled[no_show_col])
    )
    df_filled.loc[end_mask, end_actual_col] = df_filled.loc[end_mask, end_planned_col]
    print(f"Completed {end_mask.sum()} End dates from Planned End Date for Doctor Block.")

    return df_filled

df_planned_filled = fill_actual_dates_from_block(
    df_input,
    start_actual_col='Actual Surgery Room Entry Date',
    start_planned_col='Planned Start Date for Doctor Block',
    end_actual_col='End of Surgery Date (Exit from OR)',
    end_planned_col='Planned End Date for Doctor Block',
    no_show_col='No Show'
)

df_planned_filled.to_excel("patients_with_planned_fallback2017.xlsx", index=False)
# Out:
# Completed 17579 Start dates from Planned Start Date for Doctor Block.
# Completed 17579 End dates from Planned End Date for Doctor Block.

# %% [markdown]
# Look at neighbors (different ID) in the operating room on the same day - if it is possible to complete neighbors, for example completing a closing time when it is known that the next ID in line started surgery at a certain time.

# %%
file_path_n = r"/content/patients_with_planned_fallback2017.xlsx"
df_neighbor_filled = pd.read_excel(file_path_n)

def fill_exit_time_from_next_patient(df,
                                     id_col='patient_id',
                                     room_col='Planned Operating Room Number',
                                     date_col='Planned Surgery Date',
                                     start_time_col='Actual Surgery Room Entry Time',
                                     start_date_col='Actual Surgery Room Entry Date',
                                     exit_time_col='End of Surgery Time (Exit from OR)',
                                     exit_date_col='End of Surgery Date (Exit from OR)'):

    df_sorted = df.copy().sort_values(by=[room_col, start_date_col, start_time_col])
    df_sorted.reset_index(drop=True, inplace=True)

    filled_counter = 0

    for i in range(len(df_sorted) - 1):
        current = df_sorted.loc[i]
        next_row = df_sorted.loc[i + 1]

        same_room = current[room_col] == next_row[room_col]
        same_day = current[date_col] == next_row[date_col]
        different_patient = current[id_col] != next_row[id_col]

        if same_room and same_day and different_patient:
            if pd.isnull(current[exit_time_col]) and pd.notnull(next_row[start_time_col]):
                next_start_time = next_row[start_time_col]
                if isinstance(next_start_time, pd.Timestamp):
                    next_start_time = next_start_time.time()
                df_sorted.at[i, exit_time_col] = next_start_time
                filled_counter += 1

            if pd.isnull(current[exit_date_col]) and pd.notnull(next_row[start_date_col]):
                df_sorted.at[i, exit_date_col] = next_row[start_date_col]

    print(f"Completed {filled_counter} End of Surgery Time values ​​from roommates and on the same day.")
    return df_sorted

df_exit_filled = fill_exit_time_from_next_patient(
    df_planned_filled,
    id_col='patient_id',
    room_col='Planned Operating Room Number',
    date_col='Planned Surgery Date',
    start_time_col='Actual Surgery Room Entry Time',
    start_date_col='Actual Surgery Room Entry Date',
    exit_time_col='End of Surgery Time (Exit from OR)',
    exit_date_col='End of Surgery Date (Exit from OR)'
)

df_exit_filled.to_excel("patients_with_exit_time_from_neighbors2017.xlsx", index=False)
# Out:
# Completed 0 End of Surgery Time values ​​from roommates and on the same day.

# %%
# Displays the number of unique IDs
unique_ids = df_exit_filled['patient_id'].unique()
print(f"Number of unique patient_ids: {len(unique_ids)}")

# Prints all the IDs themselves
print(sorted(unique_ids))
# Out:
# Number of unique patient_ids: 44047
# [np.int64(1), np.int64(2), np.int64(3), np.int64(4), np.int64(5), np.int64(6), np.int64(7), np.int64(8), np.int64(9), np.int64(10), np.int64(11), np.int64(12), np.int64(13), np.int64(14), np.int64(15), np.int64(16), np.int64(17), np.int64(18), np.int64(19), np.int64(20), np.int64(21), np.int64(22), np.int64(23), np.int64(24), np.int64(25), np.int64(26), np.int64(27), np.int64(28), np.int64(29), np.int64(30), np.int64(31), np.int64(32), np.int64(33), np.int64(34), np.int64(35), np.int64(36), np.int64(37), np.int64(38), np.int64(39), np.int64(40), np.int64(41), np.int64(42), np.int64(43), np.int64(44), np.int64(45), np.int64(46), np.int64(47), np.int64(48), np.int64(49), np.int64(50), np.int64(51), np.int64(52), np.int64(53), np.int64(54), np.int64(55), np.int64(56), np.int64(57), np.int64(58), np.int64(59), np.int64(60), np.int64(61), np.int64(62), np.int64(63), np.int64(64), np.int64(65), np.int64(66), np.int64(67), np.int64(68), np.int64(69), np.int64(70), np.int64(71), np.int64(72), np.int64(73), np.int64(74), np.int64(75), np.int64(76), np.int64(77), np.int64(78), np.int64(79), np.int64(80), np.int64(81), np.int64(82), np.int64(83), np.int64(84), np.int64(85), np.int64(86), np.int64(87), np.int64(88), np.int64(89), np.int64(90), np.int64(91), np.int64(92), np.int64(93), np.int64(94), np.int64(95), np.int64(96), np.int64(97), np.int64(98), np.int64(99), np.int64(100), np.int64(101), np.int64(102), np.int64(103), np.int64(104), np.int64(105), np.int64(106), np.int64(107), np.int64(108), np.int64(109), np.int64(110), np.int64(111), np.int64(112), np.int64(113), np.int64(114), np.int64(115), np.int64(116), np.int64(117), np.int64(118), np.int64(119), np.int64(120), np.int64(121), np.int64(122), np.int64(123), np.int64(124), np.int64(125), np.int64(126), np.int64(127), np.int64(128), np.int64(129), np.int64(130), np.int64(131), np.int64(132), np.int64(133), np.int64(134), np.int64(135), np.int64(136), np.int64(137), np.int64(138), np.int64(139), np.int64(140), np.int64(141), np.int64(142), np.int64(143), np.int64(144), np.int64(145), np.int64(146), np.int64(147), np.int64(148), np.int64(149), np.int64(150), np.int64(151), np.int64(152), np.int64(153), np.int64(154), np.int64(155), np.int64(156), np.int64(157), np.int64(158), np.int64(159), np.int64(160), np.int64(161), np.int64(162), np.int64(163), np.int64(164), np.int64(165), np.int64(166), np.int64(167), np.int64(168), np.int64(169), np.int64(170), np.int64(171), np.int64(172), np.int64(173), np.int64(174), np.int64(175), np.int64(176), np.int64(177), np.int64(178), np.int64(179), np.int64(180), np.int64(181), np.int64(182), np.int64(183), np.int64(184), np.int64(185), np.int64(186), np.int64(187), np.int64(188), np.int64(189), np.int64(190), np.int64(191), np.int64(192), np.int64(193), np.int64(194), np.int64(195), np.int64(196), np.int64(197), np.int64(198), np.int64(199), np.int64(200), np.int64(201), np.int64(202), np.int64(203), np.int64(204), np.int64(205), np.int64(206), np.int64(207), np.int64(208), np.int64(209), np.int64(210), np.int64(211), np.int64(212), np.int64(213), np.int64(214), np.int64(215), np.int64(216), np.int64(217), np.int64(218), np.int64(219), np.int64(220), np.int64(221), np.int64(222), np.int64(223), np.int64(224), np.int64(225), np.int64(226), np.int64(227), np.int64(228), np.int64(229), np.int64(230), np.int64(231), np.int64(232), np.int64(233), np.int64(234), np.int64(235), np.int64(236), np.int64(237), np.int64(238), np.int64(239), np.int64(240), np.int64(241), np.int64(242), np.int64(243), np.int64(244), np.int64(245), np.int64(246), np.int64(247), np.int64(248), np.int64(249), np.int64(250), np.int64(251), np.int64(252), np.int64(253), np.int64(254), np.int64(255), np.int64(256), np.int64(257), np.int64(258), np.int64(259), np.int64(260), np.int64(261), np.int64(262), np.int64(263), np.int64(264), np.int64(265), np.int64(266), np.int64(267), np.int64(268), np.int64(269), np.int64(270), np.int64(271), np.int64(272), np.int64(273), np.int64(274 ...

# %%
existing_ids = set(df_exit_filled['patient_id'].unique())
expected_ids = set(range(1, df_exit_filled['patient_id'].max() + 1))

missing_ids = sorted(expected_ids - existing_ids)

print(f"Total missing IDs in sequence:{len(missing_ids)}")
print("Example of the first 10 missing identifiers:", missing_ids[:10])
# Out:
# Total missing IDs in sequence:0
# Example of the first 10 missing identifiers: []

# %% [markdown]
# Filling times from neighbors:

# %%
from datetime import timedelta

file_path_fill = r"/content/patients_with_exit_time_from_neighbors2017.xlsx"
df_neighbor_filled = pd.read_excel(file_path_fill)

def fill_actual_start_time_logic(df,
                                 id_col='patient_id',
                                 room_col='Planned Operating Room Number',
                                 date_col='Planned Surgery Date',
                                 start_time_col='Actual Surgery Room Entry Time',
                                 start_date_col='Actual Surgery Room Entry Date',
                                 exit_time_col='End of Surgery Time (Exit from OR)',
                                 planned_start_time_col='Planned Start Time for Doctor Block',
                                 surgery_duration_col='Planned Surgery Duration',
                                 no_show_col='No Show'):

    df_filled = df.copy()
    df_filled.sort_values(by=[room_col, date_col, start_time_col], inplace=True)
    df_filled.reset_index(drop=True, inplace=True)

    sources = []  # Follow where the completion came from

    for i in range(len(df_filled)):
        row = df_filled.loc[i]

        # Only if there is no entry time
        if pd.notnull(row[start_time_col]):
            sources.append("Already Present")
            continue

        # Skipping No Show
        if row.get(no_show_col, False):
            sources.append("No Show")
            continue

        filled = False

        # Complete from the previous neighbor in the same room and date
        if i > 0:
            prev_row = df_filled.loc[i - 1]
            same_room = row[room_col] == prev_row[room_col]
            same_date = row[date_col] == prev_row[date_col]

            if same_room and same_date and pd.notnull(prev_row[exit_time_col]):
                try:
                    new_time = pd.to_datetime(prev_row[exit_time_col]) + pd.Timedelta(minutes=1)
                    df_filled.at[i, start_time_col] = new_time.time()
                    sources.append("From Previous Patient in Room")
                    filled = True
                except:
                    pass

        # Try to complete the doctor's scheduled appointment
        if not filled and pd.notnull(row[planned_start_time_col]):
            try:
                df_filled.at[i, start_time_col] = pd.to_datetime(row[planned_start_time_col]).time()
                sources.append("From Planned Block Start")
                filled = True
            except:
                pass

        # Try calculating by exit time minus analysis duration
        if not filled and pd.notnull(row[exit_time_col]) and pd.notnull(row[surgery_duration_col]):
            try:
                duration = pd.to_timedelta(row[surgery_duration_col], errors='coerce')
                if pd.notnull(duration):
                    new_time = pd.to_datetime(row[exit_time_col]) - duration
                    df_filled.at[i, start_time_col] = new_time.time()
                    sources.append("From Exit Time minus Duration")
                    filled = True
            except Exception as e:
                pass

        if not filled:
            sources.append("Not Filled")

    df_filled["Start Time Completion Source"] = sources

    return df_filled

df_logic_filled = fill_actual_start_time_logic(
    df_planned_filled,
    id_col='patient_id',
    room_col='Planned Operating Room Number',
    date_col='Planned Surgery Date',
    start_time_col='Actual Surgery Room Entry Time',
    start_date_col='Actual Surgery Room Entry Date',
    exit_time_col='End of Surgery Time (Exit from OR)',
    planned_start_time_col='Planned Start Time for Doctor Block',
    surgery_duration_col='Planned Surgery Duration',
    no_show_col='No Show'
)

df_logic_filled.to_excel("/content/patients_start_time_filled_logically2017.xlsx", index=False)

# %% [markdown]
# Handling illogical values ​​with end times before closing time:

# %%
from datetime import datetime, timedelta

file_path = r"/content/patients_start_time_filled_logically2017.xlsx"
df_not_logic = pd.read_excel(file_path)

def fix_invalid_exit_times(df,
                           closure_time_col='Closure Time',
                           exit_time_col='End of Surgery Time (Exit from OR)',
                           completion_source_col='Exit Time Completion Source',
                           room_col='Planned Operating Room Number',
                           date_col='Planned Surgery Date'):
    df_fixed = df.copy()

    # Calculate average gap from valid rows
    valid_mask = df_fixed[closure_time_col].notnull() & df_fixed[exit_time_col].notnull()
    valid_diffs = []

    for idx, row in df_fixed[valid_mask].iterrows():
        try:
            c = datetime.combine(datetime.min, pd.to_datetime(row[closure_time_col]).time())
            e = datetime.combine(datetime.min, pd.to_datetime(row[exit_time_col]).time())
            if e > c:
                valid_diffs.append(e - c)
        except:
            continue

    avg_diff = pd.to_timedelta(valid_diffs).mean()
    print(f"Average gap between Closure and Exit: {avg_diff}")

    # Fix invalid rows
    sources = []
    fixed_counter = 0
    affected_rooms = []
    affected_dates = []

    for idx, row in df_fixed.iterrows():
        closure = row[closure_time_col]
        exit_time = row[exit_time_col]

        if pd.isnull(closure) or pd.isnull(exit_time):
            sources.append("Not Checked")
            continue

        try:
            c = datetime.combine(datetime.min, pd.to_datetime(closure).time())
            e = datetime.combine(datetime.min, pd.to_datetime(exit_time).time())

            if e < c:
                new_exit = max(c, e) + avg_diff
                df_fixed.at[idx, exit_time_col] = new_exit.time()
                sources.append("Fixed: Max(Closure, Exit) + Avg Gap")
                fixed_counter += 1
                affected_rooms.append(row.get(room_col, 'Unknown'))
                affected_dates.append(row.get(date_col, 'Unknown'))
            else:
                sources.append("OK")
        except:
            sources.append("Error in Conversion")

    df_fixed[completion_source_col] = sources
    print(f"Fixed {fixed_counter} rows where Exit Time was before Closure Time.")

    # Simple report on problematic rooms and dates
    if fixed_counter > 0:
        report_df = pd.DataFrame({'Room': affected_rooms, 'Date': affected_dates})
        print("\nTop 5 problematic operating rooms:")
        print(report_df['Room'].value_counts().head(5))
        print("\nTop 5 problematic dates:")
        print(report_df['Date'].value_counts().head(5))

    return df_fixed

df_fixed_exit = fix_invalid_exit_times(df_not_logic)
df_fixed_exit.to_excel("df_illogic_filled2017.xlsx", index=False)
# Out:
# Average gap between Closure and Exit: 0 days 00:13:22.831726169
# Fixed 16144 rows where Exit Time was before Closure Time.
#
# Top 5 problematic operating rooms:
# Room
# 20026.0    2382
# 20006.0    1039
# 20008.0     984
# 20013.0     889
# 20004.0     887
# Name: count, dtype: int64
#
# Top 5 problematic dates:
# Date
# 2017-03-30    195
# 2017-03-15    181
# 2017-04-27    163
# 2017-02-22    158
# 2017-01-18    144
# Name: count, dtype: int64

# %% [markdown]
# To find anomalities, we check where they were found (the illogical values):

# %%
file_path = r"/content/df_illogic_filled2017.xlsx"
df = pd.read_excel(file_path)

# Fixed row filtering (Exit Time was less than Closure Time and was fixed)
fixed_mask = df['Exit Time Completion Source'] == 'Fixed: Max(Closure, Exit) + Avg Gap'
df_fixed = df[fixed_mask]

# Calculating problem counts by operating room
room_counts = df_fixed['Planned Operating Room Number'].value_counts().head(10)

# Calculating problem counts by date
date_counts = df_fixed['Planned Surgery Date'].value_counts().head(10)

print("Top 10 operating rooms with the most non-standard exit time corrections:")
print(room_counts)

print("\n Top 10 problematic dates (when the most corrections occurred):")
print(date_counts)
# Out:
# Top 10 operating rooms with the most non-standard exit time corrections:
# Planned Operating Room Number
# 20026.0    2382
# 20006.0    1039
# 20008.0     984
# 20013.0     889
# 20004.0     887
# 20010.0     863
# 20012.0     798
# 20015.0     791
# 20009.0     775
# 20007.0     771
# Name: count, dtype: int64
#
#  Top 10 problematic dates (when the most corrections occurred):
# Planned Surgery Date
# 2017-03-30    195
# 2017-03-15    181
# 2017-04-27    163
# 2017-02-22    158
# 2017-01-18    144
# 2017-11-19    138
# 2017-03-31    137
# 2017-04-05    132
# 2017-02-09    129
# 2017-10-31    128
# Name: count, dtype: int64

# %% [markdown]
# We would like to convert the time columns to numeric, so that later they can be applied to various models:

# %%
from datetime import time

file_path = r"/content/df_illogic_filled2017.xlsx"
df = pd.read_excel(file_path)

# Time columns to convert
time_cols = [
    'Planned Surgery Time',
    'Administrative Admission Time',
    'Pre-Surgery Hospitalization Admission Time',
    'Pre-Surgical Admission Time Before Surgery',
    'Actual Surgery Room Entry Time',
    'Incision Time',
    'Closure Time',
    'End of Surgery Time (Exit from OR)',
    'Recovery Room Entry Time',
    'Recovery Room Exit Time',
    'Post-Surgery Discharge Time',
    'Planned Start Time for Doctor Block',
    'Planned End Time for Doctor Block'
]

def time_to_minutes(t):
    """Convert time to a continuous numeric indicator – minutes since midnight"""
    if pd.isnull(t):
        return None
    try:
        parsed = pd.to_datetime(t).time()
        return parsed.hour * 60 + parsed.minute + parsed.second / 60
    except:
        return None

# Convert all time columns to numeric (minutes since midnight)
for col in time_cols:
    new_col = col + "_Minutes"
    df[new_col] = df[col].apply(time_to_minutes)

num_vars_time = [col + "_Minutes" for col in time_cols]

df.to_excel("df_time_as_numeric_minutes2017.xlsx", index=False)

# %% [markdown]
# Now dealing with repetition (almost like duplication):

# %%
file_path = r"/content/df_illogic_filled2017.xlsx"
df = pd.read_excel(file_path)

def aggregate_patient_rows(df, id_col='patient_id'):
    agg_dict = {
        col: lambda x: ', '.join(sorted(set(map(str, x.dropna()))))
        for col in df.columns if col != id_col
    }
    df_grouped = df.groupby(id_col, as_index=False).agg(agg_dict)
    return df_grouped

df_aggregated = aggregate_patient_rows(df)

df_aggregated.to_excel("patients_one_row_per_id2017.xlsx", index=False)

# %% [markdown]
# Now treating deficiencies according to mechanism

# %%
df_copy=df_aggregated.copy()

# %%
print(f"Number of rows: {df_copy.shape[0]}")
print(f"Number of columns: {df_copy.shape[1]}")
# Out:
# Number of rows: 44047
# Number of columns: 52

# %%
print(df_copy.head(10))
# Out:
#    patient_id Site Code Main Surgeon Code Activity Code Activity Type Code  \
# 0           1        20       -999, 30817         81.51                 15
# 1           2        20       -999, 18731         65.21                 22
# 2           3        20                 0          86.4                  8
# 3           4        20               184            35                 14
# 4           5        20               184            35                 14
# 5           6        20               184            35                 14
# 6           7        20       -999, 18796         65.21                 22
# 7           8        20       -999, 31448         65.21                 22
# 8           9        20       -999, 31448         65.21                 22
# 9          10        20                 2          86.4                  8
#
#   Planned SU Time (Large/Medium/Small) Pre-Surgery Patient File (External)  \
# 0                                 20.0                          23457403.0
# 1                                 20.0                          23457802.0
# 2                                 19.0                          23453184.0
# 3
# 4
# 5                                  0.0                          23457806.0
# 6                                  0.0                          23457800.0
# 7                                  9.0                          23457628.0
# 8                                 20.0                          23457631.0
# 9
#
#   Pre-Surgery Admission Date Height Weight  ...  \
# 0        2017-06-08 00:00:00   1.57   63.0  ...
# 1        2017-06-15 00:00:00    1.7   79.0  ...
# 2        2017-03-15 00:00:00   1.68   60.0  ...
# 3                              1.55   73.3  ...
# 4                              1.75   84.0  ...
# 5        2017-06-15 00:00:00   1.64   74.6  ...
# 6        2017-06-15 00:00:00   1.65   76.0  ...
# 7        2017-06-13 00:00:00   1.65   71.0  ...
# 8        2017-06-13 00:00:00   1.65   80.0  ...
# 9                              1.75   90.0  ...
#
#   Planned End Time for Doctor Block Readmission  \
# 0                          12:44:00           0
# 1                          20:55:00           0
# 2                                             0
# 3                          22:40:00           0
# 4                          22:43:00           0
# 5                          22:55:00           0
# 6                          12:30:00           0
# 7                          15:21:00           0
# 8                          15:21:00           0
# 9                                             0
#
#                                     strict_signature No Show  \
# 0  1.57_63.0_60.0_20002_2017-06-18_11:00:46_13:14...   False
# 1  1.7_79.0_64.0_20009_2017-06-28_20:11:08_22:32:...   False
# 2  1.68_60.0_53.0_20004_2017-03-17_12:45:00_13:41...   False
# 3  1.55_73.3_55.0_20008_2017-12-11_20:30:00_23:42...   False
# 4  1.75_84.0_69.0_20008_2017-09-13_15:16:00_18:53...   False
# 5  1.64_74.6_60.0_20005_2017-06-19_19:55:11_21:31...   False
# 6  1.65_76.0_25.0_20014_2017-06-18_08:56:12_12:33...   False
# 7  1.65_71.0_39.0_20002_NaT_nan_nan_13:53:00_14:0...   False
# 8  1.65_80.0_39.0_20002_2017-06-18_14:38:54_15:35...   False
# 9  1.75_90.0_71.0_20014_2017-02-22_08:02:00_08:27...   False
#
#         Entry DateTime    Incision DateTime     Closure DateTime  \
# 0  2017-06-18 11:00:46  2017-06-18 11:18:00  2017-06-18 12:55:00
# 1  2017-06-28 20:11:08  2017-06-28 20:21:00  2017-06-28 22:11:00
# 2  2017-03-17 12:45:00  2017-03-17 13:04:00  2017-03-17 13:30:00
# 3  2017-12-11 20:30:00  2017-12-11 21:15:00  2017-12-11 23:38:00
# 4  2017-09-13 15:16:00  2017-09-13 16:04:00  2017-09-13 18:39:00
# 5  2017-06-19 19:55:11  2017-06-19 20:39:00
# 6  2017-06-18 08:56:12  2017-06-18 11:40:00  2017-06-18 12:24:00
# 7
# 8  2017-06-18 14:38:54  2017-06-18 14:51:00  2017-06-18 15:22:00
# 9  2017-02-22 08:02:00  2017-02-22 08:10:00  2017-02-22 08:27:00
#
#          Exit DateTime                       Start Time Completion Source  \
# 0  2017-06-18 13:14:00                                    Already Present
# 1                                                         Already Present
# 2  2017-03-17 13:41:00                                    Already Present
# 3                                                         Already Present
# 4                                                         Already Present
# 5                                                         Already Present
# 6  2017-06-18 12:33:00                                    Already Present
# 7                       From Planned Block Start, From Previous Patien...
# 8                                                         Already Present
# 9  2017-02-22 08:27:00                                    Already Present
#
#            Exit Time Completion Source
# 0                                   OK
# 1                                   OK
# 2                                   OK
# 3                                   OK
# 4                                   OK
# 5  Fixed: Max(Closure, Exit) + Avg Gap
# 6                                   OK
# 7                          Not Checked
# 8                                   OK
# 9                                   OK
#
# [10 rows x 52 columns]

# %%
print(df_copy.dtypes)
# Out:
# patient_id                                     int64
# Site Code                                     object
# Main Surgeon Code                             object
# Activity Code                                 object
# Activity Type Code                            object
# Planned SU Time (Large/Medium/Small)          object
# Pre-Surgery Patient File (External)           object
# Pre-Surgery Admission Date                    object
# Height                                        object
# Weight                                        object
# Patient Age (on Surgery Day)                  object
# Background Diseases/Diagnoses                 object
# Planned Surgery Date                          object
# Planned Surgery Time                          object
# Surgery Admission Date                        object
# Administrative Admission Time                 object
# Planned Operating Room Number                 object
# Pre-Surgery Hospitalization Admission Date    object
# Pre-Surgery Hospitalization Admission Time    object
# Pre-Surgical Admission Time Before Surgery    object
# Surgical Team Codes                           object
# Anesthesiologist Code                         object
# Anesthesia Code                               object
# Type of Anesthesia                            object
# Cancellation Reason on Surgery Day            object
# Actual Operating Room Number                  object
# Actual Surgery Room Entry Date                object
# Actual Surgery Room Entry Time                object
# Incision Time                                 object
# Closure Time                                  object
# End of Surgery Date (Exit from OR)            object
# End of Surgery Time (Exit from OR)            object
# Planned Surgery Duration                      object
# Recovery Room Entry Date                      object
# Recovery Room Entry Time                      object
# Recovery Room Exit Date                       object
# Recovery Room Exit Time                       object
# Post-Surgery Discharge Date                   object
# Post-Surgery Discharge Time                   object
# Planned Start Date for Doctor Block           object
# Planned Start Time for Doctor Block           object
# Planned End Date for Doctor Block             object
# Planned End Time for Doctor Block             object
# Readmission                                   object
# strict_signature                              object
# No Show                                       object
# Entry DateTime                                object
# Incision DateTime                             object
# Closure DateTime                              object
# Exit DateTime                                 object
# Start Time Completion Source                  object
# Exit Time Completion Source                   object
# dtype: object

# %%
from datetime import time

file_path = "/content/patients_with_exit_time_from_neighbors2017.xlsx"
df = pd.read_excel(file_path)

# Merge rows of the same patient
def aggregate_patient_rows(df, id_col='patient_id'):
    agg_dict = {
        col: lambda x: ', '.join(sorted(set(map(str, x.dropna()))))
        for col in df.columns if col != id_col
    }
    return df.groupby(id_col, as_index=False).agg(agg_dict)

df_aggregated = aggregate_patient_rows(df)

#Returning date types for date columns
date_cols = [
    'Pre-Surgery Admission Date',
    'Planned Surgery Date',
    'Surgery Admission Date',
    'Pre-Surgery Hospitalization Admission Date',
    'Actual Surgery Room Entry Date',
    'End of Surgery Date (Exit from OR)',
    'Recovery Room Entry Date',
    'Recovery Room Exit Date',
    'Post-Surgery Discharge Date',
    'Planned Start Date for Doctor Block',
    'Planned End Date for Doctor Block'
]

for col in date_cols:
    if col in df_aggregated.columns:
        df_aggregated[col] = pd.to_datetime(df_aggregated[col], errors='coerce')

# Returning time columns to time format
time_cols = [
    'Planned Surgery Time',
    'Administrative Admission Time',
    'Pre-Surgery Hospitalization Admission Time',
    'Pre-Surgical Admission Time Before Surgery',
    'Actual Surgery Room Entry Time',
    'Incision Time',
    'Closure Time',
    'End of Surgery Time (Exit from OR)',
    'Recovery Room Entry Time',
    'Recovery Room Exit Time',
    'Post-Surgery Discharge Time',
    'Planned Start Time for Doctor Block',
    'Planned End Time for Doctor Block'
]

for col in time_cols:
    if col in df_aggregated.columns:
        df_aggregated[col] = pd.to_datetime(df_aggregated[col], errors='coerce').dt.time

# Convert time columns to numeric value – minutes since midnight
def time_to_minutes(t):
    """Convert time object to minutes since midnight"""
    if pd.isnull(t):
        return None
    try:
        return t.hour * 60 + t.minute + t.second / 60
    except:
        return None

for col in time_cols:
    if col in df_aggregated.columns:
        new_col = col + "_Minutes"
        df_aggregated[new_col] = df_aggregated[col].apply(time_to_minutes)

df_aggregated.to_excel("patients_one_row_per_id_correct_types_END2017.xlsx", index=False)
# Out:
# <ipython-input-9-4f13dc54fa2a>:54: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_aggregated[col] = pd.to_datetime(df_aggregated[col], errors='coerce').dt.time
# <ipython-input-9-4f13dc54fa2a>:54: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_aggregated[col] = pd.to_datetime(df_aggregated[col], errors='coerce').dt.time
# <ipython-input-9-4f13dc54fa2a>:54: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_aggregated[col] = pd.to_datetime(df_aggregated[col], errors='coerce').dt.time
# <ipython-input-9-4f13dc54fa2a>:54: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_aggregated[col] = pd.to_datetime(df_aggregated[col], errors='coerce').dt.time
# <ipython-input-9-4f13dc54fa2a>:54: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_aggregated[col] = pd.to_datetime(df_aggregated[col], errors='coerce').dt.time
# <ipython-input-9-4f13dc54fa2a>:54: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_aggregated[col] = pd.to_datetime(df_aggregated[col], errors='coerce').dt.time
# <ipython-input-9-4f13dc54fa2a>:54: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_aggregated[col] = pd.to_datetime(df_aggregated[col], errors='coerce').dt.time
# <ipython-input-9-4f13dc54fa2a>:54: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_aggregated[col] = pd.to_datetime(df_aggregated[col], errors='coerce').dt.time
# <ipython-input-9-4f13dc54fa2a>:54: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_aggregated[col] = pd.to_datetime(df_aggregated[col], errors='coerce').dt.time
# <ipython-input-9-4f13dc54fa2a>:54: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_aggregated[col] = pd.to_datetime(df_aggregated[col], errors='coerce').dt.time
# <ipython-input-9-4f13dc54fa2a>:54: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_aggregated[col] = pd.to_datetime(df_aggregated[col], errors='coerce').dt.time
# <ipython-input-9-4f13dc54fa2a>:54: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_aggregated[col] = pd.to_datetime(df_aggregated[col], errors='coerce').dt.time
# <ipython-input-9-4f13dc54fa2a>:54: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_aggregated[col] = pd.to_datetime(df_aggregated[col], errors='coerce').dt.time

# %%
df_copy=df_aggregated.copy()

# %%
print(f"Number of rows: {df_copy.shape[0]}")
print(f"Number of columns: {df_copy.shape[1]}")
# Out:
# Number of rows: 44047
# Number of columns: 63

# %%
print(df_copy.head(10))
# Out:
#    patient_id Site Code Main Surgeon Code Activity Code Activity Type Code  \
# 0           1        20       -999, 30817         81.51                 15
# 1           2        20       -999, 18731         65.21                 22
# 2           3        20                 0          86.4                  8
# 3           4        20               184            35                 14
# 4           5        20               184            35                 14
# 5           6        20               184            35                 14
# 6           7        20       -999, 18796         65.21                 22
# 7           8        20       -999, 31448         65.21                 22
# 8           9        20       -999, 31448         65.21                 22
# 9          10        20                 2          86.4                  8
#
#   Planned SU Time (Large/Medium/Small) Pre-Surgery Patient File (External)  \
# 0                                 20.0                          23457403.0
# 1                                 20.0                          23457802.0
# 2                                 19.0                          23453184.0
# 3
# 4
# 5                                  0.0                          23457806.0
# 6                                  0.0                          23457800.0
# 7                                  9.0                          23457628.0
# 8                                 20.0                          23457631.0
# 9
#
#   Pre-Surgery Admission Date Height Weight  ...  \
# 0                 2017-06-08   1.57   63.0  ...
# 1                 2017-06-15    1.7   79.0  ...
# 2                 2017-03-15   1.68   60.0  ...
# 3                        NaT   1.55   73.3  ...
# 4                        NaT   1.75   84.0  ...
# 5                 2017-06-15   1.64   74.6  ...
# 6                 2017-06-15   1.65   76.0  ...
# 7                 2017-06-13   1.65   71.0  ...
# 8                 2017-06-13   1.65   80.0  ...
# 9                        NaT   1.75   90.0  ...
#
#   Pre-Surgical Admission Time Before Surgery_Minutes  \
# 0                                              607.0
# 1                                             1105.0
# 2                                              692.0
# 3                                             1107.0
# 4                                              859.0
# 5                                             1095.0
# 6                                              491.0
# 7                                              697.0
# 8                                              697.0
# 9                                                NaN
#
#   Actual Surgery Room Entry Time_Minutes Incision Time_Minutes  \
# 0                             660.766667                 678.0
# 1                            1211.133333                1221.0
# 2                             765.000000                 784.0
# 3                            1230.000000                1275.0
# 4                             916.000000                 964.0
# 5                            1195.183333                1239.0
# 6                             536.200000                 700.0
# 7                                    NaN                 833.0
# 8                             878.900000                 891.0
# 9                             482.000000                 490.0
#
#   Closure Time_Minutes End of Surgery Time (Exit from OR)_Minutes  \
# 0                775.0                                      794.0
# 1               1331.0                                     1352.0
# 2                810.0                                      821.0
# 3               1418.0                                     1422.0
# 4               1119.0                                     1133.0
# 5               1406.0                                     1291.0
# 6                744.0                                      753.0
# 7                849.0                                        NaN
# 8                922.0                                      935.0
# 9                507.0                                      507.0
#
#   Recovery Room Entry Time_Minutes Recovery Room Exit Time_Minutes  \
# 0                            794.0                           861.0
# 1                           1352.0                          1438.0
# 2                            824.0                           899.0
# 3                              NaN                             NaN
# 4                              NaN                             NaN
# 5                              NaN                             NaN
# 6                            753.0                           871.0
# 7                            867.0                           949.0
# 8                            935.0                          1023.0
# 9                              NaN                             NaN
#
#   Post-Surgery Discharge Time_Minutes  \
# 0                               769.0
# 1                              1089.0
# 2                               676.0
# 3                               887.0
# 4                               897.0
# 5                               841.0
# 6                               980.0
# 7                              1339.0
# 8                               610.0
# 9                               568.0
#
#   Planned Start Time for Doctor Block_Minutes  \
# 0                                       420.0
# 1                                       900.0
# 2                                         NaN
# 3                                      1140.0
# 4                                       900.0
# 5                                       900.0
# 6                                       640.0
# 7                                       780.0
# 8                                       780.0
# 9                                         NaN
#
#   Planned End Time for Doctor Block_Minutes
# 0                                     764.0
# 1                                    1255.0
# 2                                       NaN
# 3                                    1360.0
# 4                                    1363.0
# 5                                    1375.0
# 6                                     750.0
# 7                                     921.0
# 8                                     921.0
# 9                                       NaN
#
# [10 rows x 63 columns]

# %% [markdown]
# Note!
# Because some fields contain a SET number of details, they will not be converted. They will remain OBJECT.

# %%
from datetime import time

file_path = "/content/patients_one_row_per_id_correct_types_END2017.xlsx"
df = pd.read_excel(file_path)

# Define variable groups
time_vars = [
    'Pre-Surgery Admission Date',
    'Planned Surgery Date',
    'Planned Surgery Time',
    'Surgery Admission Date',
    'Administrative Admission Time',
    'Pre-Surgery Hospitalization Admission Date',
    'Pre-Surgery Hospitalization Admission Time',
    'Pre-Surgical Admission Time Before Surgery',
    'Actual Surgery Room Entry Date',
    'Actual Surgery Room Entry Time',
    'Incision Time',
    'Closure Time',
    'End of Surgery Date (Exit from OR)',
    'End of Surgery Time (Exit from OR)',
    'Recovery Room Entry Date',
    'Recovery Room Entry Time',
    'Recovery Room Exit Date',
    'Recovery Room Exit Time',
    'Post-Surgery Discharge Date',
    'Post-Surgery Discharge Time',
    'Planned Start Date for Doctor Block',
    'Planned Start Time for Doctor Block',
    'Planned End Date for Doctor Block',
    'Planned End Time for Doctor Block'
]

num_vars = [
    'Height',
    'Weight',
    'Patient Age (on Surgery Day)',
    'Planned Surgery Duration',
]

cat_vars = [
    'Background Diseases/Diagnoses', 'Site Code', 'Main Surgeon Code', 'Activity Code', 'Activity Type Code',
    'Planned SU Time (Large/Medium/Small)', 'Planned Operating Room Number', 'Surgical Team Codes',
    'Anesthesiologist Code', 'Anesthesia Code', 'Cancellation Reason on Surgery Day',
    'Actual Operating Room Number', 'Readmission', 'Type of Anesthesia',
    'patient_id', 'strict_signature'
]

# Convert time/date columns to datetime
for col in time_vars:
    if col in df.columns:
        df[col] = pd.to_datetime(df[col], errors='coerce')

# Convert time columns to numeric values (minutes since midnight)
def time_to_minutes(t):
    if pd.isnull(t):
        return None
    try:
        parsed = t if isinstance(t, pd.Timestamp) else pd.to_datetime(t)
        return parsed.hour * 60 + parsed.minute + parsed.second / 60
    except:
        return None

# Identify which time columns are actual time (not date)
time_only_cols = [col for col in time_vars if 'Time' in col]

# Create new *_Minutes columns and add to num_vars
for col in time_only_cols:
    new_col = col + '_Minutes'
    df[new_col] = df[col].apply(time_to_minutes)
    num_vars.append(new_col)

# Convert original num_vars columns to numeric
for col in num_vars:
    if col in df.columns:
        df[col] = pd.to_numeric(df[col], errors='coerce')

# Convert categorical variables
for col in cat_vars:
    if col in df.columns:
        df[col] = df[col].astype('category')
# Out:
# <ipython-input-13-54f30166fcc0>:53: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col], errors='coerce')
# <ipython-input-13-54f30166fcc0>:53: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col], errors='coerce')
# <ipython-input-13-54f30166fcc0>:53: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col], errors='coerce')
# <ipython-input-13-54f30166fcc0>:53: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col], errors='coerce')
# <ipython-input-13-54f30166fcc0>:53: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col], errors='coerce')
# <ipython-input-13-54f30166fcc0>:53: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col], errors='coerce')
# <ipython-input-13-54f30166fcc0>:53: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col], errors='coerce')
# <ipython-input-13-54f30166fcc0>:53: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col], errors='coerce')
# <ipython-input-13-54f30166fcc0>:53: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col], errors='coerce')
# <ipython-input-13-54f30166fcc0>:53: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col], errors='coerce')
# <ipython-input-13-54f30166fcc0>:53: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col], errors='coerce')
# <ipython-input-13-54f30166fcc0>:53: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col], errors='coerce')
# <ipython-input-13-54f30166fcc0>:53: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col], errors='coerce')

# %%
df_copy.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44047 entries, 0 to 44046
# Data columns (total 63 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   patient_id                                          44047 non-null  int64
#  1   Site Code                                           44047 non-null  object
#  2   Main Surgeon Code                                   44047 non-null  object
#  3   Activity Code                                       44047 non-null  object
#  4   Activity Type Code                                  44047 non-null  object
#  5   Planned SU Time (Large/Medium/Small)                44047 non-null  object
#  6   Pre-Surgery Patient File (External)                 44047 non-null  object
#  7   Pre-Surgery Admission Date                          16434 non-null  datetime64[ns]
#  8   Height                                              44047 non-null  object
#  9   Weight                                              44047 non-null  object
#  10  Patient Age (on Surgery Day)                        44047 non-null  object
#  11  Background Diseases/Diagnoses                       44047 non-null  object
#  12  Planned Surgery Date                                40691 non-null  datetime64[ns]
#  13  Planned Surgery Time                                40694 non-null  object
#  14  Surgery Admission Date                              44039 non-null  datetime64[ns]
#  15  Administrative Admission Time                       44046 non-null  object
#  16  Planned Operating Room Number                       44047 non-null  object
#  17  Pre-Surgery Hospitalization Admission Date          43869 non-null  datetime64[ns]
#  18  Pre-Surgery Hospitalization Admission Time          43869 non-null  object
#  19  Pre-Surgical Admission Time Before Surgery          28306 non-null  object
#  20  Surgical Team Codes                                 44047 non-null  object
#  21  Anesthesiologist Code                               44047 non-null  object
#  22  Anesthesia Code                                     44047 non-null  object
#  23  Type of Anesthesia                                  44047 non-null  object
#  24  Cancellation Reason on Surgery Day                  44047 non-null  object
#  25  Actual Operating Room Number                        44047 non-null  object
#  26  Actual Surgery Room Entry Date                      42463 non-null  datetime64[ns]
#  27  Actual Surgery Room Entry Time                      39112 non-null  object
#  28  Incision Time                                       43936 non-null  object
#  29  Closure Time                                        43936 non-null  object
#  30  End of Surgery Date (Exit from OR)                  42463 non-null  datetime64[ns]
#  31  End of Surgery Time (Exit from OR)                  39112 non-null  object
#  32  Planned Surgery Duration                            44047 non-null  object
#  33  Recovery Room Entry Date                            34822 non-null  datetime64[ns]
#  34  Recovery Room Entry Time                            34822 non-null  object
#  35  Recovery Room Exit Date                             34822 non-null  datetime64[ns]
#  36  Recovery Room Exit Time                             34822 non-null  object
#  37  Post-Surgery Discharge Date                         43869 non-null  datetime64[ns]
#  38  Post-Surgery Discharge Time                         43869 non-null  object
#  39  Planned Start Date for Doctor Block                 40688 non-null  datetime64[ns]
#  40  Planned Start Time for Doctor Block                 40691 non-null  object
#  41  Planned End Date for Doctor Block                   40688 non-null  datetime64[ns]
#  42  Planned End Time for Doctor Block                   40691 non-null  object
#  43  Readmission                                         44047 non-null  object
#  44  strict_signature                                    44047 non-null  object
#  45  No Show                                             44047 non-null  object
#  46  Entry DateTime                                      44047 non-null  object
#  47  Incision DateTime                                   44047 non-null  object
#  48  Closure DateTime                                    44047 non-null  object
#  49  Exit DateTime                                       44047 non-null  object
#  50  Planned Surgery Time_Minutes                        40694 non-null  float64
#  51  Administrative Admission Time_Minutes               44046 non-null  float64
#  52  Pre-Surgery Hospitalization Admission Time_Minutes  43869 non-null  float64
#  53  Pre-Surgical Admission Time Before Surgery_Minutes  28306 non-null  float64
#  54  Actual Surgery Room Entry Time_Minutes              39112 non-null  float64
#  55  Incision Time_Minutes                               43936 non-null  float64
#  56  Closure Time_Minutes                                43936 non-null  float64
#  57  End of Surgery Time (Exit from OR)_Minutes          39112 non-null  float64
#  58  Recovery Room Entry Time_Minutes                    34822 non-null  float64
#  59  Recovery Room Exit Time_Minutes                     34822 non-null  float64
#  60  Post-Surgery Discharge Time_Minutes                 43869 non-null  float64
#  61  Planned Start Time for Doctor Block_Minutes         40691 non-null  float64
#  62  Planned End Time for Doctor Block_Minutes           40691 non-null  float64
# dtypes: datetime64[ns](11), float64(13), int64(1), object(38)
# memory usage: 21.2+ MB

# %%
df_copy.isnull().sum()
# Out:
# patient_id                                        0
# Site Code                                         0
# Main Surgeon Code                                 0
# Activity Code                                     0
# Activity Type Code                                0
#                                                ...
# Recovery Room Entry Time_Minutes               9225
# Recovery Room Exit Time_Minutes                9225
# Post-Surgery Discharge Time_Minutes             178
# Planned Start Time for Doctor Block_Minutes    3356
# Planned End Time for Doctor Block_Minutes      3356
# Length: 63, dtype: int64

# %%
#createing a missing values matrix

missing_mat = np.array(df_copy.isnull()).astype(int)

plt.figure(figsize=(10,5))
sns.heatmap(missing_mat).set_title('Missing values')
plt.show()

# %%
df_copy.shape
# Out:
# (44047, 63)

# %%
#for deleting cols that have more than 70% missing values, we check first the percentage of missing values

missing_prop_by_col = df_copy.isnull().sum(axis = 0).sort_values(ascending=False)/df.shape[0]

print(missing_prop_by_col)
# Out:
# Pre-Surgery Admission Date                            0.626899
# Pre-Surgical Admission Time Before Surgery            0.357368
# Pre-Surgical Admission Time Before Surgery_Minutes    0.357368
# Recovery Room Entry Date                              0.209435
# Recovery Room Exit Time                               0.209435
#                                                         ...
# Readmission                                           0.000000
# Planned Surgery Duration                              0.000000
# Closure DateTime                                      0.000000
# Exit DateTime                                         0.000000
# Incision DateTime                                     0.000000
# Length: 63, dtype: float64

# %%
# % missing values
missing_prop_by_col = df_copy.isnull().sum(axis=0).sort_values(ascending=False) / df_copy.shape[0]
print(missing_prop_by_col)

#deleting cols that have more than 70% missing values
cols_to_drop = missing_prop_by_col[missing_prop_by_col >= 0.7].index
df_copy.drop(cols_to_drop, axis=1, inplace=True)

for col in cols_to_drop:
    if col in num_vars:
        num_vars.remove(col)
    elif col in cat_vars:
        cat_vars.remove(col)
    elif col in time_vars:
        time_vars.remove(col)
# Out:
# Pre-Surgery Admission Date                            0.626899
# Pre-Surgical Admission Time Before Surgery            0.357368
# Pre-Surgical Admission Time Before Surgery_Minutes    0.357368
# Recovery Room Entry Date                              0.209435
# Recovery Room Exit Time                               0.209435
#                                                         ...
# Readmission                                           0.000000
# Planned Surgery Duration                              0.000000
# Closure DateTime                                      0.000000
# Exit DateTime                                         0.000000
# Incision DateTime                                     0.000000
# Length: 63, dtype: float64

# %%
df_copy.info() #Cancellation Reason on Surgery Day was deleted
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44047 entries, 0 to 44046
# Data columns (total 63 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   patient_id                                          44047 non-null  int64
#  1   Site Code                                           44047 non-null  object
#  2   Main Surgeon Code                                   44047 non-null  object
#  3   Activity Code                                       44047 non-null  object
#  4   Activity Type Code                                  44047 non-null  object
#  5   Planned SU Time (Large/Medium/Small)                44047 non-null  object
#  6   Pre-Surgery Patient File (External)                 44047 non-null  object
#  7   Pre-Surgery Admission Date                          16434 non-null  datetime64[ns]
#  8   Height                                              44047 non-null  object
#  9   Weight                                              44047 non-null  object
#  10  Patient Age (on Surgery Day)                        44047 non-null  object
#  11  Background Diseases/Diagnoses                       44047 non-null  object
#  12  Planned Surgery Date                                40691 non-null  datetime64[ns]
#  13  Planned Surgery Time                                40694 non-null  object
#  14  Surgery Admission Date                              44039 non-null  datetime64[ns]
#  15  Administrative Admission Time                       44046 non-null  object
#  16  Planned Operating Room Number                       44047 non-null  object
#  17  Pre-Surgery Hospitalization Admission Date          43869 non-null  datetime64[ns]
#  18  Pre-Surgery Hospitalization Admission Time          43869 non-null  object
#  19  Pre-Surgical Admission Time Before Surgery          28306 non-null  object
#  20  Surgical Team Codes                                 44047 non-null  object
#  21  Anesthesiologist Code                               44047 non-null  object
#  22  Anesthesia Code                                     44047 non-null  object
#  23  Type of Anesthesia                                  44047 non-null  object
#  24  Cancellation Reason on Surgery Day                  44047 non-null  object
#  25  Actual Operating Room Number                        44047 non-null  object
#  26  Actual Surgery Room Entry Date                      42463 non-null  datetime64[ns]
#  27  Actual Surgery Room Entry Time                      39112 non-null  object
#  28  Incision Time                                       43936 non-null  object
#  29  Closure Time                                        43936 non-null  object
#  30  End of Surgery Date (Exit from OR)                  42463 non-null  datetime64[ns]
#  31  End of Surgery Time (Exit from OR)                  39112 non-null  object
#  32  Planned Surgery Duration                            44047 non-null  object
#  33  Recovery Room Entry Date                            34822 non-null  datetime64[ns]
#  34  Recovery Room Entry Time                            34822 non-null  object
#  35  Recovery Room Exit Date                             34822 non-null  datetime64[ns]
#  36  Recovery Room Exit Time                             34822 non-null  object
#  37  Post-Surgery Discharge Date                         43869 non-null  datetime64[ns]
#  38  Post-Surgery Discharge Time                         43869 non-null  object
#  39  Planned Start Date for Doctor Block                 40688 non-null  datetime64[ns]
#  40  Planned Start Time for Doctor Block                 40691 non-null  object
#  41  Planned End Date for Doctor Block                   40688 non-null  datetime64[ns]
#  42  Planned End Time for Doctor Block                   40691 non-null  object
#  43  Readmission                                         44047 non-null  object
#  44  strict_signature                                    44047 non-null  object
#  45  No Show                                             44047 non-null  object
#  46  Entry DateTime                                      44047 non-null  object
#  47  Incision DateTime                                   44047 non-null  object
#  48  Closure DateTime                                    44047 non-null  object
#  49  Exit DateTime                                       44047 non-null  object
#  50  Planned Surgery Time_Minutes                        40694 non-null  float64
#  51  Administrative Admission Time_Minutes               44046 non-null  float64
#  52  Pre-Surgery Hospitalization Admission Time_Minutes  43869 non-null  float64
#  53  Pre-Surgical Admission Time Before Surgery_Minutes  28306 non-null  float64
#  54  Actual Surgery Room Entry Time_Minutes              39112 non-null  float64
#  55  Incision Time_Minutes                               43936 non-null  float64
#  56  Closure Time_Minutes                                43936 non-null  float64
#  57  End of Surgery Time (Exit from OR)_Minutes          39112 non-null  float64
#  58  Recovery Room Entry Time_Minutes                    34822 non-null  float64
#  59  Recovery Room Exit Time_Minutes                     34822 non-null  float64
#  60  Post-Surgery Discharge Time_Minutes                 43869 non-null  float64
#  61  Planned Start Time for Doctor Block_Minutes         40691 non-null  float64
#  62  Planned End Time for Doctor Block_Minutes           40691 non-null  float64
# dtypes: datetime64[ns](11), float64(13), int64(1), object(38)
# memory usage: 21.2+ MB

# %% [markdown]
# In case the percentage of missing is between 40-69%, the subsection should be made categorical.

# %%
# Function that converts a time to a part of the day
def time_of_day(hour):
    if pd.isna(hour):
        return 0
    elif 5 <= hour < 12:
        return 1  # Morning
    elif 12 <= hour < 17:
        return 2  # Noon
    elif 17 <= hour < 21:
        return 3  # Evening
    else:
        return 4  # Night

# Calculation of percentage deficiencies
missing_prop_by_col = df_copy.isnull().sum(axis=0).sort_values(ascending=False) / df_copy.shape[0]
print(missing_prop_by_col)

# Variables with medium missingness (for conversion to categories)
cols_to_categorize = missing_prop_by_col[(missing_prop_by_col >= 0.4) & (missing_prop_by_col < 0.7)].index

for col in cols_to_categorize:
    if col in num_vars:
        try:
            df_copy[col] = pd.qcut(df_copy[col], 4, labels=[1, 2, 3, 4], duplicates='drop')
            df_copy[col] = df_copy[col].cat.set_categories([0, 1, 2, 3, 4])
            df_copy[col] = df_copy[col].fillna(0)
            num_vars.remove(col)
            cat_vars.append(col)
        except Exception as e:
            print(f"Conversion error {col} to categories: {e}")

    elif col in time_vars:  # Time columns – already converted to *_Minutes
        try:
            hour_col = col.replace('_Minutes', '_hour')
            time_cat_col = col.replace('_Minutes', '_time_cat')

            df_copy[hour_col] = df_copy[col] // 60
            df_copy[time_cat_col] = df_copy[hour_col].apply(time_of_day)

            df_copy[time_cat_col] = pd.Categorical(
                df_copy[time_cat_col],
                categories=[0, 1, 2, 3, 4],
                ordered=True
            )

            cat_vars.append(time_cat_col)
            time_vars.remove(col)
        except Exception as e:
            print(f"Error converting {col} to time category: {e}")

    elif col in cat_vars:
        if df_copy[col].dtype.name != 'category':
            df_copy[col] = df_copy[col].astype('category')

        if 0 not in df_copy[col].cat.categories:
            df_copy[col] = df_copy[col].cat.add_categories([0])

        df_copy[col] = df_copy[col].fillna(0)
# Out:
# Pre-Surgery Admission Date                            0.626899
# Pre-Surgical Admission Time Before Surgery            0.357368
# Pre-Surgical Admission Time Before Surgery_Minutes    0.357368
# Recovery Room Entry Date                              0.209435
# Recovery Room Exit Time                               0.209435
#                                                         ...
# Readmission                                           0.000000
# Planned Surgery Duration                              0.000000
# Closure DateTime                                      0.000000
# Exit DateTime                                         0.000000
# Incision DateTime                                     0.000000
# Length: 63, dtype: float64
# Error converting Pre-Surgery Admission Date to time category: cannot perform __floordiv__ with this index type: DatetimeArray

# %% [markdown]
# Numerical → kstest
#
# Categorical → chi-square
#
# Time → depends on how you encode it:
#
# As numbers → treat as numerical
#
# As day parts → treat as categorical

# %% [markdown]
# Is there a relationship between the location of the missing values and other variables? :

# %%
from scipy import stats

# Calculate proportion of missing values per column
missing_prop_by_col = df_copy.isnull().sum(axis=0).sort_values(ascending=False) / df_copy.shape[0]

# Select columns with missing values under 40%
cols_to_check_mechanism = missing_prop_by_col[(missing_prop_by_col > 0) & (missing_prop_by_col < 0.4)].index

# Dictionary to store p-values
p_values = {}

for col_missing in cols_to_check_mechanism:
    p_values[col_missing] = {}

    for col in df_copy.columns:
        if col_missing == col:
            continue  # Skip comparison with itself

        try:
            if col in num_vars:
                # Numerical variable → use Kolmogorov–Smirnov test
                s1 = df_copy[col].dropna()
                s2 = df_copy.loc[df_copy[col_missing].notnull(), col].dropna()
                _, p = stats.ks_2samp(s1, s2)

            elif col in time_vars:
                # Time variable → extract hour and treat as numerical
                temp_hour = df_copy[col].dt.hour
                s1 = temp_hour.dropna()
                s2 = temp_hour[df_copy[col_missing].notnull()].dropna()
                _, p = stats.ks_2samp(s1, s2)

            elif col in time_vars:
                s1 = df_copy[col].dropna()
                s2 = df_copy.loc[df_copy[col_missing].notnull(), col].dropna()
                _, p = stats.ks_2samp(s1, s2)


            elif col in cat_vars or df_copy[col].dtype.name == 'category':
                # Categorical variable → Chi-Square test
                s1 = df_copy[col_missing].isnull().astype(int)
                s2 = df_copy[col]
                table = pd.crosstab(s1, s2)
                _, p, _, _ = stats.chi2_contingency(table)

            else:
                # Default: treat as categorical
                s1 = df_copy[col_missing].isnull().astype(int)
                s2 = df_copy[col]
                table = pd.crosstab(s1, s2)
                _, p, _, _ = stats.chi2_contingency(table)

            p_values[col_missing][col] = p

        except Exception as e:
            print(f"Skipping {col_missing} vs {col}: {e}")
# Out:
# Skipping Pre-Surgical Admission Time Before Surgery vs Planned Surgery Time: Can only use .dt accessor with datetimelike values
# Skipping Pre-Surgical Admission Time Before Surgery vs Administrative Admission Time: Can only use .dt accessor with datetimelike values
# Skipping Pre-Surgical Admission Time Before Surgery vs Pre-Surgery Hospitalization Admission Time: Can only use .dt accessor with datetimelike values
# Skipping Pre-Surgical Admission Time Before Surgery vs Actual Surgery Room Entry Time: Can only use .dt accessor with datetimelike values
# Skipping Pre-Surgical Admission Time Before Surgery vs Incision Time: Can only use .dt accessor with datetimelike values
# Skipping Pre-Surgical Admission Time Before Surgery vs Closure Time: Can only use .dt accessor with datetimelike values
# Skipping Pre-Surgical Admission Time Before Surgery vs End of Surgery Time (Exit from OR): Can only use .dt accessor with datetimelike values
# Skipping Pre-Surgical Admission Time Before Surgery vs Recovery Room Entry Time: Can only use .dt accessor with datetimelike values
# Skipping Pre-Surgical Admission Time Before Surgery vs Recovery Room Exit Time: Can only use .dt accessor with datetimelike values
# Skipping Pre-Surgical Admission Time Before Surgery vs Post-Surgery Discharge Time: Can only use .dt accessor with datetimelike values
# Skipping Pre-Surgical Admission Time Before Surgery vs Planned Start Time for Doctor Block: Can only use .dt accessor with datetimelike values
# Skipping Pre-Surgical Admission Time Before Surgery vs Planned End Time for Doctor Block: Can only use .dt accessor with datetimelike values
# Skipping Pre-Surgical Admission Time Before Surgery_Minutes vs Planned Surgery Time: Can only use .dt accessor with datetimelike values
# Skipping Pre-Surgical Admission Time Before Surgery_Minutes vs Administrative Admission Time: Can only use .dt accessor with datetimelike values
# Skipping Pre-Surgical Admission Time Before Surgery_Minutes vs Pre-Surgery Hospitalization Admission Time: Can only use .dt accessor with datetimelike values
# Skipping Pre-Surgical Admission Time Before Surgery_Minutes vs Pre-Surgical Admission Time Before Surgery: Can only use .dt accessor with datetimelike values
# Skipping Pre-Surgical Admission Time Before Surgery_Minutes vs Actual Surgery Room Entry Time: Can only use .dt accessor with datetimelike values
# Skipping Pre-Surgical Admission Time Before Surgery_Minutes vs Incision Time: Can only use .dt accessor with datetimelike values
# Skipping Pre-Surgical Admission Time Before Surgery_Minutes vs Closure Time: Can only use .dt accessor with datetimelike values
# Skipping Pre-Surgical Admission Time Before Surgery_Minutes vs End of Surgery Time (Exit from OR): Can only use .dt accessor with datetimelike values
# Skipping Pre-Surgical Admission Time Before Surgery_Minutes vs Recovery Room Entry Time: Can only use .dt accessor with datetimelike values
# Skipping Pre-Surgical Admission Time Before Surgery_Minutes vs Recovery Room Exit Time: Can only use .dt accessor with datetimelike values
# Skipping Pre-Surgical Admission Time Before Surgery_Minutes vs Post-Surgery Discharge Time: Can only use .dt accessor with datetimelike values
# Skipping Pre-Surgical Admission Time Before Surgery_Minutes vs Planned Start Time for Doctor Block: Can only use .dt accessor with datetimelike values
# Skipping Pre-Surgical Admission Time Before Surgery_Minutes vs Planned End Time for Doctor Block: Can only use .dt accessor with datetimelike values
# Skipping Recovery Room Entry Date vs Planned Surgery Time: Can only use .dt accessor with datetimelike values
# Skipping Recovery Room Entry Date vs Administrative Admission Time: Can only use .dt accessor with datetimelike values
# Skipping Recovery Room Entry Date vs Pre-Surgery Hospitalization Admission Time: Can only use .dt accessor with datetimelike values
# Skipping Recovery Room Entry Date vs Pre-Surgical Admission Time Before Surgery: Can only use .dt accessor with datetimelike values
# Skipping Recovery Room Entry Date vs Actual Surgery Room Entry Time: Can only use .dt accessor with datetimelike values
# Skipping Recovery Room Entry Date vs Incision Time: Can only use .dt accessor with datetimelike values
# Skipping Recovery Room Entry Date vs Closure Time: Can only use .dt accessor with datetimelike values
# Skipping Recovery Room Entry Date vs End of Surgery Time (Exit from OR): Can only use .dt accessor with datetimelike values
# Skipping Recovery Room Entry Date vs Recovery Room Entry Time: Can only use .dt accessor with datetimelike values
# Skipping Recovery Room Entry Date vs Recovery Room Exit Time: Can only use .dt accessor with datetimelike values
# Skipping Recovery Room Entry Date vs Post-Surgery Discharge Time: Can only use .dt accessor with datetimelike values
# Skipping Recovery Room Entry Date vs Planned Start Time for Doctor Block: Can only use .dt accessor with datetimelike values
# Skipping Recovery Room Entry Date vs Planned End Time for Doctor Block: Can only use .dt accessor with datetimelike values
# Skipping Recovery Room Exit Time vs Planned Surgery Time: Can only use .dt accessor with datetimelike values
# Skipping Recovery Room Exit Time vs Administrative Admission Time: Can only use .dt accessor with datetimelike values
# Skipping Recovery Room Exit Time vs Pre-Surgery Hospitalization Admission Time: Can only use .dt accessor with datetimelike values
# Skipping Recovery Room Exit Time vs Pre-Surgical Admission Time Before Surgery: Can only use .dt accessor with datetimelike values
# Skipping Recovery Room Exit Time vs Actual Surgery Room Entry Time: Can only use .dt accessor with datetimelike values
# Skipping Recovery Room Exit Time vs Incision Time: Can only use .dt accessor with datetimelike values
# Skipping Recovery Room Exit Time vs Closure Time: Can only use .dt accessor with datetimelike values
# Skipping Recovery Room Exit Time vs End of Surgery Time (Exit from OR): Can only use .dt accessor with datetimelike values
# Skipping Recovery Room Exit Time vs Recovery Room Entry Time: Can only use .dt accessor with datetimelike values
# Skipping Recovery Room Exit Time vs Post-Surgery Discharge Time: Can only use .dt accessor with datetimelike values
# Skipping Recovery Room Exit Time vs Planned Start Time for Doctor Block: Can only use .dt accessor with datetimelike values
# Skipping Recovery Room Exit Time vs Planned End Time for Doctor Block: Can only use .dt accessor with datetimelike values
# Skipping Recovery Room Entry Time vs Planned Surgery Time: Can only use .dt accessor with datetimelike values
# Skipping Recovery Room Entry Time vs Administrative Admission Time: Can only use .dt accessor with datetimelike values
# Skipping Recovery Room Entry Time vs Pre-Surgery Hospitalization Admission Time: Can only use .dt accessor with datetimelike values
# Skipping Recovery Room Entry Time vs Pre-Surgical Admission Time Before Surgery: Can only use .dt accessor with datetimelike values
# Skipping Recovery Room Entry Time vs Actual Surgery Room Entry Time: Can only use .dt accessor with datetimelike values
# Skipping Recovery Room Entry Time vs Incision Time: Can only use .dt accessor with datetimelike values
# Skipping Recovery Room Entry Time vs Closure Time: Can only use .dt accessor with datetimelike values
# Skipping Recovery Room Entry Time vs End of Surgery Time (Exit from OR): Can only use .dt accessor with datetimelike values
# Skipping Recovery Room Entry Time vs Recovery Room Exit Time: Can only use .dt accessor with datetimelike values
# Skipping Recovery Room Entry Time vs Post-Surgery Discharge Time: Can only use .dt accessor with datetimelike values
# Skipping Recovery Room Entry Time vs Planned Start Time for Doctor Block: Can only use .dt accessor with datetimelike values
# Skipping Recovery Room Entry Time vs Planned End Time for Doctor Block: Can only use .dt accessor with datetimelike values
# Skipping Recovery Room Entry Time_Minutes vs Planned Surgery Time: Can only use .dt accessor with datetimelike values
# Skipping Recovery Room Entry Time_Minutes vs Administrative Admission Time: Can only use .dt accessor with datetimelike values
# Skipping Recovery Room Entry Time_Minutes vs Pre-Surgery Hospitalization Admission Time: Can only use .dt accessor with datetimelike values
# Skipping Recovery Room Entry Time_Minutes vs Pre-Surgical Admission Time Before Surgery: Can only use .dt accessor with datetimelike values
# Skipping Recovery Room Entry Time_Minutes vs Actual Surgery Room Entry Time: Can only use .dt accessor with datetimelike values
# Skipping Recovery Room Entry Time_Minutes vs Incision Time: Can only use .dt accessor with datetimelike values
# Skipping Recovery Room Entry Time_Minutes vs Closure Time: Can only use .dt accessor with datetimelike values
# Skipping Recovery Room Entry Time_Minutes vs End of Surgery Time (Exit from OR): Can only use .dt accessor with datetimelike values
# Skipping Recovery Room Entry Time_Minutes vs Recovery Room Entry Time: Can only use .dt accessor with datetimelike values
# Skipping Recovery Room Entry Time_Minutes vs Recovery Room Exit Time: Can only use .dt accessor with datetimelike values
# Skipping Recovery Room Entry Time_Minutes vs Post-Surgery Discharge Time: Can only use .dt accessor with datetimelike values
# Skipping Recovery Room Entry Time_Minutes vs Planned Start Time for Doctor Block: Can only use .dt accessor with datetimelike values
# Skipping Recovery Room Entry Time_Minutes vs Planned End Time for Doctor Block: Can only use .dt accessor with datetimelike values
# Skipping Recovery Room Exit Time_Minutes vs Planned Surgery Time: Can only use .dt accessor with datetimelike values
# Skipping Recovery Room Exit Time_Minutes vs Administrative Admission Time: Can only use .dt accessor with datetimelike values
# Skipping Recovery Room Exit Time_Minutes vs Pre-Surgery Hospitalization Admission Time: Can only use .dt accessor with datetimelike values
# Skipping Recovery Room Exit Time_Minutes vs Pre-Surgical Admission Time Before Surgery: Can only use .dt accessor with datetimelike values
# Skipping Recovery Room Exit Time_Minutes vs Actual Surgery Room Entry Time: Can only use .dt accessor with datetimelike values
# Skipping Recovery Room Exit Time_Minutes vs Incision Time: Can only use .dt accessor with datetimelike values
# Skipping Recovery Room Exit Time_Minutes vs Closure Time: Can only use .dt accessor with datetimelike values
# Skipping Recovery Room Exit Time_Minutes vs End of Surgery Time (Exit from OR): Can only use .dt accessor with datetimelike values
# Skipping Recovery Room Exit Time_Minutes vs Recovery Room Entry Time: Can only use .dt accessor with datetimelike values
# Skipping Recovery Room Exit Time_Minutes vs Recovery Room Exit Time: Can only use .dt accessor with datetimelike values
# Skipping Recovery Room Exit Time_Minutes vs Post-Surgery Discharge Time: Can only use .dt accessor with datetimelike values
# Skipping Recovery Room Exit Time_Minutes vs Planned Start Time for Doctor Block: Can only use .dt accessor with datetimelike values
# Skipping Recovery Room Exit Time_Minutes vs Planned End Time for Doctor Block: Can only use .dt accessor with datetimelike values
# Skipping Recovery Room Exit Date vs Planned Surgery Time: Can only use .dt accessor with datetimelike values
# Skipping Recovery Room Exit Date vs Administrative Admission Time: Can only use .dt accessor with datetimelike values
# Skipping Recovery Room Exit Date vs Pre-Surgery Hospitalization Admission Time: Can only use .dt accessor with datetimelike values
# Skipping Recovery Room Exit Date vs Pre-Surgical Admission Time Before Surgery: Can only use .dt accessor with datetimelike values
# Skipping Recovery Room Exit Date vs Actual Surgery Room Entry Time: Can only use .dt accessor with datetimelike values
# Skipping Recovery Room Exit Date vs Incision Time: Can only use .dt accessor with datetimelike values
# Skipping Recovery Room Exit Date vs Closure Time: Can only use .dt accessor with datetimelike values
# Skipping Recovery Room Exit Date vs End of Surgery Time (Exit from OR): Can only use .dt accessor with datetimelike values
# Skipping Recovery Room Exit Date vs Recovery Room Entry Time: Can only use .dt accessor with datetimelike values
# Skipping Recovery Room Exit Date vs Recovery Room Exit Time: Can only use .dt accessor with datetimelike values
# Skipping Recovery Room Exit Date vs Post-Surgery Discharge Time: Can only use .dt accessor with datetimelike values
# Skipping Recovery Room Exit Date vs Planned Start Time for Doctor Block: Can only use .dt accessor with datetimelike values
# Skipping Recovery Room Exit Date vs Planned End Time for Doctor Block: Can only use .dt accessor with datetimelike values
# Skipping End of Surgery Time (Exit from OR) vs Planned Surgery Time: Can only use .dt accessor with datetimelike values
# Skipping End of Surgery Time (Exit from OR) vs Administrative Admission Time: Can only use .dt accessor with datetimelike values
# Skipping End of Surgery Time (Exit from OR) vs Pre-Surgery Hospitalization Admission Time: Can only use .dt accessor with datetimelike values
# Skipping End of Surgery Time (Exit from OR) vs Pre-Surgical Admission Time Before Surgery: Can only use .dt accessor with datetimelike values
# Skipping End of Surgery Time (Exit from OR) vs Actual Surgery Room Entry Time: Can only use .dt accessor with datetimelike values
# Skipping End of Surgery Time (Exit from OR) vs Incision Time: Can only use .dt accessor with datetimelike values
# Skipping End of Surgery Time (Exit from OR) vs Closure Time: Can only use .dt accessor with datetimelike values
# Skipping End of Surgery Time (Exit from OR) vs Recovery Room Entry Time: Can only use .dt accessor with datetimelike values
# Skipping End of Surgery Time (Exit from OR) vs Recovery Room Exit Time: Can only use .dt accessor with datetimelike values
# Skipping End of Surgery Time (Exit from OR) vs Post-Surgery Discharge Time: Can only use .dt accessor with datetimelike values
# Skipping End of Surgery Time (Exit from OR) vs Planned Start Time for Doctor Block: Can only use .dt accessor with datetimelike values
# Skipping End of Surgery Time (Exit from OR) vs Planned End Time for Doctor Block: Can only use .dt accessor with datetimelike values
# Skipping Actual Surgery Room Entry Time vs Planned Surgery Time: Can only use .dt accessor with datetimelike values
# Skipping Actual Surgery Room Entry Time vs Administrative Admission Time: Can only use .dt accessor with datetimelike values
# Skipping Actual Surgery Room Entry Time vs Pre-Surgery Hospitalization Admission Time: Can only use .dt accessor with datetimelike values
# Skipping Actual Surgery Room Entry Time vs Pre-Surgical Admission Time Before Surgery: Can only use .dt accessor with datetimelike values
# Skipping Actual Surgery Room Entry Time vs Incision Time: Can only use .dt accessor with datetimelike values
# Skipping Actual Surgery Room Entry Time vs Closure Time: Can only use .dt accessor with datetimelike values
# Skipping Actual Surgery Room Entry Time vs End of Surgery Time (Exit from OR): Can only use .dt accessor with datetimelike values
# Skipping Actual Surgery Room Entry Time vs Recovery Room Entry Time: Can only use .dt accessor with datetimelike values
# Skipping Actual Surgery Room Entry Time vs Recovery Room Exit Time: Can only use .dt accessor with datetimelike values
# Skipping Actual Surgery Room Entry Time vs Post-Surgery Discharge Time: Can only use .dt accessor with datetimelike values
# Skipping Actual Surgery Room Entry Time vs Planned Start Time for Doctor Block: Can only use .dt accessor with datetimelike values
# Skipping Actual Surgery Room Entry Time vs Planned End Time for Doctor Block: Can only use .dt accessor with datetimelike values
# Skipping End of Surgery Time (Exit from OR)_Minutes vs Planned Surgery Time: Can only use .dt accessor with datetimelike values
# Skipping End of Surgery Time (Exit from OR)_Minutes vs Administrative Admission Time: Can only use .dt accessor with datetimelike values
# Skipping End of Surgery Time (Exit from OR)_Minutes vs Pre-Surgery Hospitalization Admission Time: Can only use .dt accessor with datetimelike values
# Skipping End of Surgery Time (Exit from OR)_Minutes vs Pre-Surgical Admission Time Before Surgery: Can only use .dt accessor with datetimelike values
# Skipping End of Surgery Time (Exit from OR)_Minutes vs Actual Surgery Room Entry Time: Can only use .dt accessor with datetimelike values
# Skipping End of Surgery Time (Exit from OR)_Minutes vs Incision Time: Can only use .dt accessor with datetimelike values
# Skipping End of Surgery Time (Exit from OR)_Minutes vs Closure Time: Can only use .dt accessor with datetimelike values
# Skipping End of Surgery Time (Exit from OR)_Minutes vs End of Surgery Time (Exit from OR): Can only use .dt accessor with datetimelike values
# Skipping End of Surgery Time (Exit from OR)_Minutes vs Recovery Room Entry Time: Can only use .dt accessor with datetimelike values
# Skipping End of Surgery Time (Exit from OR)_Minutes vs Recovery Room Exit Time: Can only use .dt accessor with datetimelike values
# Skipping End of Surgery Time (Exit from OR)_Minutes vs Post-Surgery Discharge Time: Can only use .dt accessor with datetimelike values
# Skipping End of Surgery Time (Exit from OR)_Minutes vs Planned Start Time for Doctor Block: Can only use .dt accessor with datetimelike values
# Skipping End of Surgery Time (Exit from OR)_Minutes vs Planned End Time for Doctor Block: Can only use .dt accessor with datetimelike values
# Skipping Actual Surgery Room Entry Time_Minutes vs Planned Surgery Time: Can only use .dt accessor with datetimelike values
# Skipping Actual Surgery Room Entry Time_Minutes vs Administrative Admission Time: Can only use .dt accessor with datetimelike values
# Skipping Actual Surgery Room Entry Time_Minutes vs Pre-Surgery Hospitalization Admission Time: Can only use .dt accessor with datetimelike values
# Skipping Actual Surgery Room Entry Time_Minutes vs Pre-Surgical Admission Time Before Surgery: Can only use .dt accessor with datetimelike values
# Skipping Actual Surgery Room Entry Time_Minutes vs Actual Surgery Room Entry Time: Can only use .dt accessor with datetimelike values
# Skipping Actual Surgery Room Entry Time_Minutes vs Incision Time: Can only use .dt accessor with datetimelike values
# Skipping Actual Surgery Room Entry Time_Minutes vs Closure Time: Can only use .dt accessor with datetimelike values
# Skipping Actual Surgery Room Entry Time_Minutes vs End of Surgery Time (Exit from OR): Can only use .dt accessor with datetimelike values
# Skipping Actual Surgery Room Entry Time_Minutes vs Recovery Room Entry Time: Can only use .dt accessor with datetimelike values
# Skipping Actual Surgery Room Entry Time_Minutes vs Recovery Room Exit Time: Can only use .dt accessor with datetimelike values
# Skipping Actual Surgery Room Entry Time_Minutes vs Post-Surgery Discharge Time: Can only use .dt accessor with datetimelike values
# Skipping Actual Surgery Room Entry Time_Minutes vs Planned Start Time for Doctor Block: Can only use .dt accessor with datetimelike values
# Skipping Actual Surgery Room Entry Time_Minutes vs Planned End Time for Doctor Block: Can only use .dt accessor with datetimelike values
# Skipping Planned Start Date for Doctor Block vs Planned Surgery Time: Can only use .dt accessor with datetimelike values
# Skipping Planned Start Date for Doctor Block vs Administrative Admission Time: Can only use .dt accessor with datetimelike values
# Skipping Planned Start Date for Doctor Block vs Pre-Surgery Hospitalization Admission Time: Can only use .dt accessor with datetimelike values
# Skipping Planned Start Date for Doctor Block vs Pre-Surgical Admission Time Before Surgery: Can only use .dt accessor with datetimelike values
# Skipping Planned Start Date for Doctor Block vs Actual Surgery Room Entry Time: Can only use .dt accessor with datetimelike values
# Skipping Planned Start Date for Doctor Block vs Incision Time: Can only use .dt accessor with datetimelike values
# Skipping Planned Start Date for Doctor Block vs Closure Time: Can only use .dt accessor with datetimelike values
# Skipping Planned Start Date for Doctor Block vs End of Surgery Time (Exit from OR): Can only use .dt accessor with datetimelike values
# Skipping Planned Start Date for Doctor Block vs Recovery Room Entry Time: Can only use .dt accessor with datetimelike values
# Skipping Planned Start Date for Doctor Block vs Recovery Room Exit Time: Can only use .dt accessor with datetimelike values
# Skipping Planned Start Date for Doctor Block vs Post-Surgery Discharge Time: Can only use .dt accessor with datetimelike values
# Skipping Planned Start Date for Doctor Block vs Planned Start Time for Doctor Block: Can only use .dt accessor with datetimelike values
# Skipping Planned Start Date for Doctor Block vs Planned End Time for Doctor Block: Can only use .dt accessor with datetimelike values
# Skipping Planned End Date for Doctor Block vs Planned Surgery Time: Can only use .dt accessor with datetimelike values
# Skipping Planned End Date for Doctor Block vs Administrative Admission Time: Can only use .dt accessor with datetimelike values
# Skipping Planned End Date for Doctor Block vs Pre-Surgery Hospitalization Admission Time: Can only use .dt accessor with datetimelike values
# Skipping Planned End Date for Doctor Block vs Pre-Surgical Admission Time Before Surgery: Can only use .dt accessor with datetimelike values
# Skipping Planned End Date for Doctor Block vs Actual Surgery Room Entry Time: Can only use .dt accessor with datetimelike values
# Skipping Planned End Date for Doctor Block vs Incision Time: Can only use .dt accessor with datetimelike values
# Skipping Planned End Date for Doctor Block vs Closure Time: Can only use .dt accessor with datetimelike values
# Skipping Planned End Date for Doctor Block vs End of Surgery Time (Exit from OR): Can only use .dt accessor with datetimelike values
# Skipping Planned End Date for Doctor Block vs Recovery Room Entry Time: Can only use .dt accessor with datetimelike values
# Skipping Planned End Date for Doctor Block vs Recovery Room Exit Time: Can only use .dt accessor with datetimelike values
# Skipping Planned End Date for Doctor Block vs Post-Surgery Discharge Time: Can only use .dt accessor with datetimelike values
# Skipping Planned End Date for Doctor Block vs Planned Start Time for Doctor Block: Can only use .dt accessor with datetimelike values
# Skipping Planned End Date for Doctor Block vs Planned End Time for Doctor Block: Can only use .dt accessor with datetimelike values
# Skipping Planned Start Time for Doctor Block vs Planned Surgery Time: Can only use .dt accessor with datetimelike values
# Skipping Planned Start Time for Doctor Block vs Administrative Admission Time: Can only use .dt accessor with datetimelike values
# Skipping Planned Start Time for Doctor Block vs Pre-Surgery Hospitalization Admission Time: Can only use .dt accessor with datetimelike values
# Skipping Planned Start Time for Doctor Block vs Pre-Surgical Admission Time Before Surgery: Can only use .dt accessor with datetimelike values
# Skipping Planned Start Time for Doctor Block vs Actual Surgery Room Entry Time: Can only use .dt accessor with datetimelike values
# Skipping Planned Start Time for Doctor Block vs Incision Time: Can only use .dt accessor with datetimelike values
# Skipping Planned Start Time for Doctor Block vs Closure Time: Can only use .dt accessor with datetimelike values
# Skipping Planned Start Time for Doctor Block vs End of Surgery Time (Exit from OR): Can only use .dt accessor with datetimelike values
# Skipping Planned Start Time for Doctor Block vs Recovery Room Entry Time: Can only use .dt accessor with datetimelike values
# Skipping Planned Start Time for Doctor Block vs Recovery Room Exit Time: Can only use .dt accessor with datetimelike values
# Skipping Planned Start Time for Doctor Block vs Post-Surgery Discharge Time: Can only use .dt accessor with datetimelike values
# Skipping Planned Start Time for Doctor Block vs Planned End Time for Doctor Block: Can only use .dt accessor with datetimelike values
# Skipping Planned Start Time for Doctor Block_Minutes vs Planned Surgery Time: Can only use .dt accessor with datetimelike values
# Skipping Planned Start Time for Doctor Block_Minutes vs Administrative Admission Time: Can only use .dt accessor with datetimelike values
# Skipping Planned Start Time for Doctor Block_Minutes vs Pre-Surgery Hospitalization Admission Time: Can only use .dt accessor with datetimelike values
# Skipping Planned Start Time for Doctor Block_Minutes vs Pre-Surgical Admission Time Before Surgery: Can only use .dt accessor with datetimelike values
# Skipping Planned Start Time for Doctor Block_Minutes vs Actual Surgery Room Entry Time: Can only use .dt accessor with datetimelike values
# Skipping Planned Start Time for Doctor Block_Minutes vs Incision Time: Can only use .dt accessor with datetimelike values
# Skipping Planned Start Time for Doctor Block_Minutes vs Closure Time: Can only use .dt accessor with datetimelike values
# Skipping Planned Start Time for Doctor Block_Minutes vs End of Surgery Time (Exit from OR): Can only use .dt accessor with datetimelike values
# Skipping Planned Start Time for Doctor Block_Minutes vs Recovery Room Entry Time: Can only use .dt accessor with datetimelike values
# Skipping Planned Start Time for Doctor Block_Minutes vs Recovery Room Exit Time: Can only use .dt accessor with datetimelike values
# Skipping Planned Start Time for Doctor Block_Minutes vs Post-Surgery Discharge Time: Can only use .dt accessor with datetimelike values
# Skipping Planned Start Time for Doctor Block_Minutes vs Planned Start Time for Doctor Block: Can only use .dt accessor with datetimelike values
# Skipping Planned Start Time for Doctor Block_Minutes vs Planned End Time for Doctor Block: Can only use .dt accessor with datetimelike values
# Skipping Planned End Time for Doctor Block_Minutes vs Planned Surgery Time: Can only use .dt accessor with datetimelike values
# Skipping Planned End Time for Doctor Block_Minutes vs Administrative Admission Time: Can only use .dt accessor with datetimelike values
# Skipping Planned End Time for Doctor Block_Minutes vs Pre-Surgery Hospitalization Admission Time: Can only use .dt accessor with datetimelike values
# Skipping Planned End Time for Doctor Block_Minutes vs Pre-Surgical Admission Time Before Surgery: Can only use .dt accessor with datetimelike values
# Skipping Planned End Time for Doctor Block_Minutes vs Actual Surgery Room Entry Time: Can only use .dt accessor with datetimelike values
# Skipping Planned End Time for Doctor Block_Minutes vs Incision Time: Can only use .dt accessor with datetimelike values
# Skipping Planned End Time for Doctor Block_Minutes vs Closure Time: Can only use .dt accessor with datetimelike values
# Skipping Planned End Time for Doctor Block_Minutes vs End of Surgery Time (Exit from OR): Can only use .dt accessor with datetimelike values
# Skipping Planned End Time for Doctor Block_Minutes vs Recovery Room Entry Time: Can only use .dt accessor with datetimelike values
# Skipping Planned End Time for Doctor Block_Minutes vs Recovery Room Exit Time: Can only use .dt accessor with datetimelike values
# Skipping Planned End Time for Doctor Block_Minutes vs Post-Surgery Discharge Time: Can only use .dt accessor with datetimelike values
# Skipping Planned End Time for Doctor Block_Minutes vs Planned Start Time for Doctor Block: Can only use .dt accessor with datetimelike values
# Skipping Planned End Time for Doctor Block_Minutes vs Planned End Time for Doctor Block: Can only use .dt accessor with datetimelike values
# Skipping Planned End Time for Doctor Block vs Planned Surgery Time: Can only use .dt accessor with datetimelike values
# Skipping Planned End Time for Doctor Block vs Administrative Admission Time: Can only use .dt accessor with datetimelike values
# Skipping Planned End Time for Doctor Block vs Pre-Surgery Hospitalization Admission Time: Can only use .dt accessor with datetimelike values
# Skipping Planned End Time for Doctor Block vs Pre-Surgical Admission Time Before Surgery: Can only use .dt accessor with datetimelike values
# Skipping Planned End Time for Doctor Block vs Actual Surgery Room Entry Time: Can only use .dt accessor with datetimelike values
# Skipping Planned End Time for Doctor Block vs Incision Time: Can only use .dt accessor with datetimelike values
# Skipping Planned End Time for Doctor Block vs Closure Time: Can only use .dt accessor with datetimelike values
# Skipping Planned End Time for Doctor Block vs End of Surgery Time (Exit from OR): Can only use .dt accessor with datetimelike values
# Skipping Planned End Time for Doctor Block vs Recovery Room Entry Time: Can only use .dt accessor with datetimelike values
# Skipping Planned End Time for Doctor Block vs Recovery Room Exit Time: Can only use .dt accessor with datetimelike values
# Skipping Planned End Time for Doctor Block vs Post-Surgery Discharge Time: Can only use .dt accessor with datetimelike values
# Skipping Planned End Time for Doctor Block vs Planned Start Time for Doctor Block: Can only use .dt accessor with datetimelike values
# Skipping Planned Surgery Date vs Planned Surgery Time: Can only use .dt accessor with datetimelike values
# Skipping Planned Surgery Date vs Administrative Admission Time: Can only use .dt accessor with datetimelike values
# Skipping Planned Surgery Date vs Pre-Surgery Hospitalization Admission Time: Can only use .dt accessor with datetimelike values
# Skipping Planned Surgery Date vs Pre-Surgical Admission Time Before Surgery: Can only use .dt accessor with datetimelike values
# Skipping Planned Surgery Date vs Actual Surgery Room Entry Time: Can only use .dt accessor with datetimelike values
# Skipping Planned Surgery Date vs Incision Time: Can only use .dt accessor with datetimelike values
# Skipping Planned Surgery Date vs Closure Time: Can only use .dt accessor with datetimelike values
# Skipping Planned Surgery Date vs End of Surgery Time (Exit from OR): Can only use .dt accessor with datetimelike values
# Skipping Planned Surgery Date vs Recovery Room Entry Time: Can only use .dt accessor with datetimelike values
# Skipping Planned Surgery Date vs Recovery Room Exit Time: Can only use .dt accessor with datetimelike values
# Skipping Planned Surgery Date vs Post-Surgery Discharge Time: Can only use .dt accessor with datetimelike values
# Skipping Planned Surgery Date vs Planned Start Time for Doctor Block: Can only use .dt accessor with datetimelike values
# Skipping Planned Surgery Date vs Planned End Time for Doctor Block: Can only use .dt accessor with datetimelike values
# Skipping Planned Surgery Time vs Administrative Admission Time: Can only use .dt accessor with datetimelike values
# Skipping Planned Surgery Time vs Pre-Surgery Hospitalization Admission Time: Can only use .dt accessor with datetimelike values
# Skipping Planned Surgery Time vs Pre-Surgical Admission Time Before Surgery: Can only use .dt accessor with datetimelike values
# Skipping Planned Surgery Time vs Actual Surgery Room Entry Time: Can only use .dt accessor with datetimelike values
# Skipping Planned Surgery Time vs Incision Time: Can only use .dt accessor with datetimelike values
# Skipping Planned Surgery Time vs Closure Time: Can only use .dt accessor with datetimelike values
# Skipping Planned Surgery Time vs End of Surgery Time (Exit from OR): Can only use .dt accessor with datetimelike values
# Skipping Planned Surgery Time vs Recovery Room Entry Time: Can only use .dt accessor with datetimelike values
# Skipping Planned Surgery Time vs Recovery Room Exit Time: Can only use .dt accessor with datetimelike values
# Skipping Planned Surgery Time vs Post-Surgery Discharge Time: Can only use .dt accessor with datetimelike values
# Skipping Planned Surgery Time vs Planned Start Time for Doctor Block: Can only use .dt accessor with datetimelike values
# Skipping Planned Surgery Time vs Planned End Time for Doctor Block: Can only use .dt accessor with datetimelike values
# Skipping Planned Surgery Time_Minutes vs Planned Surgery Time: Can only use .dt accessor with datetimelike values
# Skipping Planned Surgery Time_Minutes vs Administrative Admission Time: Can only use .dt accessor with datetimelike values
# Skipping Planned Surgery Time_Minutes vs Pre-Surgery Hospitalization Admission Time: Can only use .dt accessor with datetimelike values
# Skipping Planned Surgery Time_Minutes vs Pre-Surgical Admission Time Before Surgery: Can only use .dt accessor with datetimelike values
# Skipping Planned Surgery Time_Minutes vs Actual Surgery Room Entry Time: Can only use .dt accessor with datetimelike values
# Skipping Planned Surgery Time_Minutes vs Incision Time: Can only use .dt accessor with datetimelike values
# Skipping Planned Surgery Time_Minutes vs Closure Time: Can only use .dt accessor with datetimelike values
# Skipping Planned Surgery Time_Minutes vs End of Surgery Time (Exit from OR): Can only use .dt accessor with datetimelike values
# Skipping Planned Surgery Time_Minutes vs Recovery Room Entry Time: Can only use .dt accessor with datetimelike values
# Skipping Planned Surgery Time_Minutes vs Recovery Room Exit Time: Can only use .dt accessor with datetimelike values
# Skipping Planned Surgery Time_Minutes vs Post-Surgery Discharge Time: Can only use .dt accessor with datetimelike values
# Skipping Planned Surgery Time_Minutes vs Planned Start Time for Doctor Block: Can only use .dt accessor with datetimelike values
# Skipping Planned Surgery Time_Minutes vs Planned End Time for Doctor Block: Can only use .dt accessor with datetimelike values
# Skipping End of Surgery Date (Exit from OR) vs Planned Surgery Time: Can only use .dt accessor with datetimelike values
# Skipping End of Surgery Date (Exit from OR) vs Administrative Admission Time: Can only use .dt accessor with datetimelike values
# Skipping End of Surgery Date (Exit from OR) vs Pre-Surgery Hospitalization Admission Time: Can only use .dt accessor with datetimelike values
# Skipping End of Surgery Date (Exit from OR) vs Pre-Surgical Admission Time Before Surgery: Can only use .dt accessor with datetimelike values
# Skipping End of Surgery Date (Exit from OR) vs Actual Surgery Room Entry Time: Can only use .dt accessor with datetimelike values
# Skipping End of Surgery Date (Exit from OR) vs Incision Time: Can only use .dt accessor with datetimelike values
# Skipping End of Surgery Date (Exit from OR) vs Closure Time: Can only use .dt accessor with datetimelike values
# Skipping End of Surgery Date (Exit from OR) vs End of Surgery Time (Exit from OR): Can only use .dt accessor with datetimelike values
# Skipping End of Surgery Date (Exit from OR) vs Recovery Room Entry Time: Can only use .dt accessor with datetimelike values
# Skipping End of Surgery Date (Exit from OR) vs Recovery Room Exit Time: Can only use .dt accessor with datetimelike values
# Skipping End of Surgery Date (Exit from OR) vs Post-Surgery Discharge Time: Can only use .dt accessor with datetimelike values
# Skipping End of Surgery Date (Exit from OR) vs Planned Start Time for Doctor Block: Can only use .dt accessor with datetimelike values
# Skipping End of Surgery Date (Exit from OR) vs Planned End Time for Doctor Block: Can only use .dt accessor with datetimelike values
# Skipping Actual Surgery Room Entry Date vs Planned Surgery Time: Can only use .dt accessor with datetimelike values
# Skipping Actual Surgery Room Entry Date vs Administrative Admission Time: Can only use .dt accessor with datetimelike values
# Skipping Actual Surgery Room Entry Date vs Pre-Surgery Hospitalization Admission Time: Can only use .dt accessor with datetimelike values
# Skipping Actual Surgery Room Entry Date vs Pre-Surgical Admission Time Before Surgery: Can only use .dt accessor with datetimelike values
# Skipping Actual Surgery Room Entry Date vs Actual Surgery Room Entry Time: Can only use .dt accessor with datetimelike values
# Skipping Actual Surgery Room Entry Date vs Incision Time: Can only use .dt accessor with datetimelike values
# Skipping Actual Surgery Room Entry Date vs Closure Time: Can only use .dt accessor with datetimelike values
# Skipping Actual Surgery Room Entry Date vs End of Surgery Time (Exit from OR): Can only use .dt accessor with datetimelike values
# Skipping Actual Surgery Room Entry Date vs Recovery Room Entry Time: Can only use .dt accessor with datetimelike values
# Skipping Actual Surgery Room Entry Date vs Recovery Room Exit Time: Can only use .dt accessor with datetimelike values
# Skipping Actual Surgery Room Entry Date vs Post-Surgery Discharge Time: Can only use .dt accessor with datetimelike values
# Skipping Actual Surgery Room Entry Date vs Planned Start Time for Doctor Block: Can only use .dt accessor with datetimelike values
# Skipping Actual Surgery Room Entry Date vs Planned End Time for Doctor Block: Can only use .dt accessor with datetimelike values
# Skipping Pre-Surgery Hospitalization Admission Time vs Planned Surgery Time: Can only use .dt accessor with datetimelike values
# Skipping Pre-Surgery Hospitalization Admission Time vs Administrative Admission Time: Can only use .dt accessor with datetimelike values
# Skipping Pre-Surgery Hospitalization Admission Time vs Pre-Surgical Admission Time Before Surgery: Can only use .dt accessor with datetimelike values
# Skipping Pre-Surgery Hospitalization Admission Time vs Actual Surgery Room Entry Time: Can only use .dt accessor with datetimelike values
# Skipping Pre-Surgery Hospitalization Admission Time vs Incision Time: Can only use .dt accessor with datetimelike values
# Skipping Pre-Surgery Hospitalization Admission Time vs Closure Time: Can only use .dt accessor with datetimelike values
# Skipping Pre-Surgery Hospitalization Admission Time vs End of Surgery Time (Exit from OR): Can only use .dt accessor with datetimelike values
# Skipping Pre-Surgery Hospitalization Admission Time vs Recovery Room Entry Time: Can only use .dt accessor with datetimelike values
# Skipping Pre-Surgery Hospitalization Admission Time vs Recovery Room Exit Time: Can only use .dt accessor with datetimelike values
# Skipping Pre-Surgery Hospitalization Admission Time vs Post-Surgery Discharge Time: Can only use .dt accessor with datetimelike values
# Skipping Pre-Surgery Hospitalization Admission Time vs Planned Start Time for Doctor Block: Can only use .dt accessor with datetimelike values
# Skipping Pre-Surgery Hospitalization Admission Time vs Planned End Time for Doctor Block: Can only use .dt accessor with datetimelike values
# Skipping Pre-Surgery Hospitalization Admission Time_Minutes vs Planned Surgery Time: Can only use .dt accessor with datetimelike values
# Skipping Pre-Surgery Hospitalization Admission Time_Minutes vs Administrative Admission Time: Can only use .dt accessor with datetimelike values
# Skipping Pre-Surgery Hospitalization Admission Time_Minutes vs Pre-Surgery Hospitalization Admission Time: Can only use .dt accessor with datetimelike values
# Skipping Pre-Surgery Hospitalization Admission Time_Minutes vs Pre-Surgical Admission Time Before Surgery: Can only use .dt accessor with datetimelike values
# Skipping Pre-Surgery Hospitalization Admission Time_Minutes vs Actual Surgery Room Entry Time: Can only use .dt accessor with datetimelike values
# Skipping Pre-Surgery Hospitalization Admission Time_Minutes vs Incision Time: Can only use .dt accessor with datetimelike values
# Skipping Pre-Surgery Hospitalization Admission Time_Minutes vs Closure Time: Can only use .dt accessor with datetimelike values
# Skipping Pre-Surgery Hospitalization Admission Time_Minutes vs End of Surgery Time (Exit from OR): Can only use .dt accessor with datetimelike values
# Skipping Pre-Surgery Hospitalization Admission Time_Minutes vs Recovery Room Entry Time: Can only use .dt accessor with datetimelike values
# Skipping Pre-Surgery Hospitalization Admission Time_Minutes vs Recovery Room Exit Time: Can only use .dt accessor with datetimelike values
# Skipping Pre-Surgery Hospitalization Admission Time_Minutes vs Post-Surgery Discharge Time: Can only use .dt accessor with datetimelike values
# Skipping Pre-Surgery Hospitalization Admission Time_Minutes vs Planned Start Time for Doctor Block: Can only use .dt accessor with datetimelike values
# Skipping Pre-Surgery Hospitalization Admission Time_Minutes vs Planned End Time for Doctor Block: Can only use .dt accessor with datetimelike values
# Skipping Pre-Surgery Hospitalization Admission Date vs Planned Surgery Time: Can only use .dt accessor with datetimelike values
# Skipping Pre-Surgery Hospitalization Admission Date vs Administrative Admission Time: Can only use .dt accessor with datetimelike values
# Skipping Pre-Surgery Hospitalization Admission Date vs Pre-Surgery Hospitalization Admission Time: Can only use .dt accessor with datetimelike values
# Skipping Pre-Surgery Hospitalization Admission Date vs Pre-Surgical Admission Time Before Surgery: Can only use .dt accessor with datetimelike values
# Skipping Pre-Surgery Hospitalization Admission Date vs Actual Surgery Room Entry Time: Can only use .dt accessor with datetimelike values
# Skipping Pre-Surgery Hospitalization Admission Date vs Incision Time: Can only use .dt accessor with datetimelike values
# Skipping Pre-Surgery Hospitalization Admission Date vs Closure Time: Can only use .dt accessor with datetimelike values
# Skipping Pre-Surgery Hospitalization Admission Date vs End of Surgery Time (Exit from OR): Can only use .dt accessor with datetimelike values
# Skipping Pre-Surgery Hospitalization Admission Date vs Recovery Room Entry Time: Can only use .dt accessor with datetimelike values
# Skipping Pre-Surgery Hospitalization Admission Date vs Recovery Room Exit Time: Can only use .dt accessor with datetimelike values
# Skipping Pre-Surgery Hospitalization Admission Date vs Post-Surgery Discharge Time: Can only use .dt accessor with datetimelike values
# Skipping Pre-Surgery Hospitalization Admission Date vs Planned Start Time for Doctor Block: Can only use .dt accessor with datetimelike values
# Skipping Pre-Surgery Hospitalization Admission Date vs Planned End Time for Doctor Block: Can only use .dt accessor with datetimelike values
# Skipping Post-Surgery Discharge Time_Minutes vs Planned Surgery Time: Can only use .dt accessor with datetimelike values
# Skipping Post-Surgery Discharge Time_Minutes vs Administrative Admission Time: Can only use .dt accessor with datetimelike values
# Skipping Post-Surgery Discharge Time_Minutes vs Pre-Surgery Hospitalization Admission Time: Can only use .dt accessor with datetimelike values
# Skipping Post-Surgery Discharge Time_Minutes vs Pre-Surgical Admission Time Before Surgery: Can only use .dt accessor with datetimelike values
# Skipping Post-Surgery Discharge Time_Minutes vs Actual Surgery Room Entry Time: Can only use .dt accessor with datetimelike values
# Skipping Post-Surgery Discharge Time_Minutes vs Incision Time: Can only use .dt accessor with datetimelike values
# Skipping Post-Surgery Discharge Time_Minutes vs Closure Time: Can only use .dt accessor with datetimelike values
# Skipping Post-Surgery Discharge Time_Minutes vs End of Surgery Time (Exit from OR): Can only use .dt accessor with datetimelike values
# Skipping Post-Surgery Discharge Time_Minutes vs Recovery Room Entry Time: Can only use .dt accessor with datetimelike values
# Skipping Post-Surgery Discharge Time_Minutes vs Recovery Room Exit Time: Can only use .dt accessor with datetimelike values
# Skipping Post-Surgery Discharge Time_Minutes vs Post-Surgery Discharge Time: Can only use .dt accessor with datetimelike values
# Skipping Post-Surgery Discharge Time_Minutes vs Planned Start Time for Doctor Block: Can only use .dt accessor with datetimelike values
# Skipping Post-Surgery Discharge Time_Minutes vs Planned End Time for Doctor Block: Can only use .dt accessor with datetimelike values
# Skipping Post-Surgery Discharge Date vs Planned Surgery Time: Can only use .dt accessor with datetimelike values
# Skipping Post-Surgery Discharge Date vs Administrative Admission Time: Can only use .dt accessor with datetimelike values
# Skipping Post-Surgery Discharge Date vs Pre-Surgery Hospitalization Admission Time: Can only use .dt accessor with datetimelike values
# Skipping Post-Surgery Discharge Date vs Pre-Surgical Admission Time Before Surgery: Can only use .dt accessor with datetimelike values
# Skipping Post-Surgery Discharge Date vs Actual Surgery Room Entry Time: Can only use .dt accessor with datetimelike values
# Skipping Post-Surgery Discharge Date vs Incision Time: Can only use .dt accessor with datetimelike values
# Skipping Post-Surgery Discharge Date vs Closure Time: Can only use .dt accessor with datetimelike values
# Skipping Post-Surgery Discharge Date vs End of Surgery Time (Exit from OR): Can only use .dt accessor with datetimelike values
# Skipping Post-Surgery Discharge Date vs Recovery Room Entry Time: Can only use .dt accessor with datetimelike values
# Skipping Post-Surgery Discharge Date vs Recovery Room Exit Time: Can only use .dt accessor with datetimelike values
# Skipping Post-Surgery Discharge Date vs Post-Surgery Discharge Time: Can only use .dt accessor with datetimelike values
# Skipping Post-Surgery Discharge Date vs Planned Start Time for Doctor Block: Can only use .dt accessor with datetimelike values
# Skipping Post-Surgery Discharge Date vs Planned End Time for Doctor Block: Can only use .dt accessor with datetimelike values
# Skipping Post-Surgery Discharge Time vs Planned Surgery Time: Can only use .dt accessor with datetimelike values
# Skipping Post-Surgery Discharge Time vs Administrative Admission Time: Can only use .dt accessor with datetimelike values
# Skipping Post-Surgery Discharge Time vs Pre-Surgery Hospitalization Admission Time: Can only use .dt accessor with datetimelike values
# Skipping Post-Surgery Discharge Time vs Pre-Surgical Admission Time Before Surgery: Can only use .dt accessor with datetimelike values
# Skipping Post-Surgery Discharge Time vs Actual Surgery Room Entry Time: Can only use .dt accessor with datetimelike values
# Skipping Post-Surgery Discharge Time vs Incision Time: Can only use .dt accessor with datetimelike values
# Skipping Post-Surgery Discharge Time vs Closure Time: Can only use .dt accessor with datetimelike values
# Skipping Post-Surgery Discharge Time vs End of Surgery Time (Exit from OR): Can only use .dt accessor with datetimelike values
# Skipping Post-Surgery Discharge Time vs Recovery Room Entry Time: Can only use .dt accessor with datetimelike values
# Skipping Post-Surgery Discharge Time vs Recovery Room Exit Time: Can only use .dt accessor with datetimelike values
# Skipping Post-Surgery Discharge Time vs Planned Start Time for Doctor Block: Can only use .dt accessor with datetimelike values
# Skipping Post-Surgery Discharge Time vs Planned End Time for Doctor Block: Can only use .dt accessor with datetimelike values
# Skipping Closure Time vs Planned Surgery Time: Can only use .dt accessor with datetimelike values
# Skipping Closure Time vs Administrative Admission Time: Can only use .dt accessor with datetimelike values
# Skipping Closure Time vs Pre-Surgery Hospitalization Admission Time: Can only use .dt accessor with datetimelike values
# Skipping Closure Time vs Pre-Surgical Admission Time Before Surgery: Can only use .dt accessor with datetimelike values
# Skipping Closure Time vs Actual Surgery Room Entry Time: Can only use .dt accessor with datetimelike values
# Skipping Closure Time vs Incision Time: Can only use .dt accessor with datetimelike values
# Skipping Closure Time vs End of Surgery Time (Exit from OR): Can only use .dt accessor with datetimelike values
# Skipping Closure Time vs Recovery Room Entry Time: Can only use .dt accessor with datetimelike values
# Skipping Closure Time vs Recovery Room Exit Time: Can only use .dt accessor with datetimelike values
# Skipping Closure Time vs Post-Surgery Discharge Time: Can only use .dt accessor with datetimelike values
# Skipping Closure Time vs Planned Start Time for Doctor Block: Can only use .dt accessor with datetimelike values
# Skipping Closure Time vs Planned End Time for Doctor Block: Can only use .dt accessor with datetimelike values
# Skipping Incision Time vs Planned Surgery Time: Can only use .dt accessor with datetimelike values
# Skipping Incision Time vs Administrative Admission Time: Can only use .dt accessor with datetimelike values
# Skipping Incision Time vs Pre-Surgery Hospitalization Admission Time: Can only use .dt accessor with datetimelike values
# Skipping Incision Time vs Pre-Surgical Admission Time Before Surgery: Can only use .dt accessor with datetimelike values
# Skipping Incision Time vs Actual Surgery Room Entry Time: Can only use .dt accessor with datetimelike values
# Skipping Incision Time vs Closure Time: Can only use .dt accessor with datetimelike values
# Skipping Incision Time vs End of Surgery Time (Exit from OR): Can only use .dt accessor with datetimelike values
# Skipping Incision Time vs Recovery Room Entry Time: Can only use .dt accessor with datetimelike values
# Skipping Incision Time vs Recovery Room Exit Time: Can only use .dt accessor with datetimelike values
# Skipping Incision Time vs Post-Surgery Discharge Time: Can only use .dt accessor with datetimelike values
# Skipping Incision Time vs Planned Start Time for Doctor Block: Can only use .dt accessor with datetimelike values
# Skipping Incision Time vs Planned End Time for Doctor Block: Can only use .dt accessor with datetimelike values
# Skipping Incision Time_Minutes vs Planned Surgery Time: Can only use .dt accessor with datetimelike values
# Skipping Incision Time_Minutes vs Administrative Admission Time: Can only use .dt accessor with datetimelike values
# Skipping Incision Time_Minutes vs Pre-Surgery Hospitalization Admission Time: Can only use .dt accessor with datetimelike values
# Skipping Incision Time_Minutes vs Pre-Surgical Admission Time Before Surgery: Can only use .dt accessor with datetimelike values
# Skipping Incision Time_Minutes vs Actual Surgery Room Entry Time: Can only use .dt accessor with datetimelike values
# Skipping Incision Time_Minutes vs Incision Time: Can only use .dt accessor with datetimelike values
# Skipping Incision Time_Minutes vs Closure Time: Can only use .dt accessor with datetimelike values
# Skipping Incision Time_Minutes vs End of Surgery Time (Exit from OR): Can only use .dt accessor with datetimelike values
# Skipping Incision Time_Minutes vs Recovery Room Entry Time: Can only use .dt accessor with datetimelike values
# Skipping Incision Time_Minutes vs Recovery Room Exit Time: Can only use .dt accessor with datetimelike values
# Skipping Incision Time_Minutes vs Post-Surgery Discharge Time: Can only use .dt accessor with datetimelike values
# Skipping Incision Time_Minutes vs Planned Start Time for Doctor Block: Can only use .dt accessor with datetimelike values
# Skipping Incision Time_Minutes vs Planned End Time for Doctor Block: Can only use .dt accessor with datetimelike values
# Skipping Closure Time_Minutes vs Planned Surgery Time: Can only use .dt accessor with datetimelike values
# Skipping Closure Time_Minutes vs Administrative Admission Time: Can only use .dt accessor with datetimelike values
# Skipping Closure Time_Minutes vs Pre-Surgery Hospitalization Admission Time: Can only use .dt accessor with datetimelike values
# Skipping Closure Time_Minutes vs Pre-Surgical Admission Time Before Surgery: Can only use .dt accessor with datetimelike values
# Skipping Closure Time_Minutes vs Actual Surgery Room Entry Time: Can only use .dt accessor with datetimelike values
# Skipping Closure Time_Minutes vs Incision Time: Can only use .dt accessor with datetimelike values
# Skipping Closure Time_Minutes vs Closure Time: Can only use .dt accessor with datetimelike values
# Skipping Closure Time_Minutes vs End of Surgery Time (Exit from OR): Can only use .dt accessor with datetimelike values
# Skipping Closure Time_Minutes vs Recovery Room Entry Time: Can only use .dt accessor with datetimelike values
# Skipping Closure Time_Minutes vs Recovery Room Exit Time: Can only use .dt accessor with datetimelike values
# Skipping Closure Time_Minutes vs Post-Surgery Discharge Time: Can only use .dt accessor with datetimelike values
# Skipping Closure Time_Minutes vs Planned Start Time for Doctor Block: Can only use .dt accessor with datetimelike values
# Skipping Closure Time_Minutes vs Planned End Time for Doctor Block: Can only use .dt accessor with datetimelike values
# Skipping Surgery Admission Date vs Planned Surgery Time: Can only use .dt accessor with datetimelike values
# Skipping Surgery Admission Date vs Administrative Admission Time: Can only use .dt accessor with datetimelike values
# Skipping Surgery Admission Date vs Pre-Surgery Hospitalization Admission Time: Can only use .dt accessor with datetimelike values
# Skipping Surgery Admission Date vs Pre-Surgical Admission Time Before Surgery: Can only use .dt accessor with datetimelike values
# Skipping Surgery Admission Date vs Actual Surgery Room Entry Time: Can only use .dt accessor with datetimelike values
# Skipping Surgery Admission Date vs Incision Time: Can only use .dt accessor with datetimelike values
# Skipping Surgery Admission Date vs Closure Time: Can only use .dt accessor with datetimelike values
# Skipping Surgery Admission Date vs End of Surgery Time (Exit from OR): Can only use .dt accessor with datetimelike values
# Skipping Surgery Admission Date vs Recovery Room Entry Time: Can only use .dt accessor with datetimelike values
# Skipping Surgery Admission Date vs Recovery Room Exit Time: Can only use .dt accessor with datetimelike values
# Skipping Surgery Admission Date vs Post-Surgery Discharge Time: Can only use .dt accessor with datetimelike values
# Skipping Surgery Admission Date vs Planned Start Time for Doctor Block: Can only use .dt accessor with datetimelike values
# Skipping Surgery Admission Date vs Planned End Time for Doctor Block: Can only use .dt accessor with datetimelike values
# Skipping Administrative Admission Time vs Planned Surgery Time: Can only use .dt accessor with datetimelike values
# Skipping Administrative Admission Time vs Pre-Surgery Hospitalization Admission Time: Can only use .dt accessor with datetimelike values
# Skipping Administrative Admission Time vs Pre-Surgical Admission Time Before Surgery: Can only use .dt accessor with datetimelike values
# Skipping Administrative Admission Time vs Actual Surgery Room Entry Time: Can only use .dt accessor with datetimelike values
# Skipping Administrative Admission Time vs Incision Time: Can only use .dt accessor with datetimelike values
# Skipping Administrative Admission Time vs Closure Time: Can only use .dt accessor with datetimelike values
# Skipping Administrative Admission Time vs End of Surgery Time (Exit from OR): Can only use .dt accessor with datetimelike values
# Skipping Administrative Admission Time vs Recovery Room Entry Time: Can only use .dt accessor with datetimelike values
# Skipping Administrative Admission Time vs Recovery Room Exit Time: Can only use .dt accessor with datetimelike values
# Skipping Administrative Admission Time vs Post-Surgery Discharge Time: Can only use .dt accessor with datetimelike values
# Skipping Administrative Admission Time vs Planned Start Time for Doctor Block: Can only use .dt accessor with datetimelike values
# Skipping Administrative Admission Time vs Planned End Time for Doctor Block: Can only use .dt accessor with datetimelike values
# Skipping Administrative Admission Time_Minutes vs Planned Surgery Time: Can only use .dt accessor with datetimelike values
# Skipping Administrative Admission Time_Minutes vs Administrative Admission Time: Can only use .dt accessor with datetimelike values
# Skipping Administrative Admission Time_Minutes vs Pre-Surgery Hospitalization Admission Time: Can only use .dt accessor with datetimelike values
# Skipping Administrative Admission Time_Minutes vs Pre-Surgical Admission Time Before Surgery: Can only use .dt accessor with datetimelike values
# Skipping Administrative Admission Time_Minutes vs Actual Surgery Room Entry Time: Can only use .dt accessor with datetimelike values
# Skipping Administrative Admission Time_Minutes vs Incision Time: Can only use .dt accessor with datetimelike values
# Skipping Administrative Admission Time_Minutes vs Closure Time: Can only use .dt accessor with datetimelike values
# Skipping Administrative Admission Time_Minutes vs End of Surgery Time (Exit from OR): Can only use .dt accessor with datetimelike values
# Skipping Administrative Admission Time_Minutes vs Recovery Room Entry Time: Can only use .dt accessor with datetimelike values
# Skipping Administrative Admission Time_Minutes vs Recovery Room Exit Time: Can only use .dt accessor with datetimelike values
# Skipping Administrative Admission Time_Minutes vs Post-Surgery Discharge Time: Can only use .dt accessor with datetimelike values
# Skipping Administrative Admission Time_Minutes vs Planned Start Time for Doctor Block: Can only use .dt accessor with datetimelike values
# Skipping Administrative Admission Time_Minutes vs Planned End Time for Doctor Block: Can only use .dt accessor with datetimelike values

# %%
p_values
# Out:
# {'Pre-Surgical Admission Time Before Surgery': {'patient_id': np.float64(0.4977598031241225),
#   'Site Code': 1.0,
#   'Main Surgeon Code': np.float64(0.0),
#   'Activity Code': np.float64(0.0),
#   'Activity Type Code': np.float64(0.0),
#   'Planned SU Time (Large/Medium/Small)': np.float64(0.0),
#   'Pre-Surgery Patient File (External)': np.float64(1.0),
#   'Pre-Surgery Admission Date': np.float64(1.0),
#   'Height': np.float64(1.3979976881333238e-304),
#   'Weight': np.float64(1.1151657269711324e-169),
#   'Patient Age (on Surgery Day)': np.float64(2.2319104593879386e-28),
#   'Background Diseases/Diagnoses': np.float64(0.0),
#   'Planned Surgery Date': np.float64(1.0),
#   'Surgery Admission Date': np.float64(1.0),
#   'Planned Operating Room Number': np.float64(0.0),
#   'Pre-Surgery Hospitalization Admission Date': np.float64(1.0),
#   'Surgical Team Codes': np.float64(0.0),
#   'Anesthesiologist Code': np.float64(0.0),
#   'Anesthesia Code': np.float64(0.0),
#   'Type of Anesthesia': np.float64(0.0),
#   'Cancellation Reason on Surgery Day': 1.0,
#   'Actual Operating Room Number': np.float64(0.0),
#   'Actual Surgery Room Entry Date': np.float64(1.0),
#   'End of Surgery Date (Exit from OR)': np.float64(1.0),
#   'Planned Surgery Duration': np.float64(4.020008505566614e-66),
#   'Recovery Room Entry Date': np.float64(1.0),
#   'Recovery Room Exit Date': np.float64(1.0),
#   'Post-Surgery Discharge Date': np.float64(1.0),
#   'Planned Start Date for Doctor Block': np.float64(1.0),
#   'Planned End Date for Doctor Block': np.float64(1.0),
#   'Readmission': 1.0,
#   'strict_signature': np.float64(0.4977598031241225),
#   'No Show': np.float64(1.5592167368873965e-21),
#   'Entry DateTime': np.float64(1.7114029196374967e-54),
#   'Incision DateTime': np.float64(1.838298225235904e-50),
#   'Closure DateTime': np.float64(2.536937473605442e-20),
#   'Exit DateTime': np.float64(0.9999999999999967),
#   'Planned Surgery Time_Minutes': np.float64(3.331585723850361e-28),
#   'Administrative Admission Time_Minutes': np.float64(4.058836805330895e-36),
#   'Pre-Surgery Hospitalization Admission Time_Minutes': np.float64(4.63819451260102e-67),
#   'Pre-Surgical Admission Time Before Surgery_Minutes': np.float64(1.0),
#   'Actual Surgery Room Entry Time_Minutes': np.float64(1.6439025252532018e-32),
#   'Incision Time_Minutes': np.float64(2.1154451826934482e-36),
#   'Closure Time_Minutes': np.float64(5.3616880674098315e-49),
#   'End of Surgery Time (Exit from OR)_Minutes': np.float64(3.553740763528889e-49),
#   'Recovery Room Entry Time_Minutes': np.float64(1.2130265272902676e-58),
#   'Recovery Room Exit Time_Minutes': np.float64(4.2862149039594734e-44),
#   'Post-Surgery Discharge Time_Minutes': np.float64(4.2551168336402944e-12),
#   'Planned Start Time for Doctor Block_Minutes': np.float64(4.541191489101631e-77),
#   'Planned End Time for Doctor Block_Minutes': np.float64(1.8302350210360632e-14)},
#  'Pre-Surgical Admission Time Before Surgery_Minutes': {'patient_id': np.float64(0.4977598031241225),
#   'Site Code': 1.0,
#   'Main Surgeon Code': np.float64(0.0),
#   'Activity Code': np.float64(0.0),
#   'Activity Type Code': np.float64(0.0),
#   'Planned SU Time (Large/Medium/Small)': np.float64(0.0),
#   'Pre-Surgery Patient File (External)': np.float64(1.0),
#   'Pre-Surgery Admission Date': np.float64(1.0),
#   'Height': np.float64(1.3979976881333238e-304),
#   'Weight': np.float64(1.1151657269711324e-169),
#   'Patient Age (on Surgery Day)': np.float64(2.2319104593879386e-28),
#   'Background Diseases/Diagnoses': np.float64(0.0),
#   'Planned Surgery Date': np.float64(1.0),
#   'Surgery Admission Date': np.float64(1.0),
#   'Planned Operating Room Number': np.float64(0.0),
#   'Pre-Surgery Hospitalization Admission Date': np.float64(1.0),
#   'Surgical Team Codes': np.float64(0.0),
#   'Anesthesiologist Code': np.float64(0.0),
#   'Anesthesia Code': np.float64(0.0),
#   'Type of Anesthesia': np.float64(0.0),
#   'Cancellation Reason on Surgery Day': 1.0,
#   'Actual Operating Room Number': np.float64(0.0),
#   'Actual Surgery Room Entry Date': np.float64(1.0),
#   'End of Surgery Date (Exit from OR)': np.float64(1.0),
#   'Planned Surgery Duration': np.float64(4.020008505566614e-66),
#   'Recovery Room Entry Date': np.float64(1.0),
#   'Recovery Room Exit Date': np.float64(1.0),
#   'Post-Surgery Discharge Date': np.float64(1.0),
#   'Planned Start Date for Doctor Block': np.float64(1.0),
#   'Planned End Date for Doctor Block': np.float64(1.0),
#   'Readmission': 1.0,
#   'strict_signature': np.float64(0.4977598031241225),
#   'No Show': np.float64(1.5592167368873965e-21),
#   'Entry DateTime': np.float64(1.7114029196374967e-54),
#   'Incision DateTime': np.float64(1.838298225235904e-50),
#   'Closure DateTime': np.float64(2.536937473605442e-20),
#   'Exit DateTime': np.float64(0.9999999999999967),
#   'Planned Surgery Time_Minutes': np.float64(3.331585723850361e-28),
#   'Administrative Admission Time_Minutes': np.float64(4.058836805330895e-36),
#   'Pre-Surgery Hospitalization Admission Time_Minutes': np.float64(4.63819451260102e-67),
#   'Actual Surgery Room Entry Time_Minutes': np.float64(1.6439025252532018e-32),
#   'Incision Time_Minutes': np.float64(2.1154451826934482e-36),
#   'Closure Time_Minutes': np.float64(5.3616880674098315e-49),
#   'End of Surgery Time (Exit from OR)_Minutes': np.float64(3.553740763528889e-49),
#   'Recovery Room Entry Time_Minutes': np.float64(1.2130265272902676e-58),
#   'Recovery Room Exit Time_Minutes': np.float64(4.2862149039594734e-44),
#   'Post-Surgery Discharge Time_Minutes': np.float64(4.2551168336402944e-12),
#   'Planned Start Time for Doctor Block_Minutes': np.float64(4.541191489101631e-77),
#   'Planned End Time for Doctor Block_Minutes': np.float64(1.8302350210360632e-14)},
#  'Recovery Room Entry Date': {'patient_id': np.float64(0.49775980312413226),
#   'Site Code': 1.0,
#   'Main Surgeon Code': np.float64(0.0),
#   'Activity Code': np.float64(0.0),
#   'Activity Type Code': np.float64(0.0),
#   'Planned SU Time (Large/Medium/Small)': np.float64(0.0),
#   'Pre-Surgery Patient File (External)': np.float64(1.0),
#   'Pre-Surgery Admission Date': np.float64(1.0),
#   'Height': np.float64(1.11665198631627e-15),
#   'Weight': np.float64(4.1783269818748486e-15),
#   'Patient Age (on Surgery Day)': np.float64(8.793973305983407e-112),
#   'Background Diseases/Diagnoses': np.float64(0.0),
#   'Planned Surgery Date': np.float64(1.0),
#   'Surgery Admission Date': np.float64(1.0),
#   'Planned Operating Room Number': np.float64(0.0),
#   'Pre-Surgery Hospitalization Admission Date': np.float64(1.0),
#   'Surgical Team Codes': np.float64(0.0),
#   'Anesthesiologist Code': np.float64(0.0),
#   'Anesthesia Code': np.float64(0.0),
#   'Type of Anesthesia': np.float64(0.0),
#   'Cancellation Reason on Surgery Day': 1.0,
#   'Actual Operating Room Number': np.float64(0.0),
#   'Actual Surgery Room Entry Date': np.float64(1.0),
#   'End of Surgery Date (Exit from OR)': np.float64(1.0),
#   'Planned Surgery Duration': np.float64(6.972134386285479e-21),
#   'Recovery Room Exit Date': np.float64(1.0),
#   'Post-Surgery Discharge Date': np.float64(1.0),
#   'Planned Start Date for Doctor Block': np.float64(1.0),
#   'Planned End Date for Doctor Block': np.float64(1.0),
#   'Readmission': 1.0,
#   'strict_signature': np.float64(0.49775980312414203),
#   'No Show': np.float64(1.307907404883444e-43),
#   'Entry DateTime': np.float64(0.01620713865427624),
#   'Incision DateTime': np.float64(0.005622307985773995),
#   'Closure DateTime': np.float64(0.9999999999957887),
#   'Exit DateTime': np.float64(1.0),
#   'Planned Surgery Time_Minutes': np.float64(6.559550819351574e-05),
#   'Administrative Admission Time_Minutes': np.float64(5.6991495678269315e-08),
#   'Pre-Surgery Hospitalization Admission Time_Minutes': np.float64(4.705733364796778e-07),
#   'Pre-Surgical Admission Time Before Surgery_Minutes': np.float64(0.5855264802132218),
#   'Actual Surgery Room Entry Time_Minutes': np.float64(0.13584463484240683),
#   'Incision Time_Minutes': np.float64(2.5379685139005804e-09),
#   'Closure Time_Minutes': np.float64(9.207276192485209e-10),
#   'End of Surgery Time (Exit from OR)_Minutes': np.float64(0.2630496718939769),
#   'Recovery Room Entry Time_Minutes': np.float64(1.0),
#   'Recovery Room Exit Time_Minutes': np.float64(1.0),
#   'Post-Surgery Discharge Time_Minutes': np.float64(0.0006571643307587503),
#   'Planned Start Time for Doctor Block_Minutes': np.float64(2.732937998568539e-06),
#   'Planned End Time for Doctor Block_Minutes': np.float64(2.160207037402018e-13)},
#  'Recovery Room Exit Time': {'patient_id': np.float64(0.49775980312413226),
#   'Site Code': 1.0,
#   'Main Surgeon Code': np.float64(0.0),
#   'Activity Code': np.float64(0.0),
#   'Activity Type Code': np.float64(0.0),
#   'Planned SU Time (Large/Medium/Small)': np.float64(0.0),
#   'Pre-Surgery Patient File (External)': np.float64(1.0),
#   'Pre-Surgery Admission Date': np.float64(1.0),
#   'Height': np.float64(1.11665198631627e-15),
#   'Weight': np.float64(4.1783269818748486e-15),
#   'Patient Age (on Surgery Day)': np.float64(8.793973305983407e-112),
#   'Background Diseases/Diagnoses': np.float64(0.0),
#   'Planned Surgery Date': np.float64(1.0),
#   'Surgery Admission Date': np.float64(1.0),
#   'Planned Operating Room Number': np.float64(0.0),
#   'Pre-Surgery Hospitalization Admission Date': np.float64(1.0),
#   'Surgical Team Codes': np.float64(0.0),
#   'Anesthesiologist Code': np.float64(0.0),
#   'Anesthesia Code': np.float64(0.0),
#   'Type of Anesthesia': np.float64(0.0),
#   'Cancellation Reason on Surgery Day': 1.0,
#   'Actual Operating Room Number': np.float64(0.0),
#   'Actual Surgery Room Entry Date': np.float64(1.0),
#   'End of Surgery Date (Exit from OR)': np.float64(1.0),
#   'Planned Surgery Duration': np.float64(6.972134386285479e-21),
#   'Recovery Room Entry Date': np.float64(1.0),
#   'Recovery Room Exit Date': np.float64(1.0),
#   'Post-Surgery Discharge Date': np.float64(1.0),
#   'Planned Start Date for Doctor Block': np.float64(1.0),
#   'Planned End Date for Doctor Block': np.float64(1.0),
#   'Readmission': 1.0,
#   'strict_signature': np.float64(0.49775980312414203),
#   'No Show': np.float64(1.307907404883444e-43),
#   'Entry DateTime': np.float64(0.01620713865427624),
#   'Incision DateTime': np.float64(0.005622307985773995),
#   'Closure DateTime': np.float64(0.9999999999957887),
#   'Exit DateTime': np.float64(1.0),
#   'Planned Surgery Time_Minutes': np.float64(6.559550819351574e-05),
#   'Administrative Admission Time_Minutes': np.float64(5.6991495678269315e-08),
#   'Pre-Surgery Hospitalization Admission Time_Minutes': np.float64(4.705733364796778e-07),
#   'Pre-Surgical Admission Time Before Surgery_Minutes': np.float64(0.5855264802132218),
#   'Actual Surgery Room Entry Time_Minutes': np.float64(0.13584463484240683),
#   'Incision Time_Minutes': np.float64(2.5379685139005804e-09),
#   'Closure Time_Minutes': np.float64(9.207276192485209e-10),
#   'End of Surgery Time (Exit from OR)_Minutes': np.float64(0.2630496718939769),
#   'Recovery Room Entry Time_Minutes': np.float64(1.0),
#   'Recovery Room Exit Time_Minutes': np.float64(1.0),
#   'Post-Surgery Discharge Time_Minutes': np.float64(0.0006571643307587503),
#   'Planned Start Time for Doctor Block_Minutes': np.float64(2.732937998568539e-06),
#   'Planned End Time for Doctor Block_Minutes': np.float64(2.160207037402018e-13)},
#  'Recovery Room Entry Time': {'patient_id': np.float64(0.49775980312413226),
#   'Site Code': 1.0,
#   'Main Surgeon Code': np.float64(0.0),
#   'Activity Code': np.float64(0.0),
#   'Activity Type Code': np.float64(0.0),
#   'Planned SU Time (Large/Medium/Small)': np.float64(0.0),
#   'Pre-Surgery Patient File (External)': np.float64(1.0),
#   'Pre-Surgery Admission Date': np.float64(1.0),
#   'Height': np.float64(1.11665198631627e-15),
#   'Weight': np.float64(4.1783269818748486e-15),
#   'Patient Age (on Surgery Day)': np.float64(8.793973305983407e-112),
#   'Background Diseases/Diagnoses': np.float64(0.0),
#   'Planned Surgery Date': np.float64(1.0),
#   'Surgery Admission Date': np.float64(1.0),
#   'Planned Operating Room Number': np.float64(0.0),
#   'Pre-Surgery Hospitalization Admission Date': np.float64(1.0),
#   'Surgical Team Codes': np.float64(0.0),
#   'Anesthesiologist Code': np.float64(0.0),
#   'Anesthesia Code': np.float64(0.0),
#   'Type of Anesthesia': np.float64(0.0),
#   'Cancellation Reason on Surgery Day': 1.0,
#   'Actual Operating Room Number': np.float64(0.0),
#   'Actual Surgery Room Entry Date': np.float64(1.0),
#   'End of Surgery Date (Exit from OR)': np.float64(1.0),
#   'Planned Surgery Duration': np.float64(6.972134386285479e-21),
#   'Recovery Room Entry Date': np.float64(1.0),
#   'Recovery Room Exit Date': np.float64(1.0),
#   'Post-Surgery Discharge Date': np.float64(1.0),
#   'Planned Start Date for Doctor Block': np.float64(1.0),
#   'Planned End Date for Doctor Block': np.float64(1.0),
#   'Readmission': 1.0,
#   'strict_signature': np.float64(0.49775980312414203),
#   'No Show': np.float64(1.307907404883444e-43),
#   'Entry DateTime': np.float64(0.01620713865427624),
#   'Incision DateTime': np.float64(0.005622307985773995),
#   'Closure DateTime': np.float64(0.9999999999957887),
#   'Exit DateTime': np.float64(1.0),
#   'Planned Surgery Time_Minutes': np.float64(6.559550819351574e-05),
#   'Administrative Admission Time_Minutes': np.float64(5.6991495678269315e-08),
#   'Pre-Surgery Hospitalization Admission Time_Minutes': np.float64(4.705733364796778e-07),
#   'Pre-Surgical Admission Time Before Surgery_Minutes': np.float64(0.5855264802132218),
#   'Actual Surgery Room Entry Time_Minutes': np.float64(0.13584463484240683),
#   'Incision Time_Minutes': np.float64(2.5379685139005804e-09),
#   'Closure Time_Minutes': np.float64(9.207276192485209e-10),
#   'End of Surgery Time (Exit from OR)_Minutes': np.float64(0.2630496718939769),
#   'Recovery Room Entry Time_Minutes': np.float64(1.0),
#   'Recovery Room Exit Time_Minutes': np.float64(1.0),
#   'Post-Surgery Discharge Time_Minutes': np.float64(0.0006571643307587503),
#   'Planned Start Time for Doctor Block_Minutes': np.float64(2.732937998568539e-06),
#   'Planned End Time for Doctor Block_Minutes': np.float64(2.160207037402018e-13)},
#  'Recovery Room Entry Time_Minutes': {'patient_id': np.float64(0.49775980312413226),
#   'Site Code': 1.0,
#   'Main Surgeon Code': np.float64(0.0),
#   'Activity Code': np.float64(0.0),
#   'Activity Type Code': np.float64(0.0),
#   'Planned SU Time (Large/Medium/Small)': np.float64(0.0),
#   'Pre-Surgery Patient File (External)': np.float64(1.0),
#   'Pre-Surgery Admission Date': np.float64(1.0),
#   'Height': np.float64(1.11665198631627e-15),
#   'Weight': np.float64(4.1783269818748486e-15),
#   'Patient Age (on Surgery Day)': np.float64(8.793973305983407e-112),
#   'Background Diseases/Diagnoses': np.float64(0.0),
#   'Planned Surgery Date': np.float64(1.0),
#   'Surgery Admission Date': np.float64(1.0),
#   'Planned Operating Room Number': np.float64(0.0),
#   'Pre-Surgery Hospitalization Admission Date': np.float64(1.0),
#   'Surgical Team Codes': np.float64(0.0),
#   'Anesthesiologist Code': np.float64(0.0),
#   'Anesthesia Code': np.float64(0.0),
#   'Type of Anesthesia': np.float64(0.0),
#   'Cancellation Reason on Surgery Day': 1.0,
#   'Actual Operating Room Number': np.float64(0.0),
#   'Actual Surgery Room Entry Date': np.float64(1.0),
#   'End of Surgery Date (Exit from OR)': np.float64(1.0),
#   'Planned Surgery Duration': np.float64(6.972134386285479e-21),
#   'Recovery Room Entry Date': np.float64(1.0),
#   'Recovery Room Exit Date': np.float64(1.0),
#   'Post-Surgery Discharge Date': np.float64(1.0),
#   'Planned Start Date for Doctor Block': np.float64(1.0),
#   'Planned End Date for Doctor Block': np.float64(1.0),
#   'Readmission': 1.0,
#   'strict_signature': np.float64(0.49775980312414203),
#   'No Show': np.float64(1.307907404883444e-43),
#   'Entry DateTime': np.float64(0.01620713865427624),
#   'Incision DateTime': np.float64(0.005622307985773995),
#   'Closure DateTime': np.float64(0.9999999999957887),
#   'Exit DateTime': np.float64(1.0),
#   'Planned Surgery Time_Minutes': np.float64(6.559550819351574e-05),
#   'Administrative Admission Time_Minutes': np.float64(5.6991495678269315e-08),
#   'Pre-Surgery Hospitalization Admission Time_Minutes': np.float64(4.705733364796778e-07),
#   'Pre-Surgical Admission Time Before Surgery_Minutes': np.float64(0.5855264802132218),
#   'Actual Surgery Room Entry Time_Minutes': np.float64(0.13584463484240683),
#   'Incision Time_Minutes': np.float64(2.5379685139005804e-09),
#   'Closure Time_Minutes': np.float64(9.207276192485209e-10),
#   'End of Surgery Time (Exit from OR)_Minutes': np.float64(0.2630496718939769),
#   'Recovery Room Exit Time_Minutes': np.float64(1.0),
#   'Post-Surgery Discharge Time_Minutes': np.float64(0.0006571643307587503),
#   'Planned Start Time for Doctor Block_Minutes': np.float64(2.732937998568539e-06),
#   'Planned End Time for Doctor Block_Minutes': np.float64(2.160207037402018e-13)},
#  'Recovery Room Exit Time_Minutes': {'patient_id': np.float64(0.49775980312413226),
#   'Site Code': 1.0,
#   'Main Surgeon Code': np.float64(0.0),
#   'Activity Code': np.float64(0.0),
#   'Activity Type Code': np.float64(0.0),
#   'Planned SU Time (Large/Medium/Small)': np.float64(0.0),
#   'Pre-Surgery Patient File (External)': np.float64(1.0),
#   'Pre-Surgery Admission Date': np.float64(1.0),
#   'Height': np.float64(1.11665198631627e-15),
#   'Weight': np.float64(4.1783269818748486e-15),
#   'Patient Age (on Surgery Day)': np.float64(8.793973305983407e-112),
#   'Background Diseases/Diagnoses': np.float64(0.0),
#   'Planned Surgery Date': np.float64(1.0),
#   'Surgery Admission Date': np.float64(1.0),
#   'Planned Operating Room Number': np.float64(0.0),
#   'Pre-Surgery Hospitalization Admission Date': np.float64(1.0),
#   'Surgical Team Codes': np.float64(0.0),
#   'Anesthesiologist Code': np.float64(0.0),
#   'Anesthesia Code': np.float64(0.0),
#   'Type of Anesthesia': np.float64(0.0),
#   'Cancellation Reason on Surgery Day': 1.0,
#   'Actual Operating Room Number': np.float64(0.0),
#   'Actual Surgery Room Entry Date': np.float64(1.0),
#   'End of Surgery Date (Exit from OR)': np.float64(1.0),
#   'Planned Surgery Duration': np.float64(6.972134386285479e-21),
#   'Recovery Room Entry Date': np.float64(1.0),
#   'Recovery Room Exit Date': np.float64(1.0),
#   'Post-Surgery Discharge Date': np.float64(1.0),
#   'Planned Start Date for Doctor Block': np.float64(1.0),
#   'Planned End Date for Doctor Block': np.float64(1.0),
#   'Readmission': 1.0,
#   'strict_signature': np.float64(0.49775980312414203),
#   'No Show': np.float64(1.307907404883444e-43),
#   'Entry DateTime': np.float64(0.01620713865427624),
#   'Incision DateTime': np.float64(0.005622307985773995),
#   'Closure DateTime': np.float64(0.9999999999957887),
#   'Exit DateTime': np.float64(1.0),
#   'Planned Surgery Time_Minutes': np.float64(6.559550819351574e-05),
#   'Administrative Admission Time_Minutes': np.float64(5.6991495678269315e-08),
#   'Pre-Surgery Hospitalization Admission Time_Minutes': np.float64(4.705733364796778e-07),
#   'Pre-Surgical Admission Time Before Surgery_Minutes': np.float64(0.5855264802132218),
#   'Actual Surgery Room Entry Time_Minutes': np.float64(0.13584463484240683),
#   'Incision Time_Minutes': np.float64(2.5379685139005804e-09),
#   'Closure Time_Minutes': np.float64(9.207276192485209e-10),
#   'End of Surgery Time (Exit from OR)_Minutes': np.float64(0.2630496718939769),
#   'Recovery Room Entry Time_Minutes': np.float64(1.0),
#   'Post-Surgery Discharge Time_Minutes': np.float64(0.0006571643307587503),
#   'Planned Start Time for Doctor Block_Minutes': np.float64(2.732937998568539e-06),
#   'Planned End Time for Doctor Block_Minutes': np.float64(2.160207037402018e-13)},
#  'Recovery Room Exit Date': {'patient_id': np.float64(0.49775980312413226),
#   'Site Code': 1.0,
#   'Main Surgeon Code': np.float64(0.0),
#   'Activity Code': np.float64(0.0),
#   'Activity Type Code': np.float64(0.0),
#   'Planned SU Time (Large/Medium/Small)': np.float64(0.0),
#   'Pre-Surgery Patient File (External)': np.float64(1.0),
#   'Pre-Surgery Admission Date': np.float64(1.0),
#   'Height': np.float64(1.11665198631627e-15),
#   'Weight': np.float64(4.1783269818748486e-15),
#   'Patient Age (on Surgery Day)': np.float64(8.793973305983407e-112),
#   'Background Diseases/Diagnoses': np.float64(0.0),
#   'Planned Surgery Date': np.float64(1.0),
#   'Surgery Admission Date': np.float64(1.0),
#   'Planned Operating Room Number': np.float64(0.0),
#   'Pre-Surgery Hospitalization Admission Date': np.float64(1.0),
#   'Surgical Team Codes': np.float64(0.0),
#   'Anesthesiologist Code': np.float64(0.0),
#   'Anesthesia Code': np.float64(0.0),
#   'Type of Anesthesia': np.float64(0.0),
#   'Cancellation Reason on Surgery Day': 1.0,
#   'Actual Operating Room Number': np.float64(0.0),
#   'Actual Surgery Room Entry Date': np.float64(1.0),
#   'End of Surgery Date (Exit from OR)': np.float64(1.0),
#   'Planned Surgery Duration': np.float64(6.972134386285479e-21),
#   'Recovery Room Entry Date': np.float64(1.0),
#   'Post-Surgery Discharge Date': np.float64(1.0),
#   'Planned Start Date for Doctor Block': np.float64(1.0),
#   'Planned End Date for Doctor Block': np.float64(1.0),
#   'Readmission': 1.0,
#   'strict_signature': np.float64(0.49775980312414203),
#   'No Show': np.float64(1.307907404883444e-43),
#   'Entry DateTime': np.float64(0.01620713865427624),
#   'Incision DateTime': np.float64(0.005622307985773995),
#   'Closure DateTime': np.float64(0.9999999999957887),
#   'Exit DateTime': np.float64(1.0),
#   'Planned Surgery Time_Minutes': np.float64(6.559550819351574e-05),
#   'Administrative Admission Time_Minutes': np.float64(5.6991495678269315e-08),
#   'Pre-Surgery Hospitalization Admission Time_Minutes': np.float64(4.705733364796778e-07),
#   'Pre-Surgical Admission Time Before Surgery_Minutes': np.float64(0.5855264802132218),
#   'Actual Surgery Room Entry Time_Minutes': np.float64(0.13584463484240683),
#   'Incision Time_Minutes': np.float64(2.5379685139005804e-09),
#   'Closure Time_Minutes': np.float64(9.207276192485209e-10),
#   'End of Surgery Time (Exit from OR)_Minutes': np.float64(0.2630496718939769),
#   'Recovery Room Entry Time_Minutes': np.float64(1.0),
#   'Recovery Room Exit Time_Minutes': np.float64(1.0),
#   'Post-Surgery Discharge Time_Minutes': np.float64(0.0006571643307587503),
#   'Planned Start Time for Doctor Block_Minutes': np.float64(2.732937998568539e-06),
#   'Planned End Time for Doctor Block_Minutes': np.float64(2.160207037402018e-13)},
#  'End of Surgery Time (Exit from OR)': {'patient_id': np.float64(0.49775980312413226),
#   'Site Code': 1.0,
#   'Main Surgeon Code': np.float64(0.0),
#   'Activity Code': np.float64(0.0),
#   'Activity Type Code': np.float64(0.0),
#   'Planned SU Time (Large/Medium/Small)': np.float64(0.0),
#   'Pre-Surgery Patient File (External)': np.float64(1.0),
#   'Pre-Surgery Admission Date': np.float64(1.0),
#   'Height': np.float64(0.0002232490555945121),
#   'Weight': np.float64(0.004128862565214894),
#   'Patient Age (on Surgery Day)': np.float64(6.480821880188865e-10),
#   'Background Diseases/Diagnoses': np.float64(1.772474027110354e-223),
#   'Planned Surgery Date': np.float64(1.0),
#   'Surgery Admission Date': np.float64(1.0),
#   'Planned Operating Room Number': np.float64(0.0),
#   'Pre-Surgery Hospitalization Admission Date': np.float64(1.0),
#   'Surgical Team Codes': np.float64(0.0),
#   'Anesthesiologist Code': np.float64(0.0),
#   'Anesthesia Code': np.float64(0.0),
#   'Type of Anesthesia': np.float64(0.0),
#   'Cancellation Reason on Surgery Day': 1.0,
#   'Actual Operating Room Number': np.float64(0.0),
#   'Actual Surgery Room Entry Date': np.float64(1.0),
#   'End of Surgery Date (Exit from OR)': np.float64(1.0),
#   'Planned Surgery Duration': np.float64(1.4158802084108742e-23),
#   'Recovery Room Entry Date': np.float64(1.0),
#   'Recovery Room Exit Date': np.float64(1.0),
#   'Post-Surgery Discharge Date': np.float64(1.0),
#   'Planned Start Date for Doctor Block': np.float64(1.0),
#   'Planned End Date for Doctor Block': np.float64(1.0),
#   'Readmission': 1.0,
#   'strict_signature': np.float64(0.49775980312414203),
#   'No Show': np.float64(8.52574946696932e-90),
#   'Entry DateTime': np.float64(1.4058801744199567e-133),
#   'Incision DateTime': np.float64(2.3235326991457817e-99),
#   'Closure DateTime': np.float64(1.0),
#   'Exit DateTime': np.float64(1.0),
#   'Planned Surgery Time_Minutes': np.float64(0.06675489793659217),
#   'Administrative Admission Time_Minutes': np.float64(0.00043877560830814173),
#   'Pre-Surgery Hospitalization Admission Time_Minutes': np.float64(6.113385802630933e-05),
#   'Pre-Surgical Admission Time Before Surgery_Minutes': np.float64(0.9999999999999982),
#   'Actual Surgery Room Entry Time_Minutes': np.float64(1.0),
#   'Incision Time_Minutes': np.float64(0.0007238849046336684),
#   'Closure Time_Minutes': np.float64(0.002682826986224481),
#   'End of Surgery Time (Exit from OR)_Minutes': np.float64(1.0),
#   'Recovery Room Entry Time_Minutes': np.float64(0.019056484408884907),
#   'Recovery Room Exit Time_Minutes': np.float64(0.014817627490356169),
#   'Post-Surgery Discharge Time_Minutes': np.float64(0.0157121769657262),
#   'Planned Start Time for Doctor Block_Minutes': np.float64(0.007559313335943402),
#   'Planned End Time for Doctor Block_Minutes': np.float64(0.009847256224360643)},
#  'Actual Surgery Room Entry Time': {'patient_id': np.float64(0.49775980312413226),
#   'Site Code': 1.0,
#   'Main Surgeon Code': np.float64(0.0),
#   'Activity Code': np.float64(0.0),
#   'Activity Type Code': np.float64(0.0),
#   'Planned SU Time (Large/Medium/Small)': np.float64(0.0),
#   'Pre-Surgery Patient File (External)': np.float64(1.0),
#   'Pre-Surgery Admission Date': np.float64(1.0),
#   'Height': np.float64(0.0002232490555945121),
#   'Weight': np.float64(0.004128862565214894),
#   'Patient Age (on Surgery Day)': np.float64(6.480821880188865e-10),
#   'Background Diseases/Diagnoses': np.float64(1.772474027110354e-223),
#   'Planned Surgery Date': np.float64(1.0),
#   'Surgery Admission Date': np.float64(1.0),
#   'Planned Operating Room Number': np.float64(0.0),
#   'Pre-Surgery Hospitalization Admission Date': np.float64(1.0),
#   'Surgical Team Codes': np.float64(0.0),
#   'Anesthesiologist Code': np.float64(0.0),
#   'Anesthesia Code': np.float64(0.0),
#   'Type of Anesthesia': np.float64(0.0),
#   'Cancellation Reason on Surgery Day': 1.0,
#   'Actual Operating Room Number': np.float64(0.0),
#   'Actual Surgery Room Entry Date': np.float64(1.0),
#   'End of Surgery Date (Exit from OR)': np.float64(1.0),
#   'Planned Surgery Duration': np.float64(1.4158802084108742e-23),
#   'Recovery Room Entry Date': np.float64(1.0),
#   'Recovery Room Exit Date': np.float64(1.0),
#   'Post-Surgery Discharge Date': np.float64(1.0),
#   'Planned Start Date for Doctor Block': np.float64(1.0),
#   'Planned End Date for Doctor Block': np.float64(1.0),
#   'Readmission': 1.0,
#   'strict_signature': np.float64(0.49775980312414203),
#   'No Show': np.float64(8.52574946696932e-90),
#   'Entry DateTime': np.float64(1.4058801744199567e-133),
#   'Incision DateTime': np.float64(2.3235326991457817e-99),
#   'Closure DateTime': np.float64(1.0),
#   'Exit DateTime': np.float64(1.0),
#   'Planned Surgery Time_Minutes': np.float64(0.06675489793659217),
#   'Administrative Admission Time_Minutes': np.float64(0.00043877560830814173),
#   'Pre-Surgery Hospitalization Admission Time_Minutes': np.float64(6.113385802630933e-05),
#   'Pre-Surgical Admission Time Before Surgery_Minutes': np.float64(0.9999999999999982),
#   'Actual Surgery Room Entry Time_Minutes': np.float64(1.0),
#   'Incision Time_Minutes': np.float64(0.0007238849046336684),
#   'Closure Time_Minutes': np.float64(0.002682826986224481),
#   'End of Surgery Time (Exit from OR)_Minutes': np.float64(1.0),
#   'Recovery Room Entry Time_Minutes': np.float64(0.019056484408884907),
#   'Recovery Room Exit Time_Minutes': np.float64(0.014817627490356169),
#   'Post-Surgery Discharge Time_Minutes': np.float64(0.0157121769657262),
#   'Planned Start Time for Doctor Block_Minutes': np.float64(0.007559313335943402),
#   'Planned End Time for Doctor Block_Minutes': np.float64(0.009847256224360643)},
#  'End of Surgery Time (Exit from OR)_Minutes': {'patient_id': np.float64(0.49775980312413226),
#   'Site Code': 1.0,
#   'Main Surgeon Code': np.float64(0.0),
#   'Activity Code': np.float64(0.0),
#   'Activity Type Code': np.float64(0.0),
#   'Planned SU Time (Large/Medium/Small)': np.float64(0.0),
#   'Pre-Surgery Patient File (External)': np.float64(1.0),
#   'Pre-Surgery Admission Date': np.float64(1.0),
#   'Height': np.float64(0.0002232490555945121),
#   'Weight': np.float64(0.004128862565214894),
#   'Patient Age (on Surgery Day)': np.float64(6.480821880188865e-10),
#   'Background Diseases/Diagnoses': np.float64(1.772474027110354e-223),
#   'Planned Surgery Date': np.float64(1.0),
#   'Surgery Admission Date': np.float64(1.0),
#   'Planned Operating Room Number': np.float64(0.0),
#   'Pre-Surgery Hospitalization Admission Date': np.float64(1.0),
#   'Surgical Team Codes': np.float64(0.0),
#   'Anesthesiologist Code': np.float64(0.0),
#   'Anesthesia Code': np.float64(0.0),
#   'Type of Anesthesia': np.float64(0.0),
#   'Cancellation Reason on Surgery Day': 1.0,
#   'Actual Operating Room Number': np.float64(0.0),
#   'Actual Surgery Room Entry Date': np.float64(1.0),
#   'End of Surgery Date (Exit from OR)': np.float64(1.0),
#   'Planned Surgery Duration': np.float64(1.4158802084108742e-23),
#   'Recovery Room Entry Date': np.float64(1.0),
#   'Recovery Room Exit Date': np.float64(1.0),
#   'Post-Surgery Discharge Date': np.float64(1.0),
#   'Planned Start Date for Doctor Block': np.float64(1.0),
#   'Planned End Date for Doctor Block': np.float64(1.0),
#   'Readmission': 1.0,
#   'strict_signature': np.float64(0.49775980312414203),
#   'No Show': np.float64(8.52574946696932e-90),
#   'Entry DateTime': np.float64(1.4058801744199567e-133),
#   'Incision DateTime': np.float64(2.3235326991457817e-99),
#   'Closure DateTime': np.float64(1.0),
#   'Exit DateTime': np.float64(1.0),
#   'Planned Surgery Time_Minutes': np.float64(0.06675489793659217),
#   'Administrative Admission Time_Minutes': np.float64(0.00043877560830814173),
#   'Pre-Surgery Hospitalization Admission Time_Minutes': np.float64(6.113385802630933e-05),
#   'Pre-Surgical Admission Time Before Surgery_Minutes': np.float64(0.9999999999999982),
#   'Actual Surgery Room Entry Time_Minutes': np.float64(1.0),
#   'Incision Time_Minutes': np.float64(0.0007238849046336684),
#   'Closure Time_Minutes': np.float64(0.002682826986224481),
#   'Recovery Room Entry Time_Minutes': np.float64(0.019056484408884907),
#   'Recovery Room Exit Time_Minutes': np.float64(0.014817627490356169),
#   'Post-Surgery Discharge Time_Minutes': np.float64(0.0157121769657262),
#   'Planned Start Time for Doctor Block_Minutes': np.float64(0.007559313335943402),
#   'Planned End Time for Doctor Block_Minutes': np.float64(0.009847256224360643)},
#  'Actual Surgery Room Entry Time_Minutes': {'patient_id': np.float64(0.49775980312413226),
#   'Site Code': 1.0,
#   'Main Surgeon Code': np.float64(0.0),
#   'Activity Code': np.float64(0.0),
#   'Activity Type Code': np.float64(0.0),
#   'Planned SU Time (Large/Medium/Small)': np.float64(0.0),
#   'Pre-Surgery Patient File (External)': np.float64(1.0),
#   'Pre-Surgery Admission Date': np.float64(1.0),
#   'Height': np.float64(0.0002232490555945121),
#   'Weight': np.float64(0.004128862565214894),
#   'Patient Age (on Surgery Day)': np.float64(6.480821880188865e-10),
#   'Background Diseases/Diagnoses': np.float64(1.772474027110354e-223),
#   'Planned Surgery Date': np.float64(1.0),
#   'Surgery Admission Date': np.float64(1.0),
#   'Planned Operating Room Number': np.float64(0.0),
#   'Pre-Surgery Hospitalization Admission Date': np.float64(1.0),
#   'Surgical Team Codes': np.float64(0.0),
#   'Anesthesiologist Code': np.float64(0.0),
#   'Anesthesia Code': np.float64(0.0),
#   'Type of Anesthesia': np.float64(0.0),
#   'Cancellation Reason on Surgery Day': 1.0,
#   'Actual Operating Room Number': np.float64(0.0),
#   'Actual Surgery Room Entry Date': np.float64(1.0),
#   'End of Surgery Date (Exit from OR)': np.float64(1.0),
#   'Planned Surgery Duration': np.float64(1.4158802084108742e-23),
#   'Recovery Room Entry Date': np.float64(1.0),
#   'Recovery Room Exit Date': np.float64(1.0),
#   'Post-Surgery Discharge Date': np.float64(1.0),
#   'Planned Start Date for Doctor Block': np.float64(1.0),
#   'Planned End Date for Doctor Block': np.float64(1.0),
#   'Readmission': 1.0,
#   'strict_signature': np.float64(0.49775980312414203),
#   'No Show': np.float64(8.52574946696932e-90),
#   'Entry DateTime': np.float64(1.4058801744199567e-133),
#   'Incision DateTime': np.float64(2.3235326991457817e-99),
#   'Closure DateTime': np.float64(1.0),
#   'Exit DateTime': np.float64(1.0),
#   'Planned Surgery Time_Minutes': np.float64(0.06675489793659217),
#   'Administrative Admission Time_Minutes': np.float64(0.00043877560830814173),
#   'Pre-Surgery Hospitalization Admission Time_Minutes': np.float64(6.113385802630933e-05),
#   'Pre-Surgical Admission Time Before Surgery_Minutes': np.float64(0.9999999999999982),
#   'Incision Time_Minutes': np.float64(0.0007238849046336684),
#   'Closure Time_Minutes': np.float64(0.002682826986224481),
#   'End of Surgery Time (Exit from OR)_Minutes': np.float64(1.0),
#   'Recovery Room Entry Time_Minutes': np.float64(0.019056484408884907),
#   'Recovery Room Exit Time_Minutes': np.float64(0.014817627490356169),
#   'Post-Surgery Discharge Time_Minutes': np.float64(0.0157121769657262),
#   'Planned Start Time for Doctor Block_Minutes': np.float64(0.007559313335943402),
#   'Planned End Time for Doctor Block_Minutes': np.float64(0.009847256224360643)},
#  'Planned Start Date for Doctor Block': {'patient_id': np.float64(0.49775980312414203),
#   'Site Code': 1.0,
#   'Main Surgeon Code': np.float64(0.0),
#   'Activity Code': np.float64(0.0),
#   'Activity Type Code': np.float64(0.0),
#   'Planned SU Time (Large/Medium/Small)': np.float64(1.864869568343168e-40),
#   'Pre-Surgery Patient File (External)': np.float64(1.0),
#   'Pre-Surgery Admission Date': np.float64(1.0),
#   'Height': np.float64(0.47275151303871554),
#   'Weight': np.float64(0.7706044345623051),
#   'Patient Age (on Surgery Day)': np.float64(0.4374646154914783),
#   'Background Diseases/Diagnoses': np.float64(7.460062181638031e-12),
#   'Planned Surgery Date': np.float64(1.0),
#   'Surgery Admission Date': np.float64(1.0),
#   'Planned Operating Room Number': np.float64(0.0),
#   'Pre-Surgery Hospitalization Admission Date': np.float64(1.0),
#   'Surgical Team Codes': np.float64(6.165629549311022e-286),
#   'Anesthesiologist Code': np.float64(0.0),
#   'Anesthesia Code': np.float64(0.0),
#   'Type of Anesthesia': np.float64(0.0),
#   'Cancellation Reason on Surgery Day': 1.0,
#   'Actual Operating Room Number': np.float64(0.0),
#   'Actual Surgery Room Entry Date': np.float64(1.0),
#   'End of Surgery Date (Exit from OR)': np.float64(1.0),
#   'Planned Surgery Duration': np.float64(2.4616632804211455e-106),
#   'Recovery Room Entry Date': np.float64(1.0),
#   'Recovery Room Exit Date': np.float64(1.0),
#   'Post-Surgery Discharge Date': np.float64(1.0),
#   'Planned End Date for Doctor Block': np.float64(1.0),
#   'Readmission': 1.0,
#   'strict_signature': np.float64(0.49775980312413226),
#   'No Show': np.float64(1.7417033552154555e-24),
#   'Entry DateTime': np.float64(1.0),
#   'Incision DateTime': np.float64(1.0),
#   'Closure DateTime': np.float64(1.0),
#   'Exit DateTime': np.float64(1.0),
#   'Planned Surgery Time_Minutes': np.float64(1.0),
#   'Administrative Admission Time_Minutes': np.float64(0.0012496287755529934),
#   'Pre-Surgery Hospitalization Admission Time_Minutes': np.float64(0.003896171033172161),
#   'Pre-Surgical Admission Time Before Surgery_Minutes': np.float64(0.660979433617776),
#   'Actual Surgery Room Entry Time_Minutes': np.float64(0.4660815650652095),
#   'Incision Time_Minutes': np.float64(0.003323383092741076),
#   'Closure Time_Minutes': np.float64(0.0038532264816803436),
#   'End of Surgery Time (Exit from OR)_Minutes': np.float64(0.2717213056910629),
#   'Recovery Room Entry Time_Minutes': np.float64(0.9503863176314566),
#   'Recovery Room Exit Time_Minutes': np.float64(0.9986842782934785),
#   'Post-Surgery Discharge Time_Minutes': np.float64(0.7117257492788802),
#   'Planned Start Time for Doctor Block_Minutes': np.float64(1.0),
#   'Planned End Time for Doctor Block_Minutes': np.float64(1.0)},
#  'Planned End Date for Doctor Block': {'patient_id': np.float64(0.49775980312414203),
#   'Site Code': 1.0,
#   'Main Surgeon Code': np.float64(0.0),
#   'Activity Code': np.float64(0.0),
#   'Activity Type Code': np.float64(0.0),
#   'Planned SU Time (Large/Medium/Small)': np.float64(1.864869568343168e-40),
#   'Pre-Surgery Patient File (External)': np.float64(1.0),
#   'Pre-Surgery Admission Date': np.float64(1.0),
#   'Height': np.float64(0.47275151303871554),
#   'Weight': np.float64(0.7706044345623051),
#   'Patient Age (on Surgery Day)': np.float64(0.4374646154914783),
#   'Background Diseases/Diagnoses': np.float64(7.460062181638031e-12),
#   'Planned Surgery Date': np.float64(1.0),
#   'Surgery Admission Date': np.float64(1.0),
#   'Planned Operating Room Number': np.float64(0.0),
#   'Pre-Surgery Hospitalization Admission Date': np.float64(1.0),
#   'Surgical Team Codes': np.float64(6.165629549311022e-286),
#   'Anesthesiologist Code': np.float64(0.0),
#   'Anesthesia Code': np.float64(0.0),
#   'Type of Anesthesia': np.float64(0.0),
#   'Cancellation Reason on Surgery Day': 1.0,
#   'Actual Operating Room Number': np.float64(0.0),
#   'Actual Surgery Room Entry Date': np.float64(1.0),
#   'End of Surgery Date (Exit from OR)': np.float64(1.0),
#   'Planned Surgery Duration': np.float64(2.4616632804211455e-106),
#   'Recovery Room Entry Date': np.float64(1.0),
#   'Recovery Room Exit Date': np.float64(1.0),
#   'Post-Surgery Discharge Date': np.float64(1.0),
#   'Planned Start Date for Doctor Block': np.float64(1.0),
#   'Readmission': 1.0,
#   'strict_signature': np.float64(0.49775980312413226),
#   'No Show': np.float64(1.7417033552154555e-24),
#   'Entry DateTime': np.float64(1.0),
#   'Incision DateTime': np.float64(1.0),
#   'Closure DateTime': np.float64(1.0),
#   'Exit DateTime': np.float64(1.0),
#   'Planned Surgery Time_Minutes': np.float64(1.0),
#   'Administrative Admission Time_Minutes': np.float64(0.0012496287755529934),
#   'Pre-Surgery Hospitalization Admission Time_Minutes': np.float64(0.003896171033172161),
#   'Pre-Surgical Admission Time Before Surgery_Minutes': np.float64(0.660979433617776),
#   'Actual Surgery Room Entry Time_Minutes': np.float64(0.4660815650652095),
#   'Incision Time_Minutes': np.float64(0.003323383092741076),
#   'Closure Time_Minutes': np.float64(0.0038532264816803436),
#   'End of Surgery Time (Exit from OR)_Minutes': np.float64(0.2717213056910629),
#   'Recovery Room Entry Time_Minutes': np.float64(0.9503863176314566),
#   'Recovery Room Exit Time_Minutes': np.float64(0.9986842782934785),
#   'Post-Surgery Discharge Time_Minutes': np.float64(0.7117257492788802),
#   'Planned Start Time for Doctor Block_Minutes': np.float64(1.0),
#   'Planned End Time for Doctor Block_Minutes': np.float64(1.0)},
#  'Planned Start Time for Doctor Block': {'patient_id': np.float64(0.49775980312413226),
#   'Site Code': 1.0,
#   'Main Surgeon Code': np.float64(0.0),
#   'Activity Code': np.float64(0.0),
#   'Activity Type Code': np.float64(0.0),
#   'Planned SU Time (Large/Medium/Small)': np.float64(2.8898415736871596e-40),
#   'Pre-Surgery Patient File (External)': np.float64(1.0),
#   'Pre-Surgery Admission Date': np.float64(1.0),
#   'Height': np.float64(0.4647851335141341),
#   'Weight': np.float64(0.7616117740491617),
#   'Patient Age (on Surgery Day)': np.float64(0.4405712109198978),
#   'Background Diseases/Diagnoses': np.float64(3.990748495485004e-12),
#   'Planned Surgery Date': np.float64(1.0),
#   'Surgery Admission Date': np.float64(1.0),
#   'Planned Operating Room Number': np.float64(0.0),
#   'Pre-Surgery Hospitalization Admission Date': np.float64(1.0),
#   'Surgical Team Codes': np.float64(2.537472235765893e-285),
#   'Anesthesiologist Code': np.float64(0.0),
#   'Anesthesia Code': np.float64(0.0),
#   'Type of Anesthesia': np.float64(0.0),
#   'Cancellation Reason on Surgery Day': 1.0,
#   'Actual Operating Room Number': np.float64(0.0),
#   'Actual Surgery Room Entry Date': np.float64(1.0),
#   'End of Surgery Date (Exit from OR)': np.float64(1.0),
#   'Planned Surgery Duration': np.float64(2.428968163250433e-106),
#   'Recovery Room Entry Date': np.float64(1.0),
#   'Recovery Room Exit Date': np.float64(1.0),
#   'Post-Surgery Discharge Date': np.float64(1.0),
#   'Planned Start Date for Doctor Block': np.float64(1.0),
#   'Planned End Date for Doctor Block': np.float64(1.0),
#   'Readmission': 1.0,
#   'strict_signature': np.float64(0.49775980312414203),
#   'No Show': np.float64(5.168661468980795e-18),
#   'Entry DateTime': np.float64(1.0),
#   'Incision DateTime': np.float64(1.0),
#   'Closure DateTime': np.float64(1.0),
#   'Exit DateTime': np.float64(1.0),
#   'Planned Surgery Time_Minutes': np.float64(1.0),
#   'Administrative Admission Time_Minutes': np.float64(0.0013043061910385301),
#   'Pre-Surgery Hospitalization Admission Time_Minutes': np.float64(0.003896171033172161),
#   'Pre-Surgical Admission Time Before Surgery_Minutes': np.float64(0.660979433617776),
#   'Actual Surgery Room Entry Time_Minutes': np.float64(0.4660815650652095),
#   'Incision Time_Minutes': np.float64(0.003323383092741076),
#   'Closure Time_Minutes': np.float64(0.0038532264816803436),
#   'End of Surgery Time (Exit from OR)_Minutes': np.float64(0.2717213056910629),
#   'Recovery Room Entry Time_Minutes': np.float64(0.9503863176314566),
#   'Recovery Room Exit Time_Minutes': np.float64(0.9986842782934785),
#   'Post-Surgery Discharge Time_Minutes': np.float64(0.7117257492788802),
#   'Planned Start Time for Doctor Block_Minutes': np.float64(1.0),
#   'Planned End Time for Doctor Block_Minutes': np.float64(1.0)},
#  'Planned Start Time for Doctor Block_Minutes': {'patient_id': np.float64(0.49775980312413226),
#   'Site Code': 1.0,
#   'Main Surgeon Code': np.float64(0.0),
#   'Activity Code': np.float64(0.0),
#   'Activity Type Code': np.float64(0.0),
#   'Planned SU Time (Large/Medium/Small)': np.float64(2.8898415736871596e-40),
#   'Pre-Surgery Patient File (External)': np.float64(1.0),
#   'Pre-Surgery Admission Date': np.float64(1.0),
#   'Height': np.float64(0.4647851335141341),
#   'Weight': np.float64(0.7616117740491617),
#   'Patient Age (on Surgery Day)': np.float64(0.4405712109198978),
#   'Background Diseases/Diagnoses': np.float64(3.990748495485004e-12),
#   'Planned Surgery Date': np.float64(1.0),
#   'Surgery Admission Date': np.float64(1.0),
#   'Planned Operating Room Number': np.float64(0.0),
#   'Pre-Surgery Hospitalization Admission Date': np.float64(1.0),
#   'Surgical Team Codes': np.float64(2.537472235765893e-285),
#   'Anesthesiologist Code': np.float64(0.0),
#   'Anesthesia Code': np.float64(0.0),
#   'Type of Anesthesia': np.float64(0.0),
#   'Cancellation Reason on Surgery Day': 1.0,
#   'Actual Operating Room Number': np.float64(0.0),
#   'Actual Surgery Room Entry Date': np.float64(1.0),
#   'End of Surgery Date (Exit from OR)': np.float64(1.0),
#   'Planned Surgery Duration': np.float64(2.428968163250433e-106),
#   'Recovery Room Entry Date': np.float64(1.0),
#   'Recovery Room Exit Date': np.float64(1.0),
#   'Post-Surgery Discharge Date': np.float64(1.0),
#   'Planned Start Date for Doctor Block': np.float64(1.0),
#   'Planned End Date for Doctor Block': np.float64(1.0),
#   'Readmission': 1.0,
#   'strict_signature': np.float64(0.49775980312414203),
#   'No Show': np.float64(5.168661468980795e-18),
#   'Entry DateTime': np.float64(1.0),
#   'Incision DateTime': np.float64(1.0),
#   'Closure DateTime': np.float64(1.0),
#   'Exit DateTime': np.float64(1.0),
#   'Planned Surgery Time_Minutes': np.float64(1.0),
#   'Administrative Admission Time_Minutes': np.float64(0.0013043061910385301),
#   'Pre-Surgery Hospitalization Admission Time_Minutes': np.float64(0.003896171033172161),
#   'Pre-Surgical Admission Time Before Surgery_Minutes': np.float64(0.660979433617776),
#   'Actual Surgery Room Entry Time_Minutes': np.float64(0.4660815650652095),
#   'Incision Time_Minutes': np.float64(0.003323383092741076),
#   'Closure Time_Minutes': np.float64(0.0038532264816803436),
#   'End of Surgery Time (Exit from OR)_Minutes': np.float64(0.2717213056910629),
#   'Recovery Room Entry Time_Minutes': np.float64(0.9503863176314566),
#   'Recovery Room Exit Time_Minutes': np.float64(0.9986842782934785),
#   'Post-Surgery Discharge Time_Minutes': np.float64(0.7117257492788802),
#   'Planned End Time for Doctor Block_Minutes': np.float64(1.0)},
#  'Planned End Time for Doctor Block_Minutes': {'patient_id': np.float64(0.49775980312413226),
#   'Site Code': 1.0,
#   'Main Surgeon Code': np.float64(0.0),
#   'Activity Code': np.float64(0.0),
#   'Activity Type Code': np.float64(0.0),
#   'Planned SU Time (Large/Medium/Small)': np.float64(2.8898415736871596e-40),
#   'Pre-Surgery Patient File (External)': np.float64(1.0),
#   'Pre-Surgery Admission Date': np.float64(1.0),
#   'Height': np.float64(0.4647851335141341),
#   'Weight': np.float64(0.7616117740491617),
#   'Patient Age (on Surgery Day)': np.float64(0.4405712109198978),
#   'Background Diseases/Diagnoses': np.float64(3.990748495485004e-12),
#   'Planned Surgery Date': np.float64(1.0),
#   'Surgery Admission Date': np.float64(1.0),
#   'Planned Operating Room Number': np.float64(0.0),
#   'Pre-Surgery Hospitalization Admission Date': np.float64(1.0),
#   'Surgical Team Codes': np.float64(2.537472235765893e-285),
#   'Anesthesiologist Code': np.float64(0.0),
#   'Anesthesia Code': np.float64(0.0),
#   'Type of Anesthesia': np.float64(0.0),
#   'Cancellation Reason on Surgery Day': 1.0,
#   'Actual Operating Room Number': np.float64(0.0),
#   'Actual Surgery Room Entry Date': np.float64(1.0),
#   'End of Surgery Date (Exit from OR)': np.float64(1.0),
#   'Planned Surgery Duration': np.float64(2.428968163250433e-106),
#   'Recovery Room Entry Date': np.float64(1.0),
#   'Recovery Room Exit Date': np.float64(1.0),
#   'Post-Surgery Discharge Date': np.float64(1.0),
#   'Planned Start Date for Doctor Block': np.float64(1.0),
#   'Planned End Date for Doctor Block': np.float64(1.0),
#   'Readmission': 1.0,
#   'strict_signature': np.float64(0.49775980312414203),
#   'No Show': np.float64(5.168661468980795e-18),
#   'Entry DateTime': np.float64(1.0),
#   'Incision DateTime': np.float64(1.0),
#   'Closure DateTime': np.float64(1.0),
#   'Exit DateTime': np.float64(1.0),
#   'Planned Surgery Time_Minutes': np.float64(1.0),
#   'Administrative Admission Time_Minutes': np.float64(0.0013043061910385301),
#   'Pre-Surgery Hospitalization Admission Time_Minutes': np.float64(0.003896171033172161),
#   'Pre-Surgical Admission Time Before Surgery_Minutes': np.float64(0.660979433617776),
#   'Actual Surgery Room Entry Time_Minutes': np.float64(0.4660815650652095),
#   'Incision Time_Minutes': np.float64(0.003323383092741076),
#   'Closure Time_Minutes': np.float64(0.0038532264816803436),
#   'End of Surgery Time (Exit from OR)_Minutes': np.float64(0.2717213056910629),
#   'Recovery Room Entry Time_Minutes': np.float64(0.9503863176314566),
#   'Recovery Room Exit Time_Minutes': np.float64(0.9986842782934785),
#   'Post-Surgery Discharge Time_Minutes': np.float64(0.7117257492788802),
#   'Planned Start Time for Doctor Block_Minutes': np.float64(1.0)},
#  'Planned End Time for Doctor Block': {'patient_id': np.float64(0.49775980312413226),
#   'Site Code': 1.0,
#   'Main Surgeon Code': np.float64(0.0),
#   'Activity Code': np.float64(0.0),
#   'Activity Type Code': np.float64(0.0),
#   'Planned SU Time (Large/Medium/Small)': np.float64(2.8898415736871596e-40),
#   'Pre-Surgery Patient File (External)': np.float64(1.0),
#   'Pre-Surgery Admission Date': np.float64(1.0),
#   'Height': np.float64(0.4647851335141341),
#   'Weight': np.float64(0.7616117740491617),
#   'Patient Age (on Surgery Day)': np.float64(0.4405712109198978),
#   'Background Diseases/Diagnoses': np.float64(3.990748495485004e-12),
#   'Planned Surgery Date': np.float64(1.0),
#   'Surgery Admission Date': np.float64(1.0),
#   'Planned Operating Room Number': np.float64(0.0),
#   'Pre-Surgery Hospitalization Admission Date': np.float64(1.0),
#   'Surgical Team Codes': np.float64(2.537472235765893e-285),
#   'Anesthesiologist Code': np.float64(0.0),
#   'Anesthesia Code': np.float64(0.0),
#   'Type of Anesthesia': np.float64(0.0),
#   'Cancellation Reason on Surgery Day': 1.0,
#   'Actual Operating Room Number': np.float64(0.0),
#   'Actual Surgery Room Entry Date': np.float64(1.0),
#   'End of Surgery Date (Exit from OR)': np.float64(1.0),
# ...
#   'Pre-Surgery Hospitalization Admission Time_Minutes': np.float64(1.0),
#   'Pre-Surgical Admission Time Before Surgery_Minutes': np.float64(1.0),
#   'Actual Surgery Room Entry Time_Minutes': np.float64(1.0),
#   'Incision Time_Minutes': np.float64(1.0),
#   'Closure Time_Minutes': np.float64(1.0),
#   'End of Surgery Time (Exit from OR)_Minutes': np.float64(1.0),
#   'Recovery Room Entry Time_Minutes': np.float64(1.0),
#   'Recovery Room Exit Time_Minutes': np.float64(1.0),
#   'Post-Surgery Discharge Time_Minutes': np.float64(1.0),
#   'Planned Start Time for Doctor Block_Minutes': np.float64(1.0),
#   'Planned End Time for Doctor Block_Minutes': np.float64(1.0)},
#  'Incision Time': {'patient_id': np.float64(0.4977598031241518),
#   'Site Code': 1.0,
#   'Main Surgeon Code': np.float64(0.0),
#   'Activity Code': np.float64(2.8472485467414923e-262),
#   'Activity Type Code': np.float64(2.917414205177237e-305),
#   'Planned SU Time (Large/Medium/Small)': np.float64(0.7343358098577326),
#   'Pre-Surgery Patient File (External)': np.float64(1.0),
#   'Pre-Surgery Admission Date': np.float64(1.0),
#   'Height': np.float64(0.9999406619198471),
#   'Weight': np.float64(0.9990196187041064),
#   'Patient Age (on Surgery Day)': np.float64(1.0),
#   'Background Diseases/Diagnoses': np.float64(1.0),
#   'Planned Surgery Date': np.float64(1.0),
#   'Surgery Admission Date': np.float64(1.0),
#   'Planned Operating Room Number': np.float64(7.276147658065477e-43),
#   'Pre-Surgery Hospitalization Admission Date': np.float64(1.0),
#   'Surgical Team Codes': np.float64(2.1885142011707164e-198),
#   'Anesthesiologist Code': np.float64(0.0),
#   'Anesthesia Code': np.float64(3.8683388500064035e-262),
#   'Type of Anesthesia': np.float64(3.8683388500064024e-262),
#   'Cancellation Reason on Surgery Day': 1.0,
#   'Actual Operating Room Number': np.float64(1.4584805693883317e-30),
#   'Actual Surgery Room Entry Date': np.float64(1.0),
#   'End of Surgery Date (Exit from OR)': np.float64(1.0),
#   'Planned Surgery Duration': np.float64(1.0),
#   'Recovery Room Entry Date': np.float64(1.0),
#   'Recovery Room Exit Date': np.float64(1.0),
#   'Post-Surgery Discharge Date': np.float64(1.0),
#   'Planned Start Date for Doctor Block': np.float64(1.0),
#   'Planned End Date for Doctor Block': np.float64(1.0),
#   'Readmission': 1.0,
#   'strict_signature': np.float64(0.49775980312413226),
#   'No Show': np.float64(0.0),
#   'Entry DateTime': np.float64(1.0),
#   'Incision DateTime': np.float64(1.0),
#   'Closure DateTime': np.float64(1.0),
#   'Exit DateTime': np.float64(1.0),
#   'Planned Surgery Time_Minutes': np.float64(1.0),
#   'Administrative Admission Time_Minutes': np.float64(1.0),
#   'Pre-Surgery Hospitalization Admission Time_Minutes': np.float64(1.0),
#   'Pre-Surgical Admission Time Before Surgery_Minutes': np.float64(1.0),
#   'Actual Surgery Room Entry Time_Minutes': np.float64(1.0),
#   'Incision Time_Minutes': np.float64(1.0),
#   'Closure Time_Minutes': np.float64(1.0),
#   'End of Surgery Time (Exit from OR)_Minutes': np.float64(1.0),
#   'Recovery Room Entry Time_Minutes': np.float64(1.0),
#   'Recovery Room Exit Time_Minutes': np.float64(1.0),
#   'Post-Surgery Discharge Time_Minutes': np.float64(1.0),
#   'Planned Start Time for Doctor Block_Minutes': np.float64(1.0),
#   'Planned End Time for Doctor Block_Minutes': np.float64(1.0)},
#  'Incision Time_Minutes': {'patient_id': np.float64(0.4977598031241518),
#   'Site Code': 1.0,
#   'Main Surgeon Code': np.float64(0.0),
#   'Activity Code': np.float64(2.8472485467414923e-262),
#   'Activity Type Code': np.float64(2.917414205177237e-305),
#   'Planned SU Time (Large/Medium/Small)': np.float64(0.7343358098577326),
#   'Pre-Surgery Patient File (External)': np.float64(1.0),
#   'Pre-Surgery Admission Date': np.float64(1.0),
#   'Height': np.float64(0.9999406619198471),
#   'Weight': np.float64(0.9990196187041064),
#   'Patient Age (on Surgery Day)': np.float64(1.0),
#   'Background Diseases/Diagnoses': np.float64(1.0),
#   'Planned Surgery Date': np.float64(1.0),
#   'Surgery Admission Date': np.float64(1.0),
#   'Planned Operating Room Number': np.float64(7.276147658065477e-43),
#   'Pre-Surgery Hospitalization Admission Date': np.float64(1.0),
#   'Surgical Team Codes': np.float64(2.1885142011707164e-198),
#   'Anesthesiologist Code': np.float64(0.0),
#   'Anesthesia Code': np.float64(3.8683388500064035e-262),
#   'Type of Anesthesia': np.float64(3.8683388500064024e-262),
#   'Cancellation Reason on Surgery Day': 1.0,
#   'Actual Operating Room Number': np.float64(1.4584805693883317e-30),
#   'Actual Surgery Room Entry Date': np.float64(1.0),
#   'End of Surgery Date (Exit from OR)': np.float64(1.0),
#   'Planned Surgery Duration': np.float64(1.0),
#   'Recovery Room Entry Date': np.float64(1.0),
#   'Recovery Room Exit Date': np.float64(1.0),
#   'Post-Surgery Discharge Date': np.float64(1.0),
#   'Planned Start Date for Doctor Block': np.float64(1.0),
#   'Planned End Date for Doctor Block': np.float64(1.0),
#   'Readmission': 1.0,
#   'strict_signature': np.float64(0.49775980312413226),
#   'No Show': np.float64(0.0),
#   'Entry DateTime': np.float64(1.0),
#   'Incision DateTime': np.float64(1.0),
#   'Closure DateTime': np.float64(1.0),
#   'Exit DateTime': np.float64(1.0),
#   'Planned Surgery Time_Minutes': np.float64(1.0),
#   'Administrative Admission Time_Minutes': np.float64(1.0),
#   'Pre-Surgery Hospitalization Admission Time_Minutes': np.float64(1.0),
#   'Pre-Surgical Admission Time Before Surgery_Minutes': np.float64(1.0),
#   'Actual Surgery Room Entry Time_Minutes': np.float64(1.0),
#   'Closure Time_Minutes': np.float64(1.0),
#   'End of Surgery Time (Exit from OR)_Minutes': np.float64(1.0),
#   'Recovery Room Entry Time_Minutes': np.float64(1.0),
#   'Recovery Room Exit Time_Minutes': np.float64(1.0),
#   'Post-Surgery Discharge Time_Minutes': np.float64(1.0),
#   'Planned Start Time for Doctor Block_Minutes': np.float64(1.0),
#   'Planned End Time for Doctor Block_Minutes': np.float64(1.0)},
#  'Closure Time_Minutes': {'patient_id': np.float64(0.4977598031241518),
#   'Site Code': 1.0,
#   'Main Surgeon Code': np.float64(0.0),
#   'Activity Code': np.float64(2.8472485467414923e-262),
#   'Activity Type Code': np.float64(2.917414205177237e-305),
#   'Planned SU Time (Large/Medium/Small)': np.float64(0.7343358098577326),
#   'Pre-Surgery Patient File (External)': np.float64(1.0),
#   'Pre-Surgery Admission Date': np.float64(1.0),
#   'Height': np.float64(0.9999406619198471),
#   'Weight': np.float64(0.9990196187041064),
#   'Patient Age (on Surgery Day)': np.float64(1.0),
#   'Background Diseases/Diagnoses': np.float64(1.0),
#   'Planned Surgery Date': np.float64(1.0),
#   'Surgery Admission Date': np.float64(1.0),
#   'Planned Operating Room Number': np.float64(7.276147658065477e-43),
#   'Pre-Surgery Hospitalization Admission Date': np.float64(1.0),
#   'Surgical Team Codes': np.float64(2.1885142011707164e-198),
#   'Anesthesiologist Code': np.float64(0.0),
#   'Anesthesia Code': np.float64(3.8683388500064035e-262),
#   'Type of Anesthesia': np.float64(3.8683388500064024e-262),
#   'Cancellation Reason on Surgery Day': 1.0,
#   'Actual Operating Room Number': np.float64(1.4584805693883317e-30),
#   'Actual Surgery Room Entry Date': np.float64(1.0),
#   'End of Surgery Date (Exit from OR)': np.float64(1.0),
#   'Planned Surgery Duration': np.float64(1.0),
#   'Recovery Room Entry Date': np.float64(1.0),
#   'Recovery Room Exit Date': np.float64(1.0),
#   'Post-Surgery Discharge Date': np.float64(1.0),
#   'Planned Start Date for Doctor Block': np.float64(1.0),
#   'Planned End Date for Doctor Block': np.float64(1.0),
#   'Readmission': 1.0,
#   'strict_signature': np.float64(0.49775980312413226),
#   'No Show': np.float64(0.0),
#   'Entry DateTime': np.float64(1.0),
#   'Incision DateTime': np.float64(1.0),
#   'Closure DateTime': np.float64(1.0),
#   'Exit DateTime': np.float64(1.0),
#   'Planned Surgery Time_Minutes': np.float64(1.0),
#   'Administrative Admission Time_Minutes': np.float64(1.0),
#   'Pre-Surgery Hospitalization Admission Time_Minutes': np.float64(1.0),
#   'Pre-Surgical Admission Time Before Surgery_Minutes': np.float64(1.0),
#   'Actual Surgery Room Entry Time_Minutes': np.float64(1.0),
#   'Incision Time_Minutes': np.float64(1.0),
#   'End of Surgery Time (Exit from OR)_Minutes': np.float64(1.0),
#   'Recovery Room Entry Time_Minutes': np.float64(1.0),
#   'Recovery Room Exit Time_Minutes': np.float64(1.0),
#   'Post-Surgery Discharge Time_Minutes': np.float64(1.0),
#   'Planned Start Time for Doctor Block_Minutes': np.float64(1.0),
#   'Planned End Time for Doctor Block_Minutes': np.float64(1.0)},
#  'Surgery Admission Date': {'patient_id': np.float64(0.4977598031241714),
#   'Site Code': 1.0,
#   'Main Surgeon Code': np.float64(0.0),
#   'Activity Code': np.float64(0.0),
#   'Activity Type Code': np.float64(0.0),
#   'Planned SU Time (Large/Medium/Small)': np.float64(0.9999194377531365),
#   'Pre-Surgery Patient File (External)': np.float64(1.0),
#   'Pre-Surgery Admission Date': np.float64(1.0),
#   'Height': np.float64(1.0),
#   'Weight': np.float64(1.0),
#   'Patient Age (on Surgery Day)': np.float64(1.0),
#   'Background Diseases/Diagnoses': np.float64(1.0),
#   'Planned Surgery Date': np.float64(1.0),
#   'Planned Operating Room Number': np.float64(7.859122123814145e-21),
#   'Pre-Surgery Hospitalization Admission Date': np.float64(1.0),
#   'Surgical Team Codes': np.float64(0.0),
#   'Anesthesiologist Code': np.float64(0.0),
#   'Anesthesia Code': np.float64(0.33729555430464936),
#   'Type of Anesthesia': np.float64(0.3372955543046483),
#   'Cancellation Reason on Surgery Day': 1.0,
#   'Actual Operating Room Number': np.float64(4.11936169389683e-17),
#   'Actual Surgery Room Entry Date': np.float64(1.0),
#   'End of Surgery Date (Exit from OR)': np.float64(1.0),
#   'Planned Surgery Duration': np.float64(1.0),
#   'Recovery Room Entry Date': np.float64(1.0),
#   'Recovery Room Exit Date': np.float64(1.0),
#   'Post-Surgery Discharge Date': np.float64(1.0),
#   'Planned Start Date for Doctor Block': np.float64(1.0),
#   'Planned End Date for Doctor Block': np.float64(1.0),
#   'Readmission': 1.0,
#   'strict_signature': np.float64(0.4977598031241616),
#   'No Show': np.float64(0.0),
#   'Entry DateTime': np.float64(1.0),
#   'Incision DateTime': np.float64(1.0),
#   'Closure DateTime': np.float64(1.0),
#   'Exit DateTime': np.float64(1.0),
#   'Planned Surgery Time_Minutes': np.float64(1.0),
#   'Administrative Admission Time_Minutes': np.float64(1.0),
#   'Pre-Surgery Hospitalization Admission Time_Minutes': np.float64(1.0),
#   'Pre-Surgical Admission Time Before Surgery_Minutes': np.float64(1.0),
#   'Actual Surgery Room Entry Time_Minutes': np.float64(1.0),
#   'Incision Time_Minutes': np.float64(1.0),
#   'Closure Time_Minutes': np.float64(1.0),
#   'End of Surgery Time (Exit from OR)_Minutes': np.float64(1.0),
#   'Recovery Room Entry Time_Minutes': np.float64(1.0),
#   'Recovery Room Exit Time_Minutes': np.float64(1.0),
#   'Post-Surgery Discharge Time_Minutes': np.float64(1.0),
#   'Planned Start Time for Doctor Block_Minutes': np.float64(1.0),
#   'Planned End Time for Doctor Block_Minutes': np.float64(1.0)},
#  'Administrative Admission Time': {'patient_id': np.float64(0.49775980312413226),
#   'Site Code': 1.0,
#   'Main Surgeon Code': np.float64(1.0),
#   'Activity Code': np.float64(1.8084271102399976e-67),
#   'Activity Type Code': np.float64(1.0375082669531263e-70),
#   'Planned SU Time (Large/Medium/Small)': np.float64(0.9999999999998294),
#   'Pre-Surgery Patient File (External)': np.float64(0.0),
#   'Pre-Surgery Admission Date': np.float64(1.0),
#   'Height': np.float64(1.0),
#   'Weight': np.float64(1.0),
#   'Patient Age (on Surgery Day)': np.float64(1.0),
#   'Background Diseases/Diagnoses': np.float64(1.0),
#   'Planned Surgery Date': np.float64(1.0),
#   'Surgery Admission Date': np.float64(1.0),
#   'Planned Operating Room Number': np.float64(0.9999982686116793),
#   'Pre-Surgery Hospitalization Admission Date': np.float64(1.0),
#   'Surgical Team Codes': np.float64(0.0),
#   'Anesthesiologist Code': np.float64(0.822424055065762),
#   'Anesthesia Code': np.float64(1.0),
#   'Type of Anesthesia': np.float64(1.0),
#   'Cancellation Reason on Surgery Day': 1.0,
#   'Actual Operating Room Number': np.float64(2.1523423586775466e-06),
#   'Actual Surgery Room Entry Date': np.float64(1.0),
#   'End of Surgery Date (Exit from OR)': np.float64(1.0),
#   'Planned Surgery Duration': np.float64(1.0),
#   'Recovery Room Entry Date': np.float64(1.0),
#   'Recovery Room Exit Date': np.float64(1.0),
#   'Post-Surgery Discharge Date': np.float64(1.0),
#   'Planned Start Date for Doctor Block': np.float64(1.0),
#   'Planned End Date for Doctor Block': np.float64(1.0),
#   'Readmission': 1.0,
#   'strict_signature': np.float64(0.4977598031241225),
#   'No Show': np.float64(1.0),
#   'Entry DateTime': np.float64(1.0),
#   'Incision DateTime': np.float64(1.0),
#   'Closure DateTime': np.float64(1.0),
#   'Exit DateTime': np.float64(1.0),
#   'Planned Surgery Time_Minutes': np.float64(1.0),
#   'Administrative Admission Time_Minutes': np.float64(1.0),
#   'Pre-Surgery Hospitalization Admission Time_Minutes': np.float64(1.0),
#   'Pre-Surgical Admission Time Before Surgery_Minutes': np.float64(1.0),
#   'Actual Surgery Room Entry Time_Minutes': np.float64(1.0),
#   'Incision Time_Minutes': np.float64(1.0),
#   'Closure Time_Minutes': np.float64(1.0),
#   'End of Surgery Time (Exit from OR)_Minutes': np.float64(1.0),
#   'Recovery Room Entry Time_Minutes': np.float64(1.0),
#   'Recovery Room Exit Time_Minutes': np.float64(1.0),
#   'Post-Surgery Discharge Time_Minutes': np.float64(1.0),
#   'Planned Start Time for Doctor Block_Minutes': np.float64(1.0),
#   'Planned End Time for Doctor Block_Minutes': np.float64(1.0)},
#  'Administrative Admission Time_Minutes': {'patient_id': np.float64(0.49775980312413226),
#   'Site Code': 1.0,
#   'Main Surgeon Code': np.float64(1.0),
#   'Activity Code': np.float64(1.8084271102399976e-67),
#   'Activity Type Code': np.float64(1.0375082669531263e-70),
#   'Planned SU Time (Large/Medium/Small)': np.float64(0.9999999999998294),
#   'Pre-Surgery Patient File (External)': np.float64(0.0),
#   'Pre-Surgery Admission Date': np.float64(1.0),
#   'Height': np.float64(1.0),
#   'Weight': np.float64(1.0),
#   'Patient Age (on Surgery Day)': np.float64(1.0),
#   'Background Diseases/Diagnoses': np.float64(1.0),
#   'Planned Surgery Date': np.float64(1.0),
#   'Surgery Admission Date': np.float64(1.0),
#   'Planned Operating Room Number': np.float64(0.9999982686116793),
#   'Pre-Surgery Hospitalization Admission Date': np.float64(1.0),
#   'Surgical Team Codes': np.float64(0.0),
#   'Anesthesiologist Code': np.float64(0.822424055065762),
#   'Anesthesia Code': np.float64(1.0),
#   'Type of Anesthesia': np.float64(1.0),
#   'Cancellation Reason on Surgery Day': 1.0,
#   'Actual Operating Room Number': np.float64(2.1523423586775466e-06),
#   'Actual Surgery Room Entry Date': np.float64(1.0),
#   'End of Surgery Date (Exit from OR)': np.float64(1.0),
#   'Planned Surgery Duration': np.float64(1.0),
#   'Recovery Room Entry Date': np.float64(1.0),
#   'Recovery Room Exit Date': np.float64(1.0),
#   'Post-Surgery Discharge Date': np.float64(1.0),
#   'Planned Start Date for Doctor Block': np.float64(1.0),
#   'Planned End Date for Doctor Block': np.float64(1.0),
#   'Readmission': 1.0,
#   'strict_signature': np.float64(0.4977598031241225),
#   'No Show': np.float64(1.0),
#   'Entry DateTime': np.float64(1.0),
#   'Incision DateTime': np.float64(1.0),
#   'Closure DateTime': np.float64(1.0),
#   'Exit DateTime': np.float64(1.0),
#   'Planned Surgery Time_Minutes': np.float64(1.0),
#   'Pre-Surgery Hospitalization Admission Time_Minutes': np.float64(1.0),
#   'Pre-Surgical Admission Time Before Surgery_Minutes': np.float64(1.0),
#   'Actual Surgery Room Entry Time_Minutes': np.float64(1.0),
#   'Incision Time_Minutes': np.float64(1.0),
#   'Closure Time_Minutes': np.float64(1.0),
#   'End of Surgery Time (Exit from OR)_Minutes': np.float64(1.0),
#   'Recovery Room Entry Time_Minutes': np.float64(1.0),
#   'Recovery Room Exit Time_Minutes': np.float64(1.0),
#   'Post-Surgery Discharge Time_Minutes': np.float64(1.0),
#   'Planned Start Time for Doctor Block_Minutes': np.float64(1.0),
#   'Planned End Time for Doctor Block_Minutes': np.float64(1.0)}}

# %%
p_values_df = pd.DataFrame(p_values).T
p_values_df <= 0.05 #in a comparison of all the variables with the variables with under 40% missing values
p_values_df
# Out:
#                                                     patient_id  Site Code  \
# Pre-Surgical Admission Time Before Surgery             0.49776        1.0
# Pre-Surgical Admission Time Before Surgery_Minutes     0.49776        1.0
# Recovery Room Entry Date                               0.49776        1.0
# Recovery Room Exit Time                                0.49776        1.0
# Recovery Room Entry Time                               0.49776        1.0
# Recovery Room Entry Time_Minutes                       0.49776        1.0
# Recovery Room Exit Time_Minutes                        0.49776        1.0
# Recovery Room Exit Date                                0.49776        1.0
# End of Surgery Time (Exit from OR)                     0.49776        1.0
# Actual Surgery Room Entry Time                         0.49776        1.0
# End of Surgery Time (Exit from OR)_Minutes             0.49776        1.0
# Actual Surgery Room Entry Time_Minutes                 0.49776        1.0
# Planned Start Date for Doctor Block                    0.49776        1.0
# Planned End Date for Doctor Block                      0.49776        1.0
# Planned Start Time for Doctor Block                    0.49776        1.0
# Planned Start Time for Doctor Block_Minutes            0.49776        1.0
# Planned End Time for Doctor Block_Minutes              0.49776        1.0
# Planned End Time for Doctor Block                      0.49776        1.0
# Planned Surgery Date                                   0.49776        1.0
# Planned Surgery Time                                   0.49776        1.0
# Planned Surgery Time_Minutes                           0.49776        1.0
# End of Surgery Date (Exit from OR)                     0.49776        1.0
# Actual Surgery Room Entry Date                         0.49776        1.0
# Pre-Surgery Hospitalization Admission Time             0.49776        1.0
# Pre-Surgery Hospitalization Admission Time_Minutes     0.49776        1.0
# Pre-Surgery Hospitalization Admission Date             0.49776        1.0
# Post-Surgery Discharge Time_Minutes                    0.49776        1.0
# Post-Surgery Discharge Date                            0.49776        1.0
# Post-Surgery Discharge Time                            0.49776        1.0
# Closure Time                                           0.49776        1.0
# Incision Time                                          0.49776        1.0
# Incision Time_Minutes                                  0.49776        1.0
# Closure Time_Minutes                                   0.49776        1.0
# Surgery Admission Date                                 0.49776        1.0
# Administrative Admission Time                          0.49776        1.0
# Administrative Admission Time_Minutes                  0.49776        1.0
#
#                                                     Main Surgeon Code  \
# Pre-Surgical Admission Time Before Surgery               0.000000e+00
# Pre-Surgical Admission Time Before Surgery_Minutes       0.000000e+00
# Recovery Room Entry Date                                 0.000000e+00
# Recovery Room Exit Time                                  0.000000e+00
# Recovery Room Entry Time                                 0.000000e+00
# Recovery Room Entry Time_Minutes                         0.000000e+00
# Recovery Room Exit Time_Minutes                          0.000000e+00
# Recovery Room Exit Date                                  0.000000e+00
# End of Surgery Time (Exit from OR)                       0.000000e+00
# Actual Surgery Room Entry Time                           0.000000e+00
# End of Surgery Time (Exit from OR)_Minutes               0.000000e+00
# Actual Surgery Room Entry Time_Minutes                   0.000000e+00
# Planned Start Date for Doctor Block                      0.000000e+00
# Planned End Date for Doctor Block                        0.000000e+00
# Planned Start Time for Doctor Block                      0.000000e+00
# Planned Start Time for Doctor Block_Minutes              0.000000e+00
# Planned End Time for Doctor Block_Minutes                0.000000e+00
# Planned End Time for Doctor Block                        0.000000e+00
# Planned Surgery Date                                     0.000000e+00
# Planned Surgery Time                                     0.000000e+00
# Planned Surgery Time_Minutes                             0.000000e+00
# End of Surgery Date (Exit from OR)                       0.000000e+00
# Actual Surgery Room Entry Date                           0.000000e+00
# Pre-Surgery Hospitalization Admission Time              1.517101e-291
# Pre-Surgery Hospitalization Admission Time_Minutes      1.517101e-291
# Pre-Surgery Hospitalization Admission Date              1.517101e-291
# Post-Surgery Discharge Time_Minutes                     1.517101e-291
# Post-Surgery Discharge Date                             1.517101e-291
# Post-Surgery Discharge Time                             1.517101e-291
# Closure Time                                             0.000000e+00
# Incision Time                                            0.000000e+00
# Incision Time_Minutes                                    0.000000e+00
# Closure Time_Minutes                                     0.000000e+00
# Surgery Admission Date                                   0.000000e+00
# Administrative Admission Time                            1.000000e+00
# Administrative Admission Time_Minutes                    1.000000e+00
#
#                                                     Activity Code  \
# Pre-Surgical Admission Time Before Surgery           0.000000e+00
# Pre-Surgical Admission Time Before Surgery_Minutes   0.000000e+00
# Recovery Room Entry Date                             0.000000e+00
# Recovery Room Exit Time                              0.000000e+00
# Recovery Room Entry Time                             0.000000e+00
# Recovery Room Entry Time_Minutes                     0.000000e+00
# Recovery Room Exit Time_Minutes                      0.000000e+00
# Recovery Room Exit Date                              0.000000e+00
# End of Surgery Time (Exit from OR)                   0.000000e+00
# Actual Surgery Room Entry Time                       0.000000e+00
# End of Surgery Time (Exit from OR)_Minutes           0.000000e+00
# Actual Surgery Room Entry Time_Minutes               0.000000e+00
# Planned Start Date for Doctor Block                  0.000000e+00
# Planned End Date for Doctor Block                    0.000000e+00
# Planned Start Time for Doctor Block                  0.000000e+00
# Planned Start Time for Doctor Block_Minutes          0.000000e+00
# Planned End Time for Doctor Block_Minutes            0.000000e+00
# Planned End Time for Doctor Block                    0.000000e+00
# Planned Surgery Date                                 0.000000e+00
# Planned Surgery Time                                 0.000000e+00
# Planned Surgery Time_Minutes                         0.000000e+00
# End of Surgery Date (Exit from OR)                   0.000000e+00
# Actual Surgery Room Entry Date                       0.000000e+00
# Pre-Surgery Hospitalization Admission Time          1.287610e-135
# Pre-Surgery Hospitalization Admission Time_Minutes  1.287610e-135
# Pre-Surgery Hospitalization Admission Date          1.287610e-135
# Post-Surgery Discharge Time_Minutes                 1.287610e-135
# Post-Surgery Discharge Date                         1.287610e-135
# Post-Surgery Discharge Time                         1.287610e-135
# Closure Time                                        2.847249e-262
# Incision Time                                       2.847249e-262
# Incision Time_Minutes                               2.847249e-262
# Closure Time_Minutes                                2.847249e-262
# Surgery Admission Date                               0.000000e+00
# Administrative Admission Time                        1.808427e-67
# Administrative Admission Time_Minutes                1.808427e-67
#
#                                                     Activity Type Code  \
# Pre-Surgical Admission Time Before Surgery                0.000000e+00
# Pre-Surgical Admission Time Before Surgery_Minutes        0.000000e+00
# Recovery Room Entry Date                                  0.000000e+00
# Recovery Room Exit Time                                   0.000000e+00
# Recovery Room Entry Time                                  0.000000e+00
# Recovery Room Entry Time_Minutes                          0.000000e+00
# Recovery Room Exit Time_Minutes                           0.000000e+00
# Recovery Room Exit Date                                   0.000000e+00
# End of Surgery Time (Exit from OR)                        0.000000e+00
# Actual Surgery Room Entry Time                            0.000000e+00
# End of Surgery Time (Exit from OR)_Minutes                0.000000e+00
# Actual Surgery Room Entry Time_Minutes                    0.000000e+00
# Planned Start Date for Doctor Block                       0.000000e+00
# Planned End Date for Doctor Block                         0.000000e+00
# Planned Start Time for Doctor Block                       0.000000e+00
# Planned Start Time for Doctor Block_Minutes               0.000000e+00
# Planned End Time for Doctor Block_Minutes                 0.000000e+00
# Planned End Time for Doctor Block                         0.000000e+00
# Planned Surgery Date                                      0.000000e+00
# Planned Surgery Time                                      0.000000e+00
# Planned Surgery Time_Minutes                              0.000000e+00
# End of Surgery Date (Exit from OR)                        0.000000e+00
# Actual Surgery Room Entry Date                            0.000000e+00
# Pre-Surgery Hospitalization Admission Time               7.030393e-187
# Pre-Surgery Hospitalization Admission Time_Minutes       7.030393e-187
# Pre-Surgery Hospitalization Admission Date               7.030393e-187
# Post-Surgery Discharge Time_Minutes                      7.030393e-187
# Post-Surgery Discharge Date                              7.030393e-187
# Post-Surgery Discharge Time                              7.030393e-187
# Closure Time                                             2.917414e-305
# Incision Time                                            2.917414e-305
# Incision Time_Minutes                                    2.917414e-305
# Closure Time_Minutes                                     2.917414e-305
# Surgery Admission Date                                    0.000000e+00
# Administrative Admission Time                             1.037508e-70
# Administrative Admission Time_Minutes                     1.037508e-70
#
#                                                     Planned SU Time (Large/Medium/Small)  \
# Pre-Surgical Admission Time Before Surgery                                  0.000000e+00
# Pre-Surgical Admission Time Before Surgery_Minutes                          0.000000e+00
# Recovery Room Entry Date                                                    0.000000e+00
# Recovery Room Exit Time                                                     0.000000e+00
# Recovery Room Entry Time                                                    0.000000e+00
# Recovery Room Entry Time_Minutes                                            0.000000e+00
# Recovery Room Exit Time_Minutes                                             0.000000e+00
# Recovery Room Exit Date                                                     0.000000e+00
# End of Surgery Time (Exit from OR)                                          0.000000e+00
# Actual Surgery Room Entry Time                                              0.000000e+00
# End of Surgery Time (Exit from OR)_Minutes                                  0.000000e+00
# Actual Surgery Room Entry Time_Minutes                                      0.000000e+00
# Planned Start Date for Doctor Block                                         1.864870e-40
# Planned End Date for Doctor Block                                           1.864870e-40
# Planned Start Time for Doctor Block                                         2.889842e-40
# Planned Start Time for Doctor Block_Minutes                                 2.889842e-40
# Planned End Time for Doctor Block_Minutes                                   2.889842e-40
# Planned End Time for Doctor Block                                           2.889842e-40
# Planned Surgery Date                                                        2.451496e-40
# Planned Surgery Time                                                        3.805521e-40
# Planned Surgery Time_Minutes                                                3.805521e-40
# End of Surgery Date (Exit from OR)                                         2.977708e-182
# Actual Surgery Room Entry Date                                             2.977708e-182
# Pre-Surgery Hospitalization Admission Time                                  7.732076e-03
# Pre-Surgery Hospitalization Admission Time_Minutes                          7.732076e-03
# Pre-Surgery Hospitalization Admission Date                                  7.732076e-03
# Post-Surgery Discharge Time_Minutes                                         7.732076e-03
# Post-Surgery Discharge Date                                                 7.732076e-03
# Post-Surgery Discharge Time                                                 7.732076e-03
# Closure Time                                                                7.343358e-01
# Incision Time                                                               7.343358e-01
# Incision Time_Minutes                                                       7.343358e-01
# Closure Time_Minutes                                                        7.343358e-01
# Surgery Admission Date                                                      9.999194e-01
# Administrative Admission Time                                               1.000000e+00
# Administrative Admission Time_Minutes                                       1.000000e+00
#
#                                                     Pre-Surgery Patient File (External)  \
# Pre-Surgical Admission Time Before Surgery                                          1.0
# Pre-Surgical Admission Time Before Surgery_Minutes                                  1.0
# Recovery Room Entry Date                                                            1.0
# Recovery Room Exit Time                                                             1.0
# Recovery Room Entry Time                                                            1.0
# Recovery Room Entry Time_Minutes                                                    1.0
# Recovery Room Exit Time_Minutes                                                     1.0
# Recovery Room Exit Date                                                             1.0
# End of Surgery Time (Exit from OR)                                                  1.0
# Actual Surgery Room Entry Time                                                      1.0
# End of Surgery Time (Exit from OR)_Minutes                                          1.0
# Actual Surgery Room Entry Time_Minutes                                              1.0
# Planned Start Date for Doctor Block                                                 1.0
# Planned End Date for Doctor Block                                                   1.0
# Planned Start Time for Doctor Block                                                 1.0
# Planned Start Time for Doctor Block_Minutes                                         1.0
# Planned End Time for Doctor Block_Minutes                                           1.0
# Planned End Time for Doctor Block                                                   1.0
# Planned Surgery Date                                                                1.0
# Planned Surgery Time                                                                1.0
# Planned Surgery Time_Minutes                                                        1.0
# End of Surgery Date (Exit from OR)                                                  1.0
# Actual Surgery Room Entry Date                                                      1.0
# Pre-Surgery Hospitalization Admission Time                                          1.0
# Pre-Surgery Hospitalization Admission Time_Minutes                                  1.0
# Pre-Surgery Hospitalization Admission Date                                          1.0
# Post-Surgery Discharge Time_Minutes                                                 1.0
# Post-Surgery Discharge Date                                                         1.0
# Post-Surgery Discharge Time                                                         1.0
# Closure Time                                                                        1.0
# Incision Time                                                                       1.0
# Incision Time_Minutes                                                               1.0
# Closure Time_Minutes                                                                1.0
# Surgery Admission Date                                                              1.0
# Administrative Admission Time                                                       0.0
# Administrative Admission Time_Minutes                                               0.0
#
#                                                     Pre-Surgery Admission Date  \
# Pre-Surgical Admission Time Before Surgery                                 1.0
# Pre-Surgical Admission Time Before Surgery_Minutes                         1.0
# Recovery Room Entry Date                                                   1.0
# Recovery Room Exit Time                                                    1.0
# Recovery Room Entry Time                                                   1.0
# Recovery Room Entry Time_Minutes                                           1.0
# Recovery Room Exit Time_Minutes                                            1.0
# Recovery Room Exit Date                                                    1.0
# End of Surgery Time (Exit from OR)                                         1.0
# Actual Surgery Room Entry Time                                             1.0
# End of Surgery Time (Exit from OR)_Minutes                                 1.0
# Actual Surgery Room Entry Time_Minutes                                     1.0
# Planned Start Date for Doctor Block                                        1.0
# Planned End Date for Doctor Block                                          1.0
# Planned Start Time for Doctor Block                                        1.0
# Planned Start Time for Doctor Block_Minutes                                1.0
# Planned End Time for Doctor Block_Minutes                                  1.0
# Planned End Time for Doctor Block                                          1.0
# Planned Surgery Date                                                       1.0
# Planned Surgery Time                                                       1.0
# Planned Surgery Time_Minutes                                               1.0
# End of Surgery Date (Exit from OR)                                         1.0
# Actual Surgery Room Entry Date                                             1.0
# Pre-Surgery Hospitalization Admission Time                                 1.0
# Pre-Surgery Hospitalization Admission Time_Minutes                         1.0
# Pre-Surgery Hospitalization Admission Date                                 1.0
# Post-Surgery Discharge Time_Minutes                                        1.0
# Post-Surgery Discharge Date                                                1.0
# Post-Surgery Discharge Time                                                1.0
# Closure Time                                                               1.0
# Incision Time                                                              1.0
# Incision Time_Minutes                                                      1.0
# Closure Time_Minutes                                                       1.0
# Surgery Admission Date                                                     1.0
# Administrative Admission Time                                              1.0
# Administrative Admission Time_Minutes                                      1.0
#
#                                                            Height  \
# Pre-Surgical Admission Time Before Surgery          1.397998e-304
# Pre-Surgical Admission Time Before Surgery_Minutes  1.397998e-304
# Recovery Room Entry Date                             1.116652e-15
# Recovery Room Exit Time                              1.116652e-15
# Recovery Room Entry Time                             1.116652e-15
# Recovery Room Entry Time_Minutes                     1.116652e-15
# Recovery Room Exit Time_Minutes                      1.116652e-15
# Recovery Room Exit Date                              1.116652e-15
# End of Surgery Time (Exit from OR)                   2.232491e-04
# Actual Surgery Room Entry Time                       2.232491e-04
# End of Surgery Time (Exit from OR)_Minutes           2.232491e-04
# Actual Surgery Room Entry Time_Minutes               2.232491e-04
# Planned Start Date for Doctor Block                  4.727515e-01
# Planned End Date for Doctor Block                    4.727515e-01
# Planned Start Time for Doctor Block                  4.647851e-01
# Planned Start Time for Doctor Block_Minutes          4.647851e-01
# Planned End Time for Doctor Block_Minutes            4.647851e-01
# Planned End Time for Doctor Block                    4.647851e-01
# Planned Surgery Date                                 4.486530e-01
# Planned Surgery Time                                 4.409039e-01
# Planned Surgery Time_Minutes                         4.409039e-01
# End of Surgery Date (Exit from OR)                   6.817544e-01
# Actual Surgery Room Entry Date                       6.817544e-01
# Pre-Surgery Hospitalization Admission Time           9.999289e-01
# Pre-Surgery Hospitalization Admission Time_Minutes   9.999289e-01
# Pre-Surgery Hospitalization Admission Date           9.999289e-01
# Post-Surgery Discharge Time_Minutes                  9.999289e-01
# Post-Surgery Discharge Date                          9.999289e-01
# Post-Surgery Discharge Time                          9.999289e-01
# Closure Time                                         9.999407e-01
# Incision Time                                        9.999407e-01
# Incision Time_Minutes                                9.999407e-01
# Closure Time_Minutes                                 9.999407e-01
# Surgery Admission Date                               1.000000e+00
# Administrative Admission Time                        1.000000e+00
# Administrative Admission Time_Minutes                1.000000e+00
#
#                                                            Weight  ...  \
# Pre-Surgical Admission Time Before Surgery          1.115166e-169  ...
# Pre-Surgical Admission Time Before Surgery_Minutes  1.115166e-169  ...
# Recovery Room Entry Date                             4.178327e-15  ...
# Recovery Room Exit Time                              4.178327e-15  ...
# Recovery Room Entry Time                             4.178327e-15  ...
# Recovery Room Entry Time_Minutes                     4.178327e-15  ...
# Recovery Room Exit Time_Minutes                      4.178327e-15  ...
# Recovery Room Exit Date                              4.178327e-15  ...
# End of Surgery Time (Exit from OR)                   4.128863e-03  ...
# Actual Surgery Room Entry Time                       4.128863e-03  ...
# End of Surgery Time (Exit from OR)_Minutes           4.128863e-03  ...
# Actual Surgery Room Entry Time_Minutes               4.128863e-03  ...
# Planned Start Date for Doctor Block                  7.706044e-01  ...
# Planned End Date for Doctor Block                    7.706044e-01  ...
# Planned Start Time for Doctor Block                  7.616118e-01  ...
# Planned Start Time for Doctor Block_Minutes          7.616118e-01  ...
# Planned End Time for Doctor Block_Minutes            7.616118e-01  ...
# Planned End Time for Doctor Block                    7.616118e-01  ...
# Planned Surgery Date                                 7.266534e-01  ...
# Planned Surgery Time                                 7.173432e-01  ...
# Planned Surgery Time_Minutes                         7.173432e-01  ...
# End of Surgery Date (Exit from OR)                   7.733831e-01  ...
# Actual Surgery Room Entry Date                       7.733831e-01  ...
# Pre-Surgery Hospitalization Admission Time           9.990542e-01  ...
# Pre-Surgery Hospitalization Admission Time_Minutes   9.990542e-01  ...
# Pre-Surgery Hospitalization Admission Date           9.990542e-01  ...
# Post-Surgery Discharge Time_Minutes                  9.990542e-01  ...
# Post-Surgery Discharge Date                          9.990542e-01  ...
# Post-Surgery Discharge Time                          9.990542e-01  ...
# Closure Time                                         9.990196e-01  ...
# Incision Time                                        9.990196e-01  ...
# Incision Time_Minutes                                9.990196e-01  ...
# Closure Time_Minutes                                 9.990196e-01  ...
# Surgery Admission Date                               1.000000e+00  ...
# Administrative Admission Time                        1.000000e+00  ...
# Administrative Admission Time_Minutes                1.000000e+00  ...
#
#                                                     Pre-Surgical Admission Time Before Surgery_Minutes  \
# Pre-Surgical Admission Time Before Surgery                                                   1.000000
# Pre-Surgical Admission Time Before Surgery_Minutes                                                NaN
# Recovery Room Entry Date                                                                     0.585526
# Recovery Room Exit Time                                                                      0.585526
# Recovery Room Entry Time                                                                     0.585526
# Recovery Room Entry Time_Minutes                                                             0.585526
# Recovery Room Exit Time_Minutes                                                              0.585526
# Recovery Room Exit Date                                                                      0.585526
# End of Surgery Time (Exit from OR)                                                           1.000000
# Actual Surgery Room Entry Time                                                               1.000000
# End of Surgery Time (Exit from OR)_Minutes                                                   1.000000
# Actual Surgery Room Entry Time_Minutes                                                       1.000000
# Planned Start Date for Doctor Block                                                          0.660979
# Planned End Date for Doctor Block                                                            0.660979
# Planned Start Time for Doctor Block                                                          0.660979
# Planned Start Time for Doctor Block_Minutes                                                  0.660979
# Planned End Time for Doctor Block_Minutes                                                    0.660979
# Planned End Time for Doctor Block                                                            0.660979
# Planned Surgery Date                                                                         0.680633
# Planned Surgery Time                                                                         0.680633
# Planned Surgery Time_Minutes                                                                 0.680633
# End of Surgery Date (Exit from OR)                                                           1.000000
# Actual Surgery Room Entry Date                                                               1.000000
# Pre-Surgery Hospitalization Admission Time                                                   1.000000
# Pre-Surgery Hospitalization Admission Time_Minutes                                           1.000000
# Pre-Surgery Hospitalization Admission Date                                                   1.000000
# Post-Surgery Discharge Time_Minutes                                                          1.000000
# Post-Surgery Discharge Date                                                                  1.000000
# Post-Surgery Discharge Time                                                                  1.000000
# Closure Time                                                                                 1.000000
# Incision Time                                                                                1.000000
# Incision Time_Minutes                                                                        1.000000
# Closure Time_Minutes                                                                         1.000000
# Surgery Admission Date                                                                       1.000000
# Administrative Admission Time                                                                1.000000
# Administrative Admission Time_Minutes                                                        1.000000
#
#                                                     Actual Surgery Room Entry Time_Minutes  \
# Pre-Surgical Admission Time Before Surgery                                    1.643903e-32
# Pre-Surgical Admission Time Before Surgery_Minutes                            1.643903e-32
# Recovery Room Entry Date                                                      1.358446e-01
# Recovery Room Exit Time                                                       1.358446e-01
# Recovery Room Entry Time                                                      1.358446e-01
# Recovery Room Entry Time_Minutes                                              1.358446e-01
# Recovery Room Exit Time_Minutes                                               1.358446e-01
# Recovery Room Exit Date                                                       1.358446e-01
# End of Surgery Time (Exit from OR)                                            1.000000e+00
# Actual Surgery Room Entry Time                                                1.000000e+00
# End of Surgery Time (Exit from OR)_Minutes                                    1.000000e+00
# Actual Surgery Room Entry Time_Minutes                                                 NaN
# Planned Start Date for Doctor Block                                           4.660816e-01
# Planned End Date for Doctor Block                                             4.660816e-01
# Planned Start Time for Doctor Block                                           4.660816e-01
# Planned Start Time for Doctor Block_Minutes                                   4.660816e-01
# Planned End Time for Doctor Block_Minutes                                     4.660816e-01
# Planned End Time for Doctor Block                                             4.660816e-01
# Planned Surgery Date                                                          5.147744e-01
# Planned Surgery Time                                                          5.147744e-01
# Planned Surgery Time_Minutes                                                  5.147744e-01
# End of Surgery Date (Exit from OR)                                            1.000000e+00
# Actual Surgery Room Entry Date                                                1.000000e+00
# Pre-Surgery Hospitalization Admission Time                                    1.000000e+00
# Pre-Surgery Hospitalization Admission Time_Minutes                            1.000000e+00
# Pre-Surgery Hospitalization Admission Date                                    1.000000e+00
# Post-Surgery Discharge Time_Minutes                                           1.000000e+00
# Post-Surgery Discharge Date                                                   1.000000e+00
# Post-Surgery Discharge Time                                                   1.000000e+00
# Closure Time                                                                  1.000000e+00
# Incision Time                                                                 1.000000e+00
# Incision Time_Minutes                                                         1.000000e+00
# Closure Time_Minutes                                                          1.000000e+00
# Surgery Admission Date                                                        1.000000e+00
# Administrative Admission Time                                                 1.000000e+00
# Administrative Admission Time_Minutes                                         1.000000e+00
#
#                                                     Incision Time_Minutes  \
# Pre-Surgical Admission Time Before Surgery                   2.115445e-36
# Pre-Surgical Admission Time Before Surgery_Minutes           2.115445e-36
# Recovery Room Entry Date                                     2.537969e-09
# Recovery Room Exit Time                                      2.537969e-09
# Recovery Room Entry Time                                     2.537969e-09
# Recovery Room Entry Time_Minutes                             2.537969e-09
# Recovery Room Exit Time_Minutes                              2.537969e-09
# Recovery Room Exit Date                                      2.537969e-09
# End of Surgery Time (Exit from OR)                           7.238849e-04
# Actual Surgery Room Entry Time                               7.238849e-04
# End of Surgery Time (Exit from OR)_Minutes                   7.238849e-04
# Actual Surgery Room Entry Time_Minutes                       7.238849e-04
# Planned Start Date for Doctor Block                          3.323383e-03
# Planned End Date for Doctor Block                            3.323383e-03
# Planned Start Time for Doctor Block                          3.323383e-03
# Planned Start Time for Doctor Block_Minutes                  3.323383e-03
# Planned End Time for Doctor Block_Minutes                    3.323383e-03
# Planned End Time for Doctor Block                            3.323383e-03
# Planned Surgery Date                                         3.664000e-03
# Planned Surgery Time                                         3.664000e-03
# Planned Surgery Time_Minutes                                 3.664000e-03
# End of Surgery Date (Exit from OR)                           1.526784e-01
# Actual Surgery Room Entry Date                               1.526784e-01
# Pre-Surgery Hospitalization Admission Time                   1.000000e+00
# Pre-Surgery Hospitalization Admission Time_Minutes           1.000000e+00
# Pre-Surgery Hospitalization Admission Date                   1.000000e+00
# Post-Surgery Discharge Time_Minutes                          1.000000e+00
# Post-Surgery Discharge Date                                  1.000000e+00
# Post-Surgery Discharge Time                                  1.000000e+00
# Closure Time                                                 1.000000e+00
# Incision Time                                                1.000000e+00
# Incision Time_Minutes                                                 NaN
# Closure Time_Minutes                                         1.000000e+00
# Surgery Admission Date                                       1.000000e+00
# Administrative Admission Time                                1.000000e+00
# Administrative Admission Time_Minutes                        1.000000e+00
#
#                                                     Closure Time_Minutes  \
# Pre-Surgical Admission Time Before Surgery                  5.361688e-49
# Pre-Surgical Admission Time Before Surgery_Minutes          5.361688e-49
# Recovery Room Entry Date                                    9.207276e-10
# Recovery Room Exit Time                                     9.207276e-10
# Recovery Room Entry Time                                    9.207276e-10
# Recovery Room Entry Time_Minutes                            9.207276e-10
# Recovery Room Exit Time_Minutes                             9.207276e-10
# Recovery Room Exit Date                                     9.207276e-10
# End of Surgery Time (Exit from OR)                          2.682827e-03
# Actual Surgery Room Entry Time                              2.682827e-03
# End of Surgery Time (Exit from OR)_Minutes                  2.682827e-03
# Actual Surgery Room Entry Time_Minutes                      2.682827e-03
# Planned Start Date for Doctor Block                         3.853226e-03
# Planned End Date for Doctor Block                           3.853226e-03
# Planned Start Time for Doctor Block                         3.853226e-03
# Planned Start Time for Doctor Block_Minutes                 3.853226e-03
# Planned End Time for Doctor Block_Minutes                   3.853226e-03
# Planned End Time for Doctor Block                           3.853226e-03
# Planned Surgery Date                                        4.227891e-03
# Planned Surgery Time                                        4.227891e-03
# Planned Surgery Time_Minutes                                4.227891e-03
# End of Surgery Date (Exit from OR)                          2.315591e-01
# Actual Surgery Room Entry Date                              2.315591e-01
# Pre-Surgery Hospitalization Admission Time                  1.000000e+00
# Pre-Surgery Hospitalization Admission Time_Minutes          1.000000e+00
# Pre-Surgery Hospitalization Admission Date                  1.000000e+00
# Post-Surgery Discharge Time_Minutes                         1.000000e+00
# Post-Surgery Discharge Date                                 1.000000e+00
# Post-Surgery Discharge Time                                 1.000000e+00
# Closure Time                                                1.000000e+00
# Incision Time                                               1.000000e+00
# Incision Time_Minutes                                       1.000000e+00
# Closure Time_Minutes                                                 NaN
# Surgery Admission Date                                      1.000000e+00
# Administrative Admission Time                               1.000000e+00
# Administrative Admission Time_Minutes                       1.000000e+00
#
#                                                     End of Surgery Time (Exit from OR)_Minutes  \
# Pre-Surgical Admission Time Before Surgery                                        3.553741e-49
# Pre-Surgical Admission Time Before Surgery_Minutes                                3.553741e-49
# Recovery Room Entry Date                                                          2.630497e-01
# Recovery Room Exit Time                                                           2.630497e-01
# Recovery Room Entry Time                                                          2.630497e-01
# Recovery Room Entry Time_Minutes                                                  2.630497e-01
# Recovery Room Exit Time_Minutes                                                   2.630497e-01
# Recovery Room Exit Date                                                           2.630497e-01
# End of Surgery Time (Exit from OR)                                                1.000000e+00
# Actual Surgery Room Entry Time                                                    1.000000e+00
# End of Surgery Time (Exit from OR)_Minutes                                                 NaN
# Actual Surgery Room Entry Time_Minutes                                            1.000000e+00
# Planned Start Date for Doctor Block                                               2.717213e-01
# Planned End Date for Doctor Block                                                 2.717213e-01
# Planned Start Time for Doctor Block                                               2.717213e-01
# Planned Start Time for Doctor Block_Minutes                                       2.717213e-01
# Planned End Time for Doctor Block_Minutes                                         2.717213e-01
# Planned End Time for Doctor Block                                                 2.717213e-01
# Planned Surgery Date                                                              3.026562e-01
# Planned Surgery Time                                                              3.026562e-01
# Planned Surgery Time_Minutes                                                      3.026562e-01
# End of Surgery Date (Exit from OR)                                                1.000000e+00
# Actual Surgery Room Entry Date                                                    1.000000e+00
# Pre-Surgery Hospitalization Admission Time                                        1.000000e+00
# Pre-Surgery Hospitalization Admission Time_Minutes                                1.000000e+00
# Pre-Surgery Hospitalization Admission Date                                        1.000000e+00
# Post-Surgery Discharge Time_Minutes                                               1.000000e+00
# Post-Surgery Discharge Date                                                       1.000000e+00
# Post-Surgery Discharge Time                                                       1.000000e+00
# Closure Time                                                                      1.000000e+00
# Incision Time                                                                     1.000000e+00
# Incision Time_Minutes                                                             1.000000e+00
# Closure Time_Minutes                                                              1.000000e+00
# Surgery Admission Date                                                            1.000000e+00
# Administrative Admission Time                                                     1.000000e+00
# Administrative Admission Time_Minutes                                             1.000000e+00
#
#                                                     Recovery Room Entry Time_Minutes  \
# Pre-Surgical Admission Time Before Surgery                              1.213027e-58
# Pre-Surgical Admission Time Before Surgery_Minutes                      1.213027e-58
# Recovery Room Entry Date                                                1.000000e+00
# Recovery Room Exit Time                                                 1.000000e+00
# Recovery Room Entry Time                                                1.000000e+00
# Recovery Room Entry Time_Minutes                                                 NaN
# Recovery Room Exit Time_Minutes                                         1.000000e+00
# Recovery Room Exit Date                                                 1.000000e+00
# End of Surgery Time (Exit from OR)                                      1.905648e-02
# Actual Surgery Room Entry Time                                          1.905648e-02
# End of Surgery Time (Exit from OR)_Minutes                              1.905648e-02
# Actual Surgery Room Entry Time_Minutes                                  1.905648e-02
# Planned Start Date for Doctor Block                                     9.503863e-01
# Planned End Date for Doctor Block                                       9.503863e-01
# Planned Start Time for Doctor Block                                     9.503863e-01
# Planned Start Time for Doctor Block_Minutes                             9.503863e-01
# Planned End Time for Doctor Block_Minutes                               9.503863e-01
# Planned End Time for Doctor Block                                       9.503863e-01
# Planned Surgery Date                                                    9.713644e-01
# Planned Surgery Time                                                    9.713644e-01
# Planned Surgery Time_Minutes                                            9.713644e-01
# End of Surgery Date (Exit from OR)                                      9.859919e-01
# Actual Surgery Room Entry Date                                          9.859919e-01
# Pre-Surgery Hospitalization Admission Time                              1.000000e+00
# Pre-Surgery Hospitalization Admission Time_Minutes                      1.000000e+00
# Pre-Surgery Hospitalization Admission Date                              1.000000e+00
# Post-Surgery Discharge Time_Minutes                                     1.000000e+00
# Post-Surgery Discharge Date                                             1.000000e+00
# Post-Surgery Discharge Time                                             1.000000e+00
# Closure Time                                                            1.000000e+00
# Incision Time                                                           1.000000e+00
# Incision Time_Minutes                                                   1.000000e+00
# Closure Time_Minutes                                                    1.000000e+00
# Surgery Admission Date                                                  1.000000e+00
# Administrative Admission Time                                           1.000000e+00
# Administrative Admission Time_Minutes                                   1.000000e+00
#
#                                                     Recovery Room Exit Time_Minutes  \
# Pre-Surgical Admission Time Before Surgery                             4.286215e-44
# Pre-Surgical Admission Time Before Surgery_Minutes                     4.286215e-44
# Recovery Room Entry Date                                               1.000000e+00
# Recovery Room Exit Time                                                1.000000e+00
# Recovery Room Entry Time                                               1.000000e+00
# Recovery Room Entry Time_Minutes                                       1.000000e+00
# Recovery Room Exit Time_Minutes                                                 NaN
# Recovery Room Exit Date                                                1.000000e+00
# End of Surgery Time (Exit from OR)                                     1.481763e-02
# Actual Surgery Room Entry Time                                         1.481763e-02
# End of Surgery Time (Exit from OR)_Minutes                             1.481763e-02
# Actual Surgery Room Entry Time_Minutes                                 1.481763e-02
# Planned Start Date for Doctor Block                                    9.986843e-01
# Planned End Date for Doctor Block                                      9.986843e-01
# Planned Start Time for Doctor Block                                    9.986843e-01
# Planned Start Time for Doctor Block_Minutes                            9.986843e-01
# Planned End Time for Doctor Block_Minutes                              9.986843e-01
# Planned End Time for Doctor Block                                      9.986843e-01
# Planned Surgery Date                                                   9.997091e-01
# Planned Surgery Time                                                   9.997091e-01
# Planned Surgery Time_Minutes                                           9.997091e-01
# End of Surgery Date (Exit from OR)                                     9.871882e-01
# Actual Surgery Room Entry Date                                         9.871882e-01
# Pre-Surgery Hospitalization Admission Time                             1.000000e+00
# Pre-Surgery Hospitalization Admission Time_Minutes                     1.000000e+00
# Pre-Surgery Hospitalization Admission Date                             1.000000e+00
# Post-Surgery Discharge Time_Minutes                                    1.000000e+00
# Post-Surgery Discharge Date                                            1.000000e+00
# Post-Surgery Discharge Time                                            1.000000e+00
# Closure Time                                                           1.000000e+00
# Incision Time                                                          1.000000e+00
# Incision Time_Minutes                                                  1.000000e+00
# Closure Time_Minutes                                                   1.000000e+00
# Surgery Admission Date                                                 1.000000e+00
# Administrative Admission Time                                          1.000000e+00
# Administrative Admission Time_Minutes                                  1.000000e+00
#
#                                                     Post-Surgery Discharge Time_Minutes  \
# Pre-Surgical Admission Time Before Surgery                                 4.255117e-12
# Pre-Surgical Admission Time Before Surgery_Minutes                         4.255117e-12
# Recovery Room Entry Date                                                   6.571643e-04
# Recovery Room Exit Time                                                    6.571643e-04
# Recovery Room Entry Time                                                   6.571643e-04
# Recovery Room Entry Time_Minutes                                           6.571643e-04
# Recovery Room Exit Time_Minutes                                            6.571643e-04
# Recovery Room Exit Date                                                    6.571643e-04
# End of Surgery Time (Exit from OR)                                         1.571218e-02
# Actual Surgery Room Entry Time                                             1.571218e-02
# End of Surgery Time (Exit from OR)_Minutes                                 1.571218e-02
# Actual Surgery Room Entry Time_Minutes                                     1.571218e-02
# Planned Start Date for Doctor Block                                        7.117257e-01
# Planned End Date for Doctor Block                                          7.117257e-01
# Planned Start Time for Doctor Block                                        7.117257e-01
# Planned Start Time for Doctor Block_Minutes                                7.117257e-01
# Planned End Time for Doctor Block_Minutes                                  7.117257e-01
# Planned End Time for Doctor Block                                          7.117257e-01
# Planned Surgery Date                                                       7.027104e-01
# Planned Surgery Time                                                       7.027104e-01
# Planned Surgery Time_Minutes                                               7.027104e-01
# End of Surgery Date (Exit from OR)                                         8.602670e-01
# Actual Surgery Room Entry Date                                             8.602670e-01
# Pre-Surgery Hospitalization Admission Time                                 1.000000e+00
# Pre-Surgery Hospitalization Admission Time_Minutes                         1.000000e+00
# Pre-Surgery Hospitalization Admission Date                                 1.000000e+00
# Post-Surgery Discharge Time_Minutes                                                 NaN
# Post-Surgery Discharge Date                                                1.000000e+00
# Post-Surgery Discharge Time                                                1.000000e+00
# Closure Time                                                               1.000000e+00
# Incision Time                                                              1.000000e+00
# Incision Time_Minutes                                                      1.000000e+00
# Closure Time_Minutes                                                       1.000000e+00
# Surgery Admission Date                                                     1.000000e+00
# Administrative Admission Time                                              1.000000e+00
# Administrative Admission Time_Minutes                                      1.000000e+00
#
#                                                     Planned Start Time for Doctor Block_Minutes  \
# Pre-Surgical Admission Time Before Surgery                                         4.541191e-77
# Pre-Surgical Admission Time Before Surgery_Minutes                                 4.541191e-77
# Recovery Room Entry Date                                                           2.732938e-06
# Recovery Room Exit Time                                                            2.732938e-06
# Recovery Room Entry Time                                                           2.732938e-06
# Recovery Room Entry Time_Minutes                                                   2.732938e-06
# Recovery Room Exit Time_Minutes                                                    2.732938e-06
# Recovery Room Exit Date                                                            2.732938e-06
# End of Surgery Time (Exit from OR)                                                 7.559313e-03
# Actual Surgery Room Entry Time                                                     7.559313e-03
# End of Surgery Time (Exit from OR)_Minutes                                         7.559313e-03
# Actual Surgery Room Entry Time_Minutes                                             7.559313e-03
# Planned Start Date for Doctor Block                                                1.000000e+00
# Planned End Date for Doctor Block                                                  1.000000e+00
# Planned Start Time for Doctor Block                                                1.000000e+00
# Planned Start Time for Doctor Block_Minutes                                                 NaN
# Planned End Time for Doctor Block_Minutes                                          1.000000e+00
# Planned End Time for Doctor Block                                                  1.000000e+00
# Planned Surgery Date                                                               1.000000e+00
# Planned Surgery Time                                                               1.000000e+00
# Planned Surgery Time_Minutes                                                       1.000000e+00
# End of Surgery Date (Exit from OR)                                                 1.000000e+00
# Actual Surgery Room Entry Date                                                     1.000000e+00
# Pre-Surgery Hospitalization Admission Time                                         1.000000e+00
# Pre-Surgery Hospitalization Admission Time_Minutes                                 1.000000e+00
# Pre-Surgery Hospitalization Admission Date                                         1.000000e+00
# Post-Surgery Discharge Time_Minutes                                                1.000000e+00
# Post-Surgery Discharge Date                                                        1.000000e+00
# Post-Surgery Discharge Time                                                        1.000000e+00
# Closure Time                                                                       1.000000e+00
# Incision Time                                                                      1.000000e+00
# Incision Time_Minutes                                                              1.000000e+00
# Closure Time_Minutes                                                               1.000000e+00
# Surgery Admission Date                                                             1.000000e+00
# Administrative Admission Time                                                      1.000000e+00
# Administrative Admission Time_Minutes                                              1.000000e+00
#
#                                                     Planned End Time for Doctor Block_Minutes
# Pre-Surgical Admission Time Before Surgery                                       1.830235e-14
# Pre-Surgical Admission Time Before Surgery_Minutes                               1.830235e-14
# Recovery Room Entry Date                                                         2.160207e-13
# Recovery Room Exit Time                                                          2.160207e-13
# Recovery Room Entry Time                                                         2.160207e-13
# Recovery Room Entry Time_Minutes                                                 2.160207e-13
# Recovery Room Exit Time_Minutes                                                  2.160207e-13
# Recovery Room Exit Date                                                          2.160207e-13
# End of Surgery Time (Exit from OR)                                               9.847256e-03
# Actual Surgery Room Entry Time                                                   9.847256e-03
# End of Surgery Time (Exit from OR)_Minutes                                       9.847256e-03
# Actual Surgery Room Entry Time_Minutes                                           9.847256e-03
# Planned Start Date for Doctor Block                                              1.000000e+00
# Planned End Date for Doctor Block                                                1.000000e+00
# Planned Start Time for Doctor Block                                              1.000000e+00
# Planned Start Time for Doctor Block_Minutes                                      1.000000e+00
# Planned End Time for Doctor Block_Minutes                                                 NaN
# Planned End Time for Doctor Block                                                1.000000e+00
# Planned Surgery Date                                                             1.000000e+00
# Planned Surgery Time                                                             1.000000e+00
# Planned Surgery Time_Minutes                                                     1.000000e+00
# End of Surgery Date (Exit from OR)                                               1.000000e+00
# Actual Surgery Room Entry Date                                                   1.000000e+00
# Pre-Surgery Hospitalization Admission Time                                       1.000000e+00
# Pre-Surgery Hospitalization Admission Time_Minutes                               1.000000e+00
# Pre-Surgery Hospitalization Admission Date                                       1.000000e+00
# Post-Surgery Discharge Time_Minutes                                              1.000000e+00
# Post-Surgery Discharge Date                                                      1.000000e+00
# Post-Surgery Discharge Time                                                      1.000000e+00
# Closure Time                                                                     1.000000e+00
# Incision Time                                                                    1.000000e+00
# Incision Time_Minutes                                                            1.000000e+00
# Closure Time_Minutes                                                             1.000000e+00
# Surgery Admission Date                                                           1.000000e+00
# Administrative Admission Time                                                    1.000000e+00
# Administrative Admission Time_Minutes                                            1.000000e+00
#
# [36 rows x 50 columns]

# %%
p_values_df = pd.DataFrame(p_values).T
p_values_df = p_values_df <= 0.05 #in a comparison of all the variables with the variables with under 40% missing values
p_values_df
# Out:
#                                                     patient_id  Site Code  \
# Pre-Surgical Admission Time Before Surgery               False      False
# Pre-Surgical Admission Time Before Surgery_Minutes       False      False
# Recovery Room Entry Date                                 False      False
# Recovery Room Exit Time                                  False      False
# Recovery Room Entry Time                                 False      False
# Recovery Room Entry Time_Minutes                         False      False
# Recovery Room Exit Time_Minutes                          False      False
# Recovery Room Exit Date                                  False      False
# End of Surgery Time (Exit from OR)                       False      False
# Actual Surgery Room Entry Time                           False      False
# End of Surgery Time (Exit from OR)_Minutes               False      False
# Actual Surgery Room Entry Time_Minutes                   False      False
# Planned Start Date for Doctor Block                      False      False
# Planned End Date for Doctor Block                        False      False
# Planned Start Time for Doctor Block                      False      False
# Planned Start Time for Doctor Block_Minutes              False      False
# Planned End Time for Doctor Block_Minutes                False      False
# Planned End Time for Doctor Block                        False      False
# Planned Surgery Date                                     False      False
# Planned Surgery Time                                     False      False
# Planned Surgery Time_Minutes                             False      False
# End of Surgery Date (Exit from OR)                       False      False
# Actual Surgery Room Entry Date                           False      False
# Pre-Surgery Hospitalization Admission Time               False      False
# Pre-Surgery Hospitalization Admission Time_Minutes       False      False
# Pre-Surgery Hospitalization Admission Date               False      False
# Post-Surgery Discharge Time_Minutes                      False      False
# Post-Surgery Discharge Date                              False      False
# Post-Surgery Discharge Time                              False      False
# Closure Time                                             False      False
# Incision Time                                            False      False
# Incision Time_Minutes                                    False      False
# Closure Time_Minutes                                     False      False
# Surgery Admission Date                                   False      False
# Administrative Admission Time                            False      False
# Administrative Admission Time_Minutes                    False      False
#
#                                                     Main Surgeon Code  \
# Pre-Surgical Admission Time Before Surgery                       True
# Pre-Surgical Admission Time Before Surgery_Minutes               True
# Recovery Room Entry Date                                         True
# Recovery Room Exit Time                                          True
# Recovery Room Entry Time                                         True
# Recovery Room Entry Time_Minutes                                 True
# Recovery Room Exit Time_Minutes                                  True
# Recovery Room Exit Date                                          True
# End of Surgery Time (Exit from OR)                               True
# Actual Surgery Room Entry Time                                   True
# End of Surgery Time (Exit from OR)_Minutes                       True
# Actual Surgery Room Entry Time_Minutes                           True
# Planned Start Date for Doctor Block                              True
# Planned End Date for Doctor Block                                True
# Planned Start Time for Doctor Block                              True
# Planned Start Time for Doctor Block_Minutes                      True
# Planned End Time for Doctor Block_Minutes                        True
# Planned End Time for Doctor Block                                True
# Planned Surgery Date                                             True
# Planned Surgery Time                                             True
# Planned Surgery Time_Minutes                                     True
# End of Surgery Date (Exit from OR)                               True
# Actual Surgery Room Entry Date                                   True
# Pre-Surgery Hospitalization Admission Time                       True
# Pre-Surgery Hospitalization Admission Time_Minutes               True
# Pre-Surgery Hospitalization Admission Date                       True
# Post-Surgery Discharge Time_Minutes                              True
# Post-Surgery Discharge Date                                      True
# Post-Surgery Discharge Time                                      True
# Closure Time                                                     True
# Incision Time                                                    True
# Incision Time_Minutes                                            True
# Closure Time_Minutes                                             True
# Surgery Admission Date                                           True
# Administrative Admission Time                                   False
# Administrative Admission Time_Minutes                           False
#
#                                                     Activity Code  \
# Pre-Surgical Admission Time Before Surgery                   True
# Pre-Surgical Admission Time Before Surgery_Minutes           True
# Recovery Room Entry Date                                     True
# Recovery Room Exit Time                                      True
# Recovery Room Entry Time                                     True
# Recovery Room Entry Time_Minutes                             True
# Recovery Room Exit Time_Minutes                              True
# Recovery Room Exit Date                                      True
# End of Surgery Time (Exit from OR)                           True
# Actual Surgery Room Entry Time                               True
# End of Surgery Time (Exit from OR)_Minutes                   True
# Actual Surgery Room Entry Time_Minutes                       True
# Planned Start Date for Doctor Block                          True
# Planned End Date for Doctor Block                            True
# Planned Start Time for Doctor Block                          True
# Planned Start Time for Doctor Block_Minutes                  True
# Planned End Time for Doctor Block_Minutes                    True
# Planned End Time for Doctor Block                            True
# Planned Surgery Date                                         True
# Planned Surgery Time                                         True
# Planned Surgery Time_Minutes                                 True
# End of Surgery Date (Exit from OR)                           True
# Actual Surgery Room Entry Date                               True
# Pre-Surgery Hospitalization Admission Time                   True
# Pre-Surgery Hospitalization Admission Time_Minutes           True
# Pre-Surgery Hospitalization Admission Date                   True
# Post-Surgery Discharge Time_Minutes                          True
# Post-Surgery Discharge Date                                  True
# Post-Surgery Discharge Time                                  True
# Closure Time                                                 True
# Incision Time                                                True
# Incision Time_Minutes                                        True
# Closure Time_Minutes                                         True
# Surgery Admission Date                                       True
# Administrative Admission Time                                True
# Administrative Admission Time_Minutes                        True
#
#                                                     Activity Type Code  \
# Pre-Surgical Admission Time Before Surgery                        True
# Pre-Surgical Admission Time Before Surgery_Minutes                True
# Recovery Room Entry Date                                          True
# Recovery Room Exit Time                                           True
# Recovery Room Entry Time                                          True
# Recovery Room Entry Time_Minutes                                  True
# Recovery Room Exit Time_Minutes                                   True
# Recovery Room Exit Date                                           True
# End of Surgery Time (Exit from OR)                                True
# Actual Surgery Room Entry Time                                    True
# End of Surgery Time (Exit from OR)_Minutes                        True
# Actual Surgery Room Entry Time_Minutes                            True
# Planned Start Date for Doctor Block                               True
# Planned End Date for Doctor Block                                 True
# Planned Start Time for Doctor Block                               True
# Planned Start Time for Doctor Block_Minutes                       True
# Planned End Time for Doctor Block_Minutes                         True
# Planned End Time for Doctor Block                                 True
# Planned Surgery Date                                              True
# Planned Surgery Time                                              True
# Planned Surgery Time_Minutes                                      True
# End of Surgery Date (Exit from OR)                                True
# Actual Surgery Room Entry Date                                    True
# Pre-Surgery Hospitalization Admission Time                        True
# Pre-Surgery Hospitalization Admission Time_Minutes                True
# Pre-Surgery Hospitalization Admission Date                        True
# Post-Surgery Discharge Time_Minutes                               True
# Post-Surgery Discharge Date                                       True
# Post-Surgery Discharge Time                                       True
# Closure Time                                                      True
# Incision Time                                                     True
# Incision Time_Minutes                                             True
# Closure Time_Minutes                                              True
# Surgery Admission Date                                            True
# Administrative Admission Time                                     True
# Administrative Admission Time_Minutes                             True
#
#                                                     Planned SU Time (Large/Medium/Small)  \
# Pre-Surgical Admission Time Before Surgery                                          True
# Pre-Surgical Admission Time Before Surgery_Minutes                                  True
# Recovery Room Entry Date                                                            True
# Recovery Room Exit Time                                                             True
# Recovery Room Entry Time                                                            True
# Recovery Room Entry Time_Minutes                                                    True
# Recovery Room Exit Time_Minutes                                                     True
# Recovery Room Exit Date                                                             True
# End of Surgery Time (Exit from OR)                                                  True
# Actual Surgery Room Entry Time                                                      True
# End of Surgery Time (Exit from OR)_Minutes                                          True
# Actual Surgery Room Entry Time_Minutes                                              True
# Planned Start Date for Doctor Block                                                 True
# Planned End Date for Doctor Block                                                   True
# Planned Start Time for Doctor Block                                                 True
# Planned Start Time for Doctor Block_Minutes                                         True
# Planned End Time for Doctor Block_Minutes                                           True
# Planned End Time for Doctor Block                                                   True
# Planned Surgery Date                                                                True
# Planned Surgery Time                                                                True
# Planned Surgery Time_Minutes                                                        True
# End of Surgery Date (Exit from OR)                                                  True
# Actual Surgery Room Entry Date                                                      True
# Pre-Surgery Hospitalization Admission Time                                          True
# Pre-Surgery Hospitalization Admission Time_Minutes                                  True
# Pre-Surgery Hospitalization Admission Date                                          True
# Post-Surgery Discharge Time_Minutes                                                 True
# Post-Surgery Discharge Date                                                         True
# Post-Surgery Discharge Time                                                         True
# Closure Time                                                                       False
# Incision Time                                                                      False
# Incision Time_Minutes                                                              False
# Closure Time_Minutes                                                               False
# Surgery Admission Date                                                             False
# Administrative Admission Time                                                      False
# Administrative Admission Time_Minutes                                              False
#
#                                                     Pre-Surgery Patient File (External)  \
# Pre-Surgical Admission Time Before Surgery                                        False
# Pre-Surgical Admission Time Before Surgery_Minutes                                False
# Recovery Room Entry Date                                                          False
# Recovery Room Exit Time                                                           False
# Recovery Room Entry Time                                                          False
# Recovery Room Entry Time_Minutes                                                  False
# Recovery Room Exit Time_Minutes                                                   False
# Recovery Room Exit Date                                                           False
# End of Surgery Time (Exit from OR)                                                False
# Actual Surgery Room Entry Time                                                    False
# End of Surgery Time (Exit from OR)_Minutes                                        False
# Actual Surgery Room Entry Time_Minutes                                            False
# Planned Start Date for Doctor Block                                               False
# Planned End Date for Doctor Block                                                 False
# Planned Start Time for Doctor Block                                               False
# Planned Start Time for Doctor Block_Minutes                                       False
# Planned End Time for Doctor Block_Minutes                                         False
# Planned End Time for Doctor Block                                                 False
# Planned Surgery Date                                                              False
# Planned Surgery Time                                                              False
# Planned Surgery Time_Minutes                                                      False
# End of Surgery Date (Exit from OR)                                                False
# Actual Surgery Room Entry Date                                                    False
# Pre-Surgery Hospitalization Admission Time                                        False
# Pre-Surgery Hospitalization Admission Time_Minutes                                False
# Pre-Surgery Hospitalization Admission Date                                        False
# Post-Surgery Discharge Time_Minutes                                               False
# Post-Surgery Discharge Date                                                       False
# Post-Surgery Discharge Time                                                       False
# Closure Time                                                                      False
# Incision Time                                                                     False
# Incision Time_Minutes                                                             False
# Closure Time_Minutes                                                              False
# Surgery Admission Date                                                            False
# Administrative Admission Time                                                      True
# Administrative Admission Time_Minutes                                              True
#
#                                                     Pre-Surgery Admission Date  \
# Pre-Surgical Admission Time Before Surgery                               False
# Pre-Surgical Admission Time Before Surgery_Minutes                       False
# Recovery Room Entry Date                                                 False
# Recovery Room Exit Time                                                  False
# Recovery Room Entry Time                                                 False
# Recovery Room Entry Time_Minutes                                         False
# Recovery Room Exit Time_Minutes                                          False
# Recovery Room Exit Date                                                  False
# End of Surgery Time (Exit from OR)                                       False
# Actual Surgery Room Entry Time                                           False
# End of Surgery Time (Exit from OR)_Minutes                               False
# Actual Surgery Room Entry Time_Minutes                                   False
# Planned Start Date for Doctor Block                                      False
# Planned End Date for Doctor Block                                        False
# Planned Start Time for Doctor Block                                      False
# Planned Start Time for Doctor Block_Minutes                              False
# Planned End Time for Doctor Block_Minutes                                False
# Planned End Time for Doctor Block                                        False
# Planned Surgery Date                                                     False
# Planned Surgery Time                                                     False
# Planned Surgery Time_Minutes                                             False
# End of Surgery Date (Exit from OR)                                       False
# Actual Surgery Room Entry Date                                           False
# Pre-Surgery Hospitalization Admission Time                               False
# Pre-Surgery Hospitalization Admission Time_Minutes                       False
# Pre-Surgery Hospitalization Admission Date                               False
# Post-Surgery Discharge Time_Minutes                                      False
# Post-Surgery Discharge Date                                              False
# Post-Surgery Discharge Time                                              False
# Closure Time                                                             False
# Incision Time                                                            False
# Incision Time_Minutes                                                    False
# Closure Time_Minutes                                                     False
# Surgery Admission Date                                                   False
# Administrative Admission Time                                            False
# Administrative Admission Time_Minutes                                    False
#
#                                                     Height  Weight  ...  \
# Pre-Surgical Admission Time Before Surgery            True    True  ...
# Pre-Surgical Admission Time Before Surgery_Minutes    True    True  ...
# Recovery Room Entry Date                              True    True  ...
# Recovery Room Exit Time                               True    True  ...
# Recovery Room Entry Time                              True    True  ...
# Recovery Room Entry Time_Minutes                      True    True  ...
# Recovery Room Exit Time_Minutes                       True    True  ...
# Recovery Room Exit Date                               True    True  ...
# End of Surgery Time (Exit from OR)                    True    True  ...
# Actual Surgery Room Entry Time                        True    True  ...
# End of Surgery Time (Exit from OR)_Minutes            True    True  ...
# Actual Surgery Room Entry Time_Minutes                True    True  ...
# Planned Start Date for Doctor Block                  False   False  ...
# Planned End Date for Doctor Block                    False   False  ...
# Planned Start Time for Doctor Block                  False   False  ...
# Planned Start Time for Doctor Block_Minutes          False   False  ...
# Planned End Time for Doctor Block_Minutes            False   False  ...
# Planned End Time for Doctor Block                    False   False  ...
# Planned Surgery Date                                 False   False  ...
# Planned Surgery Time                                 False   False  ...
# Planned Surgery Time_Minutes                         False   False  ...
# End of Surgery Date (Exit from OR)                   False   False  ...
# Actual Surgery Room Entry Date                       False   False  ...
# Pre-Surgery Hospitalization Admission Time           False   False  ...
# Pre-Surgery Hospitalization Admission Time_Minutes   False   False  ...
# Pre-Surgery Hospitalization Admission Date           False   False  ...
# Post-Surgery Discharge Time_Minutes                  False   False  ...
# Post-Surgery Discharge Date                          False   False  ...
# Post-Surgery Discharge Time                          False   False  ...
# Closure Time                                         False   False  ...
# Incision Time                                        False   False  ...
# Incision Time_Minutes                                False   False  ...
# Closure Time_Minutes                                 False   False  ...
# Surgery Admission Date                               False   False  ...
# Administrative Admission Time                        False   False  ...
# Administrative Admission Time_Minutes                False   False  ...
#
#                                                     Pre-Surgical Admission Time Before Surgery_Minutes  \
# Pre-Surgical Admission Time Before Surgery                                                      False
# Pre-Surgical Admission Time Before Surgery_Minutes                                              False
# Recovery Room Entry Date                                                                        False
# Recovery Room Exit Time                                                                         False
# Recovery Room Entry Time                                                                        False
# Recovery Room Entry Time_Minutes                                                                False
# Recovery Room Exit Time_Minutes                                                                 False
# Recovery Room Exit Date                                                                         False
# End of Surgery Time (Exit from OR)                                                              False
# Actual Surgery Room Entry Time                                                                  False
# End of Surgery Time (Exit from OR)_Minutes                                                      False
# Actual Surgery Room Entry Time_Minutes                                                          False
# Planned Start Date for Doctor Block                                                             False
# Planned End Date for Doctor Block                                                               False
# Planned Start Time for Doctor Block                                                             False
# Planned Start Time for Doctor Block_Minutes                                                     False
# Planned End Time for Doctor Block_Minutes                                                       False
# Planned End Time for Doctor Block                                                               False
# Planned Surgery Date                                                                            False
# Planned Surgery Time                                                                            False
# Planned Surgery Time_Minutes                                                                    False
# End of Surgery Date (Exit from OR)                                                              False
# Actual Surgery Room Entry Date                                                                  False
# Pre-Surgery Hospitalization Admission Time                                                      False
# Pre-Surgery Hospitalization Admission Time_Minutes                                              False
# Pre-Surgery Hospitalization Admission Date                                                      False
# Post-Surgery Discharge Time_Minutes                                                             False
# Post-Surgery Discharge Date                                                                     False
# Post-Surgery Discharge Time                                                                     False
# Closure Time                                                                                    False
# Incision Time                                                                                   False
# Incision Time_Minutes                                                                           False
# Closure Time_Minutes                                                                            False
# Surgery Admission Date                                                                          False
# Administrative Admission Time                                                                   False
# Administrative Admission Time_Minutes                                                           False
#
#                                                     Actual Surgery Room Entry Time_Minutes  \
# Pre-Surgical Admission Time Before Surgery                                            True
# Pre-Surgical Admission Time Before Surgery_Minutes                                    True
# Recovery Room Entry Date                                                             False
# Recovery Room Exit Time                                                              False
# Recovery Room Entry Time                                                             False
# Recovery Room Entry Time_Minutes                                                     False
# Recovery Room Exit Time_Minutes                                                      False
# Recovery Room Exit Date                                                              False
# End of Surgery Time (Exit from OR)                                                   False
# Actual Surgery Room Entry Time                                                       False
# End of Surgery Time (Exit from OR)_Minutes                                           False
# Actual Surgery Room Entry Time_Minutes                                               False
# Planned Start Date for Doctor Block                                                  False
# Planned End Date for Doctor Block                                                    False
# Planned Start Time for Doctor Block                                                  False
# Planned Start Time for Doctor Block_Minutes                                          False
# Planned End Time for Doctor Block_Minutes                                            False
# Planned End Time for Doctor Block                                                    False
# Planned Surgery Date                                                                 False
# Planned Surgery Time                                                                 False
# Planned Surgery Time_Minutes                                                         False
# End of Surgery Date (Exit from OR)                                                   False
# Actual Surgery Room Entry Date                                                       False
# Pre-Surgery Hospitalization Admission Time                                           False
# Pre-Surgery Hospitalization Admission Time_Minutes                                   False
# Pre-Surgery Hospitalization Admission Date                                           False
# Post-Surgery Discharge Time_Minutes                                                  False
# Post-Surgery Discharge Date                                                          False
# Post-Surgery Discharge Time                                                          False
# Closure Time                                                                         False
# Incision Time                                                                        False
# Incision Time_Minutes                                                                False
# Closure Time_Minutes                                                                 False
# Surgery Admission Date                                                               False
# Administrative Admission Time                                                        False
# Administrative Admission Time_Minutes                                                False
#
#                                                     Incision Time_Minutes  \
# Pre-Surgical Admission Time Before Surgery                           True
# Pre-Surgical Admission Time Before Surgery_Minutes                   True
# Recovery Room Entry Date                                             True
# Recovery Room Exit Time                                              True
# Recovery Room Entry Time                                             True
# Recovery Room Entry Time_Minutes                                     True
# Recovery Room Exit Time_Minutes                                      True
# Recovery Room Exit Date                                              True
# End of Surgery Time (Exit from OR)                                   True
# Actual Surgery Room Entry Time                                       True
# End of Surgery Time (Exit from OR)_Minutes                           True
# Actual Surgery Room Entry Time_Minutes                               True
# Planned Start Date for Doctor Block                                  True
# Planned End Date for Doctor Block                                    True
# Planned Start Time for Doctor Block                                  True
# Planned Start Time for Doctor Block_Minutes                          True
# Planned End Time for Doctor Block_Minutes                            True
# Planned End Time for Doctor Block                                    True
# Planned Surgery Date                                                 True
# Planned Surgery Time                                                 True
# Planned Surgery Time_Minutes                                         True
# End of Surgery Date (Exit from OR)                                  False
# Actual Surgery Room Entry Date                                      False
# Pre-Surgery Hospitalization Admission Time                          False
# Pre-Surgery Hospitalization Admission Time_Minutes                  False
# Pre-Surgery Hospitalization Admission Date                          False
# Post-Surgery Discharge Time_Minutes                                 False
# Post-Surgery Discharge Date                                         False
# Post-Surgery Discharge Time                                         False
# Closure Time                                                        False
# Incision Time                                                       False
# Incision Time_Minutes                                               False
# Closure Time_Minutes                                                False
# Surgery Admission Date                                              False
# Administrative Admission Time                                       False
# Administrative Admission Time_Minutes                               False
#
#                                                     Closure Time_Minutes  \
# Pre-Surgical Admission Time Before Surgery                          True
# Pre-Surgical Admission Time Before Surgery_Minutes                  True
# Recovery Room Entry Date                                            True
# Recovery Room Exit Time                                             True
# Recovery Room Entry Time                                            True
# Recovery Room Entry Time_Minutes                                    True
# Recovery Room Exit Time_Minutes                                     True
# Recovery Room Exit Date                                             True
# End of Surgery Time (Exit from OR)                                  True
# Actual Surgery Room Entry Time                                      True
# End of Surgery Time (Exit from OR)_Minutes                          True
# Actual Surgery Room Entry Time_Minutes                              True
# Planned Start Date for Doctor Block                                 True
# Planned End Date for Doctor Block                                   True
# Planned Start Time for Doctor Block                                 True
# Planned Start Time for Doctor Block_Minutes                         True
# Planned End Time for Doctor Block_Minutes                           True
# Planned End Time for Doctor Block                                   True
# Planned Surgery Date                                                True
# Planned Surgery Time                                                True
# Planned Surgery Time_Minutes                                        True
# End of Surgery Date (Exit from OR)                                 False
# Actual Surgery Room Entry Date                                     False
# Pre-Surgery Hospitalization Admission Time                         False
# Pre-Surgery Hospitalization Admission Time_Minutes                 False
# Pre-Surgery Hospitalization Admission Date                         False
# Post-Surgery Discharge Time_Minutes                                False
# Post-Surgery Discharge Date                                        False
# Post-Surgery Discharge Time                                        False
# Closure Time                                                       False
# Incision Time                                                      False
# Incision Time_Minutes                                              False
# Closure Time_Minutes                                               False
# Surgery Admission Date                                             False
# Administrative Admission Time                                      False
# Administrative Admission Time_Minutes                              False
#
#                                                     End of Surgery Time (Exit from OR)_Minutes  \
# Pre-Surgical Admission Time Before Surgery                                                True
# Pre-Surgical Admission Time Before Surgery_Minutes                                        True
# Recovery Room Entry Date                                                                 False
# Recovery Room Exit Time                                                                  False
# Recovery Room Entry Time                                                                 False
# Recovery Room Entry Time_Minutes                                                         False
# Recovery Room Exit Time_Minutes                                                          False
# Recovery Room Exit Date                                                                  False
# End of Surgery Time (Exit from OR)                                                       False
# Actual Surgery Room Entry Time                                                           False
# End of Surgery Time (Exit from OR)_Minutes                                               False
# Actual Surgery Room Entry Time_Minutes                                                   False
# Planned Start Date for Doctor Block                                                      False
# Planned End Date for Doctor Block                                                        False
# Planned Start Time for Doctor Block                                                      False
# Planned Start Time for Doctor Block_Minutes                                              False
# Planned End Time for Doctor Block_Minutes                                                False
# Planned End Time for Doctor Block                                                        False
# Planned Surgery Date                                                                     False
# Planned Surgery Time                                                                     False
# Planned Surgery Time_Minutes                                                             False
# End of Surgery Date (Exit from OR)                                                       False
# Actual Surgery Room Entry Date                                                           False
# Pre-Surgery Hospitalization Admission Time                                               False
# Pre-Surgery Hospitalization Admission Time_Minutes                                       False
# Pre-Surgery Hospitalization Admission Date                                               False
# Post-Surgery Discharge Time_Minutes                                                      False
# Post-Surgery Discharge Date                                                              False
# Post-Surgery Discharge Time                                                              False
# Closure Time                                                                             False
# Incision Time                                                                            False
# Incision Time_Minutes                                                                    False
# Closure Time_Minutes                                                                     False
# Surgery Admission Date                                                                   False
# Administrative Admission Time                                                            False
# Administrative Admission Time_Minutes                                                    False
#
#                                                     Recovery Room Entry Time_Minutes  \
# Pre-Surgical Admission Time Before Surgery                                      True
# Pre-Surgical Admission Time Before Surgery_Minutes                              True
# Recovery Room Entry Date                                                       False
# Recovery Room Exit Time                                                        False
# Recovery Room Entry Time                                                       False
# Recovery Room Entry Time_Minutes                                               False
# Recovery Room Exit Time_Minutes                                                False
# Recovery Room Exit Date                                                        False
# End of Surgery Time (Exit from OR)                                              True
# Actual Surgery Room Entry Time                                                  True
# End of Surgery Time (Exit from OR)_Minutes                                      True
# Actual Surgery Room Entry Time_Minutes                                          True
# Planned Start Date for Doctor Block                                            False
# Planned End Date for Doctor Block                                              False
# Planned Start Time for Doctor Block                                            False
# Planned Start Time for Doctor Block_Minutes                                    False
# Planned End Time for Doctor Block_Minutes                                      False
# Planned End Time for Doctor Block                                              False
# Planned Surgery Date                                                           False
# Planned Surgery Time                                                           False
# Planned Surgery Time_Minutes                                                   False
# End of Surgery Date (Exit from OR)                                             False
# Actual Surgery Room Entry Date                                                 False
# Pre-Surgery Hospitalization Admission Time                                     False
# Pre-Surgery Hospitalization Admission Time_Minutes                             False
# Pre-Surgery Hospitalization Admission Date                                     False
# Post-Surgery Discharge Time_Minutes                                            False
# Post-Surgery Discharge Date                                                    False
# Post-Surgery Discharge Time                                                    False
# Closure Time                                                                   False
# Incision Time                                                                  False
# Incision Time_Minutes                                                          False
# Closure Time_Minutes                                                           False
# Surgery Admission Date                                                         False
# Administrative Admission Time                                                  False
# Administrative Admission Time_Minutes                                          False
#
#                                                     Recovery Room Exit Time_Minutes  \
# Pre-Surgical Admission Time Before Surgery                                     True
# Pre-Surgical Admission Time Before Surgery_Minutes                             True
# Recovery Room Entry Date                                                      False
# Recovery Room Exit Time                                                       False
# Recovery Room Entry Time                                                      False
# Recovery Room Entry Time_Minutes                                              False
# Recovery Room Exit Time_Minutes                                               False
# Recovery Room Exit Date                                                       False
# End of Surgery Time (Exit from OR)                                             True
# Actual Surgery Room Entry Time                                                 True
# End of Surgery Time (Exit from OR)_Minutes                                     True
# Actual Surgery Room Entry Time_Minutes                                         True
# Planned Start Date for Doctor Block                                           False
# Planned End Date for Doctor Block                                             False
# Planned Start Time for Doctor Block                                           False
# Planned Start Time for Doctor Block_Minutes                                   False
# Planned End Time for Doctor Block_Minutes                                     False
# Planned End Time for Doctor Block                                             False
# Planned Surgery Date                                                          False
# Planned Surgery Time                                                          False
# Planned Surgery Time_Minutes                                                  False
# End of Surgery Date (Exit from OR)                                            False
# Actual Surgery Room Entry Date                                                False
# Pre-Surgery Hospitalization Admission Time                                    False
# Pre-Surgery Hospitalization Admission Time_Minutes                            False
# Pre-Surgery Hospitalization Admission Date                                    False
# Post-Surgery Discharge Time_Minutes                                           False
# Post-Surgery Discharge Date                                                   False
# Post-Surgery Discharge Time                                                   False
# Closure Time                                                                  False
# Incision Time                                                                 False
# Incision Time_Minutes                                                         False
# Closure Time_Minutes                                                          False
# Surgery Admission Date                                                        False
# Administrative Admission Time                                                 False
# Administrative Admission Time_Minutes                                         False
#
#                                                     Post-Surgery Discharge Time_Minutes  \
# Pre-Surgical Admission Time Before Surgery                                         True
# Pre-Surgical Admission Time Before Surgery_Minutes                                 True
# Recovery Room Entry Date                                                           True
# Recovery Room Exit Time                                                            True
# Recovery Room Entry Time                                                           True
# Recovery Room Entry Time_Minutes                                                   True
# Recovery Room Exit Time_Minutes                                                    True
# Recovery Room Exit Date                                                            True
# End of Surgery Time (Exit from OR)                                                 True
# Actual Surgery Room Entry Time                                                     True
# End of Surgery Time (Exit from OR)_Minutes                                         True
# Actual Surgery Room Entry Time_Minutes                                             True
# Planned Start Date for Doctor Block                                               False
# Planned End Date for Doctor Block                                                 False
# Planned Start Time for Doctor Block                                               False
# Planned Start Time for Doctor Block_Minutes                                       False
# Planned End Time for Doctor Block_Minutes                                         False
# Planned End Time for Doctor Block                                                 False
# Planned Surgery Date                                                              False
# Planned Surgery Time                                                              False
# Planned Surgery Time_Minutes                                                      False
# End of Surgery Date (Exit from OR)                                                False
# Actual Surgery Room Entry Date                                                    False
# Pre-Surgery Hospitalization Admission Time                                        False
# Pre-Surgery Hospitalization Admission Time_Minutes                                False
# Pre-Surgery Hospitalization Admission Date                                        False
# Post-Surgery Discharge Time_Minutes                                               False
# Post-Surgery Discharge Date                                                       False
# Post-Surgery Discharge Time                                                       False
# Closure Time                                                                      False
# Incision Time                                                                     False
# Incision Time_Minutes                                                             False
# Closure Time_Minutes                                                              False
# Surgery Admission Date                                                            False
# Administrative Admission Time                                                     False
# Administrative Admission Time_Minutes                                             False
#
#                                                     Planned Start Time for Doctor Block_Minutes  \
# Pre-Surgical Admission Time Before Surgery                                                 True
# Pre-Surgical Admission Time Before Surgery_Minutes                                         True
# Recovery Room Entry Date                                                                   True
# Recovery Room Exit Time                                                                    True
# Recovery Room Entry Time                                                                   True
# Recovery Room Entry Time_Minutes                                                           True
# Recovery Room Exit Time_Minutes                                                            True
# Recovery Room Exit Date                                                                    True
# End of Surgery Time (Exit from OR)                                                         True
# Actual Surgery Room Entry Time                                                             True
# End of Surgery Time (Exit from OR)_Minutes                                                 True
# Actual Surgery Room Entry Time_Minutes                                                     True
# Planned Start Date for Doctor Block                                                       False
# Planned End Date for Doctor Block                                                         False
# Planned Start Time for Doctor Block                                                       False
# Planned Start Time for Doctor Block_Minutes                                               False
# Planned End Time for Doctor Block_Minutes                                                 False
# Planned End Time for Doctor Block                                                         False
# Planned Surgery Date                                                                      False
# Planned Surgery Time                                                                      False
# Planned Surgery Time_Minutes                                                              False
# End of Surgery Date (Exit from OR)                                                        False
# Actual Surgery Room Entry Date                                                            False
# Pre-Surgery Hospitalization Admission Time                                                False
# Pre-Surgery Hospitalization Admission Time_Minutes                                        False
# Pre-Surgery Hospitalization Admission Date                                                False
# Post-Surgery Discharge Time_Minutes                                                       False
# Post-Surgery Discharge Date                                                               False
# Post-Surgery Discharge Time                                                               False
# Closure Time                                                                              False
# Incision Time                                                                             False
# Incision Time_Minutes                                                                     False
# Closure Time_Minutes                                                                      False
# Surgery Admission Date                                                                    False
# Administrative Admission Time                                                             False
# Administrative Admission Time_Minutes                                                     False
#
#                                                     Planned End Time for Doctor Block_Minutes
# Pre-Surgical Admission Time Before Surgery                                               True
# Pre-Surgical Admission Time Before Surgery_Minutes                                       True
# Recovery Room Entry Date                                                                 True
# Recovery Room Exit Time                                                                  True
# Recovery Room Entry Time                                                                 True
# Recovery Room Entry Time_Minutes                                                         True
# Recovery Room Exit Time_Minutes                                                          True
# Recovery Room Exit Date                                                                  True
# End of Surgery Time (Exit from OR)                                                       True
# Actual Surgery Room Entry Time                                                           True
# End of Surgery Time (Exit from OR)_Minutes                                               True
# Actual Surgery Room Entry Time_Minutes                                                   True
# Planned Start Date for Doctor Block                                                     False
# Planned End Date for Doctor Block                                                       False
# Planned Start Time for Doctor Block                                                     False
# Planned Start Time for Doctor Block_Minutes                                             False
# Planned End Time for Doctor Block_Minutes                                               False
# Planned End Time for Doctor Block                                                       False
# Planned Surgery Date                                                                    False
# Planned Surgery Time                                                                    False
# Planned Surgery Time_Minutes                                                            False
# End of Surgery Date (Exit from OR)                                                      False
# Actual Surgery Room Entry Date                                                          False
# Pre-Surgery Hospitalization Admission Time                                              False
# Pre-Surgery Hospitalization Admission Time_Minutes                                      False
# Pre-Surgery Hospitalization Admission Date                                              False
# Post-Surgery Discharge Time_Minutes                                                     False
# Post-Surgery Discharge Date                                                             False
# Post-Surgery Discharge Time                                                             False
# Closure Time                                                                            False
# Incision Time                                                                           False
# Incision Time_Minutes                                                                   False
# Closure Time_Minutes                                                                    False
# Surgery Admission Date                                                                  False
# Administrative Admission Time                                                           False
# Administrative Admission Time_Minutes                                                   False
#
# [36 rows x 50 columns]

# %%
p_values_df['num_of_affecting_columns'] = (p_values_df).sum(axis=1)
p_values_df['MCAR'] = p_values_df['num_of_affecting_columns'] == 0
p_values_df
# Out:
#                                                     patient_id  Site Code  \
# Pre-Surgical Admission Time Before Surgery               False      False
# Pre-Surgical Admission Time Before Surgery_Minutes       False      False
# Recovery Room Entry Date                                 False      False
# Recovery Room Exit Time                                  False      False
# Recovery Room Entry Time                                 False      False
# Recovery Room Entry Time_Minutes                         False      False
# Recovery Room Exit Time_Minutes                          False      False
# Recovery Room Exit Date                                  False      False
# End of Surgery Time (Exit from OR)                       False      False
# Actual Surgery Room Entry Time                           False      False
# End of Surgery Time (Exit from OR)_Minutes               False      False
# Actual Surgery Room Entry Time_Minutes                   False      False
# Planned Start Date for Doctor Block                      False      False
# Planned End Date for Doctor Block                        False      False
# Planned Start Time for Doctor Block                      False      False
# Planned Start Time for Doctor Block_Minutes              False      False
# Planned End Time for Doctor Block_Minutes                False      False
# Planned End Time for Doctor Block                        False      False
# Planned Surgery Date                                     False      False
# Planned Surgery Time                                     False      False
# Planned Surgery Time_Minutes                             False      False
# End of Surgery Date (Exit from OR)                       False      False
# Actual Surgery Room Entry Date                           False      False
# Pre-Surgery Hospitalization Admission Time               False      False
# Pre-Surgery Hospitalization Admission Time_Minutes       False      False
# Pre-Surgery Hospitalization Admission Date               False      False
# Post-Surgery Discharge Time_Minutes                      False      False
# Post-Surgery Discharge Date                              False      False
# Post-Surgery Discharge Time                              False      False
# Closure Time                                             False      False
# Incision Time                                            False      False
# Incision Time_Minutes                                    False      False
# Closure Time_Minutes                                     False      False
# Surgery Admission Date                                   False      False
# Administrative Admission Time                            False      False
# Administrative Admission Time_Minutes                    False      False
#
#                                                     Main Surgeon Code  \
# Pre-Surgical Admission Time Before Surgery                       True
# Pre-Surgical Admission Time Before Surgery_Minutes               True
# Recovery Room Entry Date                                         True
# Recovery Room Exit Time                                          True
# Recovery Room Entry Time                                         True
# Recovery Room Entry Time_Minutes                                 True
# Recovery Room Exit Time_Minutes                                  True
# Recovery Room Exit Date                                          True
# End of Surgery Time (Exit from OR)                               True
# Actual Surgery Room Entry Time                                   True
# End of Surgery Time (Exit from OR)_Minutes                       True
# Actual Surgery Room Entry Time_Minutes                           True
# Planned Start Date for Doctor Block                              True
# Planned End Date for Doctor Block                                True
# Planned Start Time for Doctor Block                              True
# Planned Start Time for Doctor Block_Minutes                      True
# Planned End Time for Doctor Block_Minutes                        True
# Planned End Time for Doctor Block                                True
# Planned Surgery Date                                             True
# Planned Surgery Time                                             True
# Planned Surgery Time_Minutes                                     True
# End of Surgery Date (Exit from OR)                               True
# Actual Surgery Room Entry Date                                   True
# Pre-Surgery Hospitalization Admission Time                       True
# Pre-Surgery Hospitalization Admission Time_Minutes               True
# Pre-Surgery Hospitalization Admission Date                       True
# Post-Surgery Discharge Time_Minutes                              True
# Post-Surgery Discharge Date                                      True
# Post-Surgery Discharge Time                                      True
# Closure Time                                                     True
# Incision Time                                                    True
# Incision Time_Minutes                                            True
# Closure Time_Minutes                                             True
# Surgery Admission Date                                           True
# Administrative Admission Time                                   False
# Administrative Admission Time_Minutes                           False
#
#                                                     Activity Code  \
# Pre-Surgical Admission Time Before Surgery                   True
# Pre-Surgical Admission Time Before Surgery_Minutes           True
# Recovery Room Entry Date                                     True
# Recovery Room Exit Time                                      True
# Recovery Room Entry Time                                     True
# Recovery Room Entry Time_Minutes                             True
# Recovery Room Exit Time_Minutes                              True
# Recovery Room Exit Date                                      True
# End of Surgery Time (Exit from OR)                           True
# Actual Surgery Room Entry Time                               True
# End of Surgery Time (Exit from OR)_Minutes                   True
# Actual Surgery Room Entry Time_Minutes                       True
# Planned Start Date for Doctor Block                          True
# Planned End Date for Doctor Block                            True
# Planned Start Time for Doctor Block                          True
# Planned Start Time for Doctor Block_Minutes                  True
# Planned End Time for Doctor Block_Minutes                    True
# Planned End Time for Doctor Block                            True
# Planned Surgery Date                                         True
# Planned Surgery Time                                         True
# Planned Surgery Time_Minutes                                 True
# End of Surgery Date (Exit from OR)                           True
# Actual Surgery Room Entry Date                               True
# Pre-Surgery Hospitalization Admission Time                   True
# Pre-Surgery Hospitalization Admission Time_Minutes           True
# Pre-Surgery Hospitalization Admission Date                   True
# Post-Surgery Discharge Time_Minutes                          True
# Post-Surgery Discharge Date                                  True
# Post-Surgery Discharge Time                                  True
# Closure Time                                                 True
# Incision Time                                                True
# Incision Time_Minutes                                        True
# Closure Time_Minutes                                         True
# Surgery Admission Date                                       True
# Administrative Admission Time                                True
# Administrative Admission Time_Minutes                        True
#
#                                                     Activity Type Code  \
# Pre-Surgical Admission Time Before Surgery                        True
# Pre-Surgical Admission Time Before Surgery_Minutes                True
# Recovery Room Entry Date                                          True
# Recovery Room Exit Time                                           True
# Recovery Room Entry Time                                          True
# Recovery Room Entry Time_Minutes                                  True
# Recovery Room Exit Time_Minutes                                   True
# Recovery Room Exit Date                                           True
# End of Surgery Time (Exit from OR)                                True
# Actual Surgery Room Entry Time                                    True
# End of Surgery Time (Exit from OR)_Minutes                        True
# Actual Surgery Room Entry Time_Minutes                            True
# Planned Start Date for Doctor Block                               True
# Planned End Date for Doctor Block                                 True
# Planned Start Time for Doctor Block                               True
# Planned Start Time for Doctor Block_Minutes                       True
# Planned End Time for Doctor Block_Minutes                         True
# Planned End Time for Doctor Block                                 True
# Planned Surgery Date                                              True
# Planned Surgery Time                                              True
# Planned Surgery Time_Minutes                                      True
# End of Surgery Date (Exit from OR)                                True
# Actual Surgery Room Entry Date                                    True
# Pre-Surgery Hospitalization Admission Time                        True
# Pre-Surgery Hospitalization Admission Time_Minutes                True
# Pre-Surgery Hospitalization Admission Date                        True
# Post-Surgery Discharge Time_Minutes                               True
# Post-Surgery Discharge Date                                       True
# Post-Surgery Discharge Time                                       True
# Closure Time                                                      True
# Incision Time                                                     True
# Incision Time_Minutes                                             True
# Closure Time_Minutes                                              True
# Surgery Admission Date                                            True
# Administrative Admission Time                                     True
# Administrative Admission Time_Minutes                             True
#
#                                                     Planned SU Time (Large/Medium/Small)  \
# Pre-Surgical Admission Time Before Surgery                                          True
# Pre-Surgical Admission Time Before Surgery_Minutes                                  True
# Recovery Room Entry Date                                                            True
# Recovery Room Exit Time                                                             True
# Recovery Room Entry Time                                                            True
# Recovery Room Entry Time_Minutes                                                    True
# Recovery Room Exit Time_Minutes                                                     True
# Recovery Room Exit Date                                                             True
# End of Surgery Time (Exit from OR)                                                  True
# Actual Surgery Room Entry Time                                                      True
# End of Surgery Time (Exit from OR)_Minutes                                          True
# Actual Surgery Room Entry Time_Minutes                                              True
# Planned Start Date for Doctor Block                                                 True
# Planned End Date for Doctor Block                                                   True
# Planned Start Time for Doctor Block                                                 True
# Planned Start Time for Doctor Block_Minutes                                         True
# Planned End Time for Doctor Block_Minutes                                           True
# Planned End Time for Doctor Block                                                   True
# Planned Surgery Date                                                                True
# Planned Surgery Time                                                                True
# Planned Surgery Time_Minutes                                                        True
# End of Surgery Date (Exit from OR)                                                  True
# Actual Surgery Room Entry Date                                                      True
# Pre-Surgery Hospitalization Admission Time                                          True
# Pre-Surgery Hospitalization Admission Time_Minutes                                  True
# Pre-Surgery Hospitalization Admission Date                                          True
# Post-Surgery Discharge Time_Minutes                                                 True
# Post-Surgery Discharge Date                                                         True
# Post-Surgery Discharge Time                                                         True
# Closure Time                                                                       False
# Incision Time                                                                      False
# Incision Time_Minutes                                                              False
# Closure Time_Minutes                                                               False
# Surgery Admission Date                                                             False
# Administrative Admission Time                                                      False
# Administrative Admission Time_Minutes                                              False
#
#                                                     Pre-Surgery Patient File (External)  \
# Pre-Surgical Admission Time Before Surgery                                        False
# Pre-Surgical Admission Time Before Surgery_Minutes                                False
# Recovery Room Entry Date                                                          False
# Recovery Room Exit Time                                                           False
# Recovery Room Entry Time                                                          False
# Recovery Room Entry Time_Minutes                                                  False
# Recovery Room Exit Time_Minutes                                                   False
# Recovery Room Exit Date                                                           False
# End of Surgery Time (Exit from OR)                                                False
# Actual Surgery Room Entry Time                                                    False
# End of Surgery Time (Exit from OR)_Minutes                                        False
# Actual Surgery Room Entry Time_Minutes                                            False
# Planned Start Date for Doctor Block                                               False
# Planned End Date for Doctor Block                                                 False
# Planned Start Time for Doctor Block                                               False
# Planned Start Time for Doctor Block_Minutes                                       False
# Planned End Time for Doctor Block_Minutes                                         False
# Planned End Time for Doctor Block                                                 False
# Planned Surgery Date                                                              False
# Planned Surgery Time                                                              False
# Planned Surgery Time_Minutes                                                      False
# End of Surgery Date (Exit from OR)                                                False
# Actual Surgery Room Entry Date                                                    False
# Pre-Surgery Hospitalization Admission Time                                        False
# Pre-Surgery Hospitalization Admission Time_Minutes                                False
# Pre-Surgery Hospitalization Admission Date                                        False
# Post-Surgery Discharge Time_Minutes                                               False
# Post-Surgery Discharge Date                                                       False
# Post-Surgery Discharge Time                                                       False
# Closure Time                                                                      False
# Incision Time                                                                     False
# Incision Time_Minutes                                                             False
# Closure Time_Minutes                                                              False
# Surgery Admission Date                                                            False
# Administrative Admission Time                                                      True
# Administrative Admission Time_Minutes                                              True
#
#                                                     Pre-Surgery Admission Date  \
# Pre-Surgical Admission Time Before Surgery                               False
# Pre-Surgical Admission Time Before Surgery_Minutes                       False
# Recovery Room Entry Date                                                 False
# Recovery Room Exit Time                                                  False
# Recovery Room Entry Time                                                 False
# Recovery Room Entry Time_Minutes                                         False
# Recovery Room Exit Time_Minutes                                          False
# Recovery Room Exit Date                                                  False
# End of Surgery Time (Exit from OR)                                       False
# Actual Surgery Room Entry Time                                           False
# End of Surgery Time (Exit from OR)_Minutes                               False
# Actual Surgery Room Entry Time_Minutes                                   False
# Planned Start Date for Doctor Block                                      False
# Planned End Date for Doctor Block                                        False
# Planned Start Time for Doctor Block                                      False
# Planned Start Time for Doctor Block_Minutes                              False
# Planned End Time for Doctor Block_Minutes                                False
# Planned End Time for Doctor Block                                        False
# Planned Surgery Date                                                     False
# Planned Surgery Time                                                     False
# Planned Surgery Time_Minutes                                             False
# End of Surgery Date (Exit from OR)                                       False
# Actual Surgery Room Entry Date                                           False
# Pre-Surgery Hospitalization Admission Time                               False
# Pre-Surgery Hospitalization Admission Time_Minutes                       False
# Pre-Surgery Hospitalization Admission Date                               False
# Post-Surgery Discharge Time_Minutes                                      False
# Post-Surgery Discharge Date                                              False
# Post-Surgery Discharge Time                                              False
# Closure Time                                                             False
# Incision Time                                                            False
# Incision Time_Minutes                                                    False
# Closure Time_Minutes                                                     False
# Surgery Admission Date                                                   False
# Administrative Admission Time                                            False
# Administrative Admission Time_Minutes                                    False
#
#                                                     Height  Weight  ...  \
# Pre-Surgical Admission Time Before Surgery            True    True  ...
# Pre-Surgical Admission Time Before Surgery_Minutes    True    True  ...
# Recovery Room Entry Date                              True    True  ...
# Recovery Room Exit Time                               True    True  ...
# Recovery Room Entry Time                              True    True  ...
# Recovery Room Entry Time_Minutes                      True    True  ...
# Recovery Room Exit Time_Minutes                       True    True  ...
# Recovery Room Exit Date                               True    True  ...
# End of Surgery Time (Exit from OR)                    True    True  ...
# Actual Surgery Room Entry Time                        True    True  ...
# End of Surgery Time (Exit from OR)_Minutes            True    True  ...
# Actual Surgery Room Entry Time_Minutes                True    True  ...
# Planned Start Date for Doctor Block                  False   False  ...
# Planned End Date for Doctor Block                    False   False  ...
# Planned Start Time for Doctor Block                  False   False  ...
# Planned Start Time for Doctor Block_Minutes          False   False  ...
# Planned End Time for Doctor Block_Minutes            False   False  ...
# Planned End Time for Doctor Block                    False   False  ...
# Planned Surgery Date                                 False   False  ...
# Planned Surgery Time                                 False   False  ...
# Planned Surgery Time_Minutes                         False   False  ...
# End of Surgery Date (Exit from OR)                   False   False  ...
# Actual Surgery Room Entry Date                       False   False  ...
# Pre-Surgery Hospitalization Admission Time           False   False  ...
# Pre-Surgery Hospitalization Admission Time_Minutes   False   False  ...
# Pre-Surgery Hospitalization Admission Date           False   False  ...
# Post-Surgery Discharge Time_Minutes                  False   False  ...
# Post-Surgery Discharge Date                          False   False  ...
# Post-Surgery Discharge Time                          False   False  ...
# Closure Time                                         False   False  ...
# Incision Time                                        False   False  ...
# Incision Time_Minutes                                False   False  ...
# Closure Time_Minutes                                 False   False  ...
# Surgery Admission Date                               False   False  ...
# Administrative Admission Time                        False   False  ...
# Administrative Admission Time_Minutes                False   False  ...
#
#                                                     Incision Time_Minutes  \
# Pre-Surgical Admission Time Before Surgery                           True
# Pre-Surgical Admission Time Before Surgery_Minutes                   True
# Recovery Room Entry Date                                             True
# Recovery Room Exit Time                                              True
# Recovery Room Entry Time                                             True
# Recovery Room Entry Time_Minutes                                     True
# Recovery Room Exit Time_Minutes                                      True
# Recovery Room Exit Date                                              True
# End of Surgery Time (Exit from OR)                                   True
# Actual Surgery Room Entry Time                                       True
# End of Surgery Time (Exit from OR)_Minutes                           True
# Actual Surgery Room Entry Time_Minutes                               True
# Planned Start Date for Doctor Block                                  True
# Planned End Date for Doctor Block                                    True
# Planned Start Time for Doctor Block                                  True
# Planned Start Time for Doctor Block_Minutes                          True
# Planned End Time for Doctor Block_Minutes                            True
# Planned End Time for Doctor Block                                    True
# Planned Surgery Date                                                 True
# Planned Surgery Time                                                 True
# Planned Surgery Time_Minutes                                         True
# End of Surgery Date (Exit from OR)                                  False
# Actual Surgery Room Entry Date                                      False
# Pre-Surgery Hospitalization Admission Time                          False
# Pre-Surgery Hospitalization Admission Time_Minutes                  False
# Pre-Surgery Hospitalization Admission Date                          False
# Post-Surgery Discharge Time_Minutes                                 False
# Post-Surgery Discharge Date                                         False
# Post-Surgery Discharge Time                                         False
# Closure Time                                                        False
# Incision Time                                                       False
# Incision Time_Minutes                                               False
# Closure Time_Minutes                                                False
# Surgery Admission Date                                              False
# Administrative Admission Time                                       False
# Administrative Admission Time_Minutes                               False
#
#                                                     Closure Time_Minutes  \
# Pre-Surgical Admission Time Before Surgery                          True
# Pre-Surgical Admission Time Before Surgery_Minutes                  True
# Recovery Room Entry Date                                            True
# Recovery Room Exit Time                                             True
# Recovery Room Entry Time                                            True
# Recovery Room Entry Time_Minutes                                    True
# Recovery Room Exit Time_Minutes                                     True
# Recovery Room Exit Date                                             True
# End of Surgery Time (Exit from OR)                                  True
# Actual Surgery Room Entry Time                                      True
# End of Surgery Time (Exit from OR)_Minutes                          True
# Actual Surgery Room Entry Time_Minutes                              True
# Planned Start Date for Doctor Block                                 True
# Planned End Date for Doctor Block                                   True
# Planned Start Time for Doctor Block                                 True
# Planned Start Time for Doctor Block_Minutes                         True
# Planned End Time for Doctor Block_Minutes                           True
# Planned End Time for Doctor Block                                   True
# Planned Surgery Date                                                True
# Planned Surgery Time                                                True
# Planned Surgery Time_Minutes                                        True
# End of Surgery Date (Exit from OR)                                 False
# Actual Surgery Room Entry Date                                     False
# Pre-Surgery Hospitalization Admission Time                         False
# Pre-Surgery Hospitalization Admission Time_Minutes                 False
# Pre-Surgery Hospitalization Admission Date                         False
# Post-Surgery Discharge Time_Minutes                                False
# Post-Surgery Discharge Date                                        False
# Post-Surgery Discharge Time                                        False
# Closure Time                                                       False
# Incision Time                                                      False
# Incision Time_Minutes                                              False
# Closure Time_Minutes                                               False
# Surgery Admission Date                                             False
# Administrative Admission Time                                      False
# Administrative Admission Time_Minutes                              False
#
#                                                     End of Surgery Time (Exit from OR)_Minutes  \
# Pre-Surgical Admission Time Before Surgery                                                True
# Pre-Surgical Admission Time Before Surgery_Minutes                                        True
# Recovery Room Entry Date                                                                 False
# Recovery Room Exit Time                                                                  False
# Recovery Room Entry Time                                                                 False
# Recovery Room Entry Time_Minutes                                                         False
# Recovery Room Exit Time_Minutes                                                          False
# Recovery Room Exit Date                                                                  False
# End of Surgery Time (Exit from OR)                                                       False
# Actual Surgery Room Entry Time                                                           False
# End of Surgery Time (Exit from OR)_Minutes                                               False
# Actual Surgery Room Entry Time_Minutes                                                   False
# Planned Start Date for Doctor Block                                                      False
# Planned End Date for Doctor Block                                                        False
# Planned Start Time for Doctor Block                                                      False
# Planned Start Time for Doctor Block_Minutes                                              False
# Planned End Time for Doctor Block_Minutes                                                False
# Planned End Time for Doctor Block                                                        False
# Planned Surgery Date                                                                     False
# Planned Surgery Time                                                                     False
# Planned Surgery Time_Minutes                                                             False
# End of Surgery Date (Exit from OR)                                                       False
# Actual Surgery Room Entry Date                                                           False
# Pre-Surgery Hospitalization Admission Time                                               False
# Pre-Surgery Hospitalization Admission Time_Minutes                                       False
# Pre-Surgery Hospitalization Admission Date                                               False
# Post-Surgery Discharge Time_Minutes                                                      False
# Post-Surgery Discharge Date                                                              False
# Post-Surgery Discharge Time                                                              False
# Closure Time                                                                             False
# Incision Time                                                                            False
# Incision Time_Minutes                                                                    False
# Closure Time_Minutes                                                                     False
# Surgery Admission Date                                                                   False
# Administrative Admission Time                                                            False
# Administrative Admission Time_Minutes                                                    False
#
#                                                     Recovery Room Entry Time_Minutes  \
# Pre-Surgical Admission Time Before Surgery                                      True
# Pre-Surgical Admission Time Before Surgery_Minutes                              True
# Recovery Room Entry Date                                                       False
# Recovery Room Exit Time                                                        False
# Recovery Room Entry Time                                                       False
# Recovery Room Entry Time_Minutes                                               False
# Recovery Room Exit Time_Minutes                                                False
# Recovery Room Exit Date                                                        False
# End of Surgery Time (Exit from OR)                                              True
# Actual Surgery Room Entry Time                                                  True
# End of Surgery Time (Exit from OR)_Minutes                                      True
# Actual Surgery Room Entry Time_Minutes                                          True
# Planned Start Date for Doctor Block                                            False
# Planned End Date for Doctor Block                                              False
# Planned Start Time for Doctor Block                                            False
# Planned Start Time for Doctor Block_Minutes                                    False
# Planned End Time for Doctor Block_Minutes                                      False
# Planned End Time for Doctor Block                                              False
# Planned Surgery Date                                                           False
# Planned Surgery Time                                                           False
# Planned Surgery Time_Minutes                                                   False
# End of Surgery Date (Exit from OR)                                             False
# Actual Surgery Room Entry Date                                                 False
# Pre-Surgery Hospitalization Admission Time                                     False
# Pre-Surgery Hospitalization Admission Time_Minutes                             False
# Pre-Surgery Hospitalization Admission Date                                     False
# Post-Surgery Discharge Time_Minutes                                            False
# Post-Surgery Discharge Date                                                    False
# Post-Surgery Discharge Time                                                    False
# Closure Time                                                                   False
# Incision Time                                                                  False
# Incision Time_Minutes                                                          False
# Closure Time_Minutes                                                           False
# Surgery Admission Date                                                         False
# Administrative Admission Time                                                  False
# Administrative Admission Time_Minutes                                          False
#
#                                                     Recovery Room Exit Time_Minutes  \
# Pre-Surgical Admission Time Before Surgery                                     True
# Pre-Surgical Admission Time Before Surgery_Minutes                             True
# Recovery Room Entry Date                                                      False
# Recovery Room Exit Time                                                       False
# Recovery Room Entry Time                                                      False
# Recovery Room Entry Time_Minutes                                              False
# Recovery Room Exit Time_Minutes                                               False
# Recovery Room Exit Date                                                       False
# End of Surgery Time (Exit from OR)                                             True
# Actual Surgery Room Entry Time                                                 True
# End of Surgery Time (Exit from OR)_Minutes                                     True
# Actual Surgery Room Entry Time_Minutes                                         True
# Planned Start Date for Doctor Block                                           False
# Planned End Date for Doctor Block                                             False
# Planned Start Time for Doctor Block                                           False
# Planned Start Time for Doctor Block_Minutes                                   False
# Planned End Time for Doctor Block_Minutes                                     False
# Planned End Time for Doctor Block                                             False
# Planned Surgery Date                                                          False
# Planned Surgery Time                                                          False
# Planned Surgery Time_Minutes                                                  False
# End of Surgery Date (Exit from OR)                                            False
# Actual Surgery Room Entry Date                                                False
# Pre-Surgery Hospitalization Admission Time                                    False
# Pre-Surgery Hospitalization Admission Time_Minutes                            False
# Pre-Surgery Hospitalization Admission Date                                    False
# Post-Surgery Discharge Time_Minutes                                           False
# Post-Surgery Discharge Date                                                   False
# Post-Surgery Discharge Time                                                   False
# Closure Time                                                                  False
# Incision Time                                                                 False
# Incision Time_Minutes                                                         False
# Closure Time_Minutes                                                          False
# Surgery Admission Date                                                        False
# Administrative Admission Time                                                 False
# Administrative Admission Time_Minutes                                         False
#
#                                                     Post-Surgery Discharge Time_Minutes  \
# Pre-Surgical Admission Time Before Surgery                                         True
# Pre-Surgical Admission Time Before Surgery_Minutes                                 True
# Recovery Room Entry Date                                                           True
# Recovery Room Exit Time                                                            True
# Recovery Room Entry Time                                                           True
# Recovery Room Entry Time_Minutes                                                   True
# Recovery Room Exit Time_Minutes                                                    True
# Recovery Room Exit Date                                                            True
# End of Surgery Time (Exit from OR)                                                 True
# Actual Surgery Room Entry Time                                                     True
# End of Surgery Time (Exit from OR)_Minutes                                         True
# Actual Surgery Room Entry Time_Minutes                                             True
# Planned Start Date for Doctor Block                                               False
# Planned End Date for Doctor Block                                                 False
# Planned Start Time for Doctor Block                                               False
# Planned Start Time for Doctor Block_Minutes                                       False
# Planned End Time for Doctor Block_Minutes                                         False
# Planned End Time for Doctor Block                                                 False
# Planned Surgery Date                                                              False
# Planned Surgery Time                                                              False
# Planned Surgery Time_Minutes                                                      False
# End of Surgery Date (Exit from OR)                                                False
# Actual Surgery Room Entry Date                                                    False
# Pre-Surgery Hospitalization Admission Time                                        False
# Pre-Surgery Hospitalization Admission Time_Minutes                                False
# Pre-Surgery Hospitalization Admission Date                                        False
# Post-Surgery Discharge Time_Minutes                                               False
# Post-Surgery Discharge Date                                                       False
# Post-Surgery Discharge Time                                                       False
# Closure Time                                                                      False
# Incision Time                                                                     False
# Incision Time_Minutes                                                             False
# Closure Time_Minutes                                                              False
# Surgery Admission Date                                                            False
# Administrative Admission Time                                                     False
# Administrative Admission Time_Minutes                                             False
#
#                                                     Planned Start Time for Doctor Block_Minutes  \
# Pre-Surgical Admission Time Before Surgery                                                 True
# Pre-Surgical Admission Time Before Surgery_Minutes                                         True
# Recovery Room Entry Date                                                                   True
# Recovery Room Exit Time                                                                    True
# Recovery Room Entry Time                                                                   True
# Recovery Room Entry Time_Minutes                                                           True
# Recovery Room Exit Time_Minutes                                                            True
# Recovery Room Exit Date                                                                    True
# End of Surgery Time (Exit from OR)                                                         True
# Actual Surgery Room Entry Time                                                             True
# End of Surgery Time (Exit from OR)_Minutes                                                 True
# Actual Surgery Room Entry Time_Minutes                                                     True
# Planned Start Date for Doctor Block                                                       False
# Planned End Date for Doctor Block                                                         False
# Planned Start Time for Doctor Block                                                       False
# Planned Start Time for Doctor Block_Minutes                                               False
# Planned End Time for Doctor Block_Minutes                                                 False
# Planned End Time for Doctor Block                                                         False
# Planned Surgery Date                                                                      False
# Planned Surgery Time                                                                      False
# Planned Surgery Time_Minutes                                                              False
# End of Surgery Date (Exit from OR)                                                        False
# Actual Surgery Room Entry Date                                                            False
# Pre-Surgery Hospitalization Admission Time                                                False
# Pre-Surgery Hospitalization Admission Time_Minutes                                        False
# Pre-Surgery Hospitalization Admission Date                                                False
# Post-Surgery Discharge Time_Minutes                                                       False
# Post-Surgery Discharge Date                                                               False
# Post-Surgery Discharge Time                                                               False
# Closure Time                                                                              False
# Incision Time                                                                             False
# Incision Time_Minutes                                                                     False
# Closure Time_Minutes                                                                      False
# Surgery Admission Date                                                                    False
# Administrative Admission Time                                                             False
# Administrative Admission Time_Minutes                                                     False
#
#                                                     Planned End Time for Doctor Block_Minutes  \
# Pre-Surgical Admission Time Before Surgery                                               True
# Pre-Surgical Admission Time Before Surgery_Minutes                                       True
# Recovery Room Entry Date                                                                 True
# Recovery Room Exit Time                                                                  True
# Recovery Room Entry Time                                                                 True
# Recovery Room Entry Time_Minutes                                                         True
# Recovery Room Exit Time_Minutes                                                          True
# Recovery Room Exit Date                                                                  True
# End of Surgery Time (Exit from OR)                                                       True
# Actual Surgery Room Entry Time                                                           True
# End of Surgery Time (Exit from OR)_Minutes                                               True
# Actual Surgery Room Entry Time_Minutes                                                   True
# Planned Start Date for Doctor Block                                                     False
# Planned End Date for Doctor Block                                                       False
# Planned Start Time for Doctor Block                                                     False
# Planned Start Time for Doctor Block_Minutes                                             False
# Planned End Time for Doctor Block_Minutes                                               False
# Planned End Time for Doctor Block                                                       False
# Planned Surgery Date                                                                    False
# Planned Surgery Time                                                                    False
# Planned Surgery Time_Minutes                                                            False
# End of Surgery Date (Exit from OR)                                                      False
# Actual Surgery Room Entry Date                                                          False
# Pre-Surgery Hospitalization Admission Time                                              False
# Pre-Surgery Hospitalization Admission Time_Minutes                                      False
# Pre-Surgery Hospitalization Admission Date                                              False
# Post-Surgery Discharge Time_Minutes                                                     False
# Post-Surgery Discharge Date                                                             False
# Post-Surgery Discharge Time                                                             False
# Closure Time                                                                            False
# Incision Time                                                                           False
# Incision Time_Minutes                                                                   False
# Closure Time_Minutes                                                                    False
# Surgery Admission Date                                                                  False
# Administrative Admission Time                                                           False
# Administrative Admission Time_Minutes                                                   False
#
#                                                     num_of_affecting_columns  \
# Pre-Surgical Admission Time Before Surgery                                31
# Pre-Surgical Admission Time Before Surgery_Minutes                        31
# Recovery Room Entry Date                                                  26
# Recovery Room Exit Time                                                   26
# Recovery Room Entry Time                                                  26
# Recovery Room Entry Time_Minutes                                          26
# Recovery Room Exit Time_Minutes                                           26
# Recovery Room Exit Date                                                   26
# End of Surgery Time (Exit from OR)                                        27
# Actual Surgery Room Entry Time                                            27
# End of Surgery Time (Exit from OR)_Minutes                                27
# Actual Surgery Room Entry Time_Minutes                                    27
# Planned Start Date for Doctor Block                                       17
# Planned End Date for Doctor Block                                         17
# Planned Start Time for Doctor Block                                       17
# Planned Start Time for Doctor Block_Minutes                               17
# Planned End Time for Doctor Block_Minutes                                 17
# Planned End Time for Doctor Block                                         17
# Planned Surgery Date                                                      17
# Planned Surgery Time                                                      17
# Planned Surgery Time_Minutes                                              17
# End of Surgery Date (Exit from OR)                                        12
# Actual Surgery Room Entry Date                                            12
# Pre-Surgery Hospitalization Admission Time                                10
# Pre-Surgery Hospitalization Admission Time_Minutes                        10
# Pre-Surgery Hospitalization Admission Date                                10
# Post-Surgery Discharge Time_Minutes                                       10
# Post-Surgery Discharge Date                                               10
# Post-Surgery Discharge Time                                               10
# Closure Time                                                              10
# Incision Time                                                             10
# Incision Time_Minutes                                                     10
# Closure Time_Minutes                                                      10
# Surgery Admission Date                                                     8
# Administrative Admission Time                                              5
# Administrative Admission Time_Minutes                                      5
#
#                                                      MCAR
# Pre-Surgical Admission Time Before Surgery          False
# Pre-Surgical Admission Time Before Surgery_Minutes  False
# Recovery Room Entry Date                            False
# Recovery Room Exit Time                             False
# Recovery Room Entry Time                            False
# Recovery Room Entry Time_Minutes                    False
# Recovery Room Exit Time_Minutes                     False
# Recovery Room Exit Date                             False
# End of Surgery Time (Exit from OR)                  False
# Actual Surgery Room Entry Time                      False
# End of Surgery Time (Exit from OR)_Minutes          False
# Actual Surgery Room Entry Time_Minutes              False
# Planned Start Date for Doctor Block                 False
# Planned End Date for Doctor Block                   False
# Planned Start Time for Doctor Block                 False
# Planned Start Time for Doctor Block_Minutes         False
# Planned End Time for Doctor Block_Minutes           False
# Planned End Time for Doctor Block                   False
# Planned Surgery Date                                False
# Planned Surgery Time                                False
# Planned Surgery Time_Minutes                        False
# End of Surgery Date (Exit from OR)                  False
# Actual Surgery Room Entry Date                      False
# Pre-Surgery Hospitalization Admission Time          False
# Pre-Surgery Hospitalization Admission Time_Minutes  False
# Pre-Surgery Hospitalization Admission Date          False
# Post-Surgery Discharge Time_Minutes                 False
# Post-Surgery Discharge Date                         False
# Post-Surgery Discharge Time                         False
# Closure Time                                        False
# Incision Time                                       False
# Incision Time_Minutes                               False
# Closure Time_Minutes                                False
# Surgery Admission Date                              False
# Administrative Admission Time                       False
# Administrative Admission Time_Minutes               False
#
# [36 rows x 52 columns]

# %% [markdown]
# If MCAR = False: we categorize
#
# if MCAR = True: we impute.

# %%
cols_to_impute = list(p_values_df.query('MCAR == True').index)
cols_to_categorize = list(p_values_df.query('MCAR == False').index)

# %% [markdown]
# We use 2 patterns of missing data in the df. MCAR (Missing Completely at Random): the probability of a data point being missing is unrelate to both observed and unobserved data.
#
# MAR (Missing at Random): the probability of a data point being missing can be related to the observed values, but not to the values that are missing.

# %%
cols_to_impute
# Out:
# []

# %%
cols_to_categorize
# Out:
# ['Pre-Surgical Admission Time Before Surgery',
#  'Pre-Surgical Admission Time Before Surgery_Minutes',
#  'Recovery Room Entry Date',
#  'Recovery Room Exit Time',
#  'Recovery Room Entry Time',
#  'Recovery Room Entry Time_Minutes',
#  'Recovery Room Exit Time_Minutes',
#  'Recovery Room Exit Date',
#  'End of Surgery Time (Exit from OR)',
#  'Actual Surgery Room Entry Time',
#  'End of Surgery Time (Exit from OR)_Minutes',
#  'Actual Surgery Room Entry Time_Minutes',
#  'Planned Start Date for Doctor Block',
#  'Planned End Date for Doctor Block',
#  'Planned Start Time for Doctor Block',
#  'Planned Start Time for Doctor Block_Minutes',
#  'Planned End Time for Doctor Block_Minutes',
#  'Planned End Time for Doctor Block',
#  'Planned Surgery Date',
#  'Planned Surgery Time',
#  'Planned Surgery Time_Minutes',
#  'End of Surgery Date (Exit from OR)',
#  'Actual Surgery Room Entry Date',
#  'Pre-Surgery Hospitalization Admission Time',
#  'Pre-Surgery Hospitalization Admission Time_Minutes',
#  'Pre-Surgery Hospitalization Admission Date',
#  'Post-Surgery Discharge Time_Minutes',
#  'Post-Surgery Discharge Date',
#  'Post-Surgery Discharge Time',
#  'Closure Time',
#  'Incision Time',
#  'Incision Time_Minutes',
#  'Closure Time_Minutes',
#  'Surgery Admission Date',
#  'Administrative Admission Time',
#  'Administrative Admission Time_Minutes']

# %% [markdown]
# Imputation: We will replace the missing values with neighboring values according to the nearest neighbors method (KNN).

# %%
from sklearn.impute import KNNImputer

# Check if there are missing values in the specified columns
if df_copy[cols_to_impute].isnull().any().any():
    # If there are missing values, impute them using KNNImputer
    imputer = KNNImputer(n_neighbors=3)
    df_copy[cols_to_impute] = imputer.fit_transform(df[cols_to_impute])
else:
    print("No missing values found in the specified columns.")
# Out:
# No missing values found in the specified columns.

# %%
missing_mat = np.array(df_copy.isnull()).astype(int)

plt.figure(figsize=(10,5))
sns.heatmap(missing_mat)
# Out:
# <Axes: >

# %% [markdown]
# Categorization:

# %%
len(cols_to_categorize)
# Out:
# 36

# %%
def time_to_minutes(t):
    if pd.isnull(t):
        return None
    try:
        return t.hour * 60 + t.minute + t.second / 60
    except:
        return None

original_time_cols = [
    'Planned Surgery Time',
    'Administrative Admission Time',
    'Pre-Surgery Hospitalization Admission Time',
    'Pre-Surgical Admission Time Before Surgery',
    'Actual Surgery Room Entry Time',
    'Incision Time',
    'Closure Time',
    'End of Surgery Time (Exit from OR)',
    'Recovery Room Entry Time',
    'Recovery Room Exit Time',
    'Post-Surgery Discharge Time',
    'Planned Start Time for Doctor Block',
    'Planned End Time for Doctor Block'
]

# Create _Minutes columns if missing
for col in original_time_cols:
    col_minutes = col + "_Minutes"
    if col in df_copy.columns and col_minutes not in df_copy.columns:
        df_copy[col_minutes] = pd.to_datetime(df_copy[col], errors='coerce').apply(time_to_minutes)

# Add _Minutes time columns to num_vars
time_minute_vars = [col + "_Minutes" for col in original_time_cols if col + "_Minutes" in df_copy.columns]
num_vars += time_minute_vars

# Define categorization function
def categorize_columns(cols_to_categorize, num_vars=[], cat_vars=[], time_vars=[]):
    def time_of_day(hour):
        if pd.isna(hour):
            return 0
        elif 5 <= hour < 12:
            return 1  # Morning
        elif 12 <= hour < 17:
            return 2  # Afternoon
        elif 17 <= hour < 21:
            return 3  # Evening
        else:
            return 4  # Night

    global df_copy

    for col in cols_to_categorize:
        if col in num_vars:
            try:
                df_copy[col] = pd.qcut(df_copy[col], 4, labels=[1, 2, 3, 4], duplicates='drop')
                df_copy[col] = df_copy[col].cat.set_categories([0, 1, 2, 3, 4])
                df_copy[col] = df_copy[col].fillna(0)
                num_vars.remove(col)
                cat_vars.append(col)
            except Exception as e:
                print(f"Skipping numerical column {col} due to error: {e}")

        elif col in time_vars:
            try:
                hour_col = col.replace('_Minutes', '_hour')
                time_cat_col = col.replace('_Minutes', '_time_cat')
                df_copy[hour_col] = df_copy[col] // 60
                df_copy[time_cat_col] = df_copy[hour_col].apply(time_of_day)
                df_copy[time_cat_col] = pd.Categorical(df_copy[time_cat_col], categories=[0, 1, 2, 3, 4], ordered=True)
                cat_vars.append(time_cat_col)
                time_vars.remove(col)
            except Exception as e:
                print(f"Error converting {col} to time category: {e}")

        else:
            if pd.api.types.is_categorical_dtype(df_copy[col]):
                if 0 not in df_copy[col].cat.categories:
                    df_copy[col] = df_copy[col].cat.add_categories([0])
                df_copy[col] = df_copy[col].fillna(0)
            else:
                unique_categories = df_copy[col].dropna().unique()
                df_copy[col] = pd.Categorical(df_copy[col], categories=[0] + list(unique_categories))
                df_copy[col] = df_copy[col].fillna(0)
            if col not in cat_vars:
                cat_vars.append(col)

    return num_vars, cat_vars, time_vars

# Final call to categorize
num_vars, cat_vars, time_vars = categorize_columns(cols_to_categorize, num_vars, cat_vars, time_vars)
# Out:
# Error converting Pre-Surgical Admission Time Before Surgery to time category: unsupported operand type(s) for //: 'datetime.time' and 'int'
# Error converting Recovery Room Entry Date to time category: cannot perform __floordiv__ with this index type: DatetimeArray
# Error converting Recovery Room Exit Time to time category: unsupported operand type(s) for //: 'datetime.time' and 'int'
# Error converting Recovery Room Entry Time to time category: unsupported operand type(s) for //: 'datetime.time' and 'int'
# Error converting Recovery Room Exit Date to time category: cannot perform __floordiv__ with this index type: DatetimeArray
# Error converting End of Surgery Time (Exit from OR) to time category: unsupported operand type(s) for //: 'datetime.time' and 'int'
# Error converting Actual Surgery Room Entry Time to time category: unsupported operand type(s) for //: 'datetime.time' and 'int'
# Error converting Planned Start Date for Doctor Block to time category: cannot perform __floordiv__ with this index type: DatetimeArray
# Error converting Planned End Date for Doctor Block to time category: cannot perform __floordiv__ with this index type: DatetimeArray
# Error converting Planned Start Time for Doctor Block to time category: unsupported operand type(s) for //: 'datetime.time' and 'int'
# Error converting Planned End Time for Doctor Block to time category: unsupported operand type(s) for //: 'datetime.time' and 'int'
# Error converting Planned Surgery Date to time category: cannot perform __floordiv__ with this index type: DatetimeArray
# Error converting Planned Surgery Time to time category: unsupported operand type(s) for //: 'datetime.time' and 'int'
# Error converting End of Surgery Date (Exit from OR) to time category: cannot perform __floordiv__ with this index type: DatetimeArray
# Error converting Actual Surgery Room Entry Date to time category: cannot perform __floordiv__ with this index type: DatetimeArray
# Error converting Pre-Surgery Hospitalization Admission Time to time category: unsupported operand type(s) for //: 'datetime.time' and 'int'
# Error converting Pre-Surgery Hospitalization Admission Date to time category: cannot perform __floordiv__ with this index type: DatetimeArray
# Error converting Post-Surgery Discharge Date to time category: cannot perform __floordiv__ with this index type: DatetimeArray
# Error converting Post-Surgery Discharge Time to time category: unsupported operand type(s) for //: 'datetime.time' and 'int'
# Error converting Closure Time to time category: unsupported operand type(s) for //: 'datetime.time' and 'int'
# Error converting Incision Time to time category: unsupported operand type(s) for //: 'datetime.time' and 'int'
# Error converting Surgery Admission Date to time category: cannot perform __floordiv__ with this index type: DatetimeArray
# Error converting Administrative Admission Time to time category: unsupported operand type(s) for //: 'datetime.time' and 'int'

# %% [markdown]
# Because we cleared the original data, there would be no longer missing values, thus I update the df to be without the missing values- there were no longer missing values at our original data- so there would no longer be missing values at out engineered data.

# %%
df_no_missing = df_copy.dropna()
df_copy = df_no_missing

# %%
df_no_missing.isnull().sum()
# Out:
# patient_id                                     0
# Site Code                                      0
# Main Surgeon Code                              0
# Activity Code                                  0
# Activity Type Code                             0
#                                               ..
# Recovery Room Entry Time_Minutes               0
# Recovery Room Exit Time_Minutes                0
# Post-Surgery Discharge Time_Minutes            0
# Planned Start Time for Doctor Block_Minutes    0
# Planned End Time for Doctor Block_Minutes      0
# Length: 63, dtype: int64

# %%
# !pip install ydata-profiling
# Out:
# Collecting ydata-profiling
#   Downloading ydata_profiling-4.16.1-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: scipy<1.16,>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling) (1.15.2)
# Requirement already satisfied: pandas!=1.4.0,<3.0,>1.1 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling) (2.2.2)
# Requirement already satisfied: matplotlib<=3.10,>=3.5 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling) (3.10.0)
# Requirement already satisfied: pydantic>=2 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling) (2.11.4)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling) (6.0.2)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling) (3.1.6)
# Collecting visions<0.8.2,>=0.7.5 (from visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling)
#   Downloading visions-0.8.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy<2.2,>=1.16.0 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling) (2.0.2)
# Collecting htmlmin==0.1.12 (from ydata-profiling)
#   Downloading htmlmin-0.1.12.tar.gz (19 kB)
#   Preparing metadata (setup.py) ... done
# Collecting phik<0.13,>=0.11.1 (from ydata-profiling)
#   Downloading phik-0.12.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.6 kB)
# Requirement already satisfied: requests<3,>=2.24.0 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling) (2.32.3)
# Requirement already satisfied: tqdm<5,>=4.48.2 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling) (4.67.1)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling) (0.13.2)
# Collecting multimethod<2,>=1.4 (from ydata-profiling)
#   Downloading multimethod-1.12-py3-none-any.whl.metadata (9.6 kB)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling) (0.14.4)
# Requirement already satisfied: typeguard<5,>=3 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling) (4.4.2)
# Collecting imagehash==4.3.1 (from ydata-profiling)
#   Downloading ImageHash-4.3.1-py2.py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: wordcloud>=1.9.3 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling) (1.9.4)
# Collecting dacite>=1.8 (from ydata-profiling)
#   Downloading dacite-1.9.2-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: numba<=0.61,>=0.56.0 in /usr/local/lib/python3.11/dist-packages (from ydata-profiling) (0.60.0)
# Collecting PyWavelets (from imagehash==4.3.1->ydata-profiling)
#   Downloading pywavelets-1.8.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.0 kB)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (from imagehash==4.3.1->ydata-profiling) (11.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2<3.2,>=2.11.1->ydata-profiling) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba<=0.61,>=0.56.0->ydata-profiling) (0.43.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas!=1.4.0,<3.0,>1.1->ydata-profiling) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas!=1.4.0,<3.0,>1.1->ydata-profiling) (2025.2)
# Requirement already satisfied: joblib>=0.14.1 in /usr/local/lib/python3.11/dist-packages (from phik<0.13,>=0.11.1->ydata-profiling) (1.4.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2->ydata-profiling) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2->ydata-profiling) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2->ydata-profiling) (4.13.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2->ydata-profiling) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.24.0->ydata-profiling) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.24.0->ydata-profiling) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.24.0->ydata-profiling) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.24.0->ydata-profiling) (2025.4.26)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.11/dist-packages (from statsmodels<1,>=0.13.2->ydata-profiling) (1.0.1)
# Requirement already satisfied: attrs>=19.3.0 in /usr/local/lib/python3.11/dist-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (25.3.0)
# Requirement already satisfied: networkx>=2.4 in /usr/local/lib/python3.11/dist-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (3.4.2)
# Collecting puremagic (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling)
#   Downloading puremagic-1.29-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib<=3.10,>=3.5->ydata-profiling) (1.17.0)
# Downloading ydata_profiling-4.16.1-py2.py3-none-any.whl (400 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.1/400.1 kB 7.5 MB/s eta 0:00:00
# Downloading ImageHash-4.3.1-py2.py3-none-any.whl (296 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 21.5 MB/s eta 0:00:00
# Downloading dacite-1.9.2-py3-none-any.whl (16 kB)
# Downloading multimethod-1.12-py3-none-any.whl (10 kB)
# Downloading phik-0.12.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (687 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 687.8/687.8 kB 31.0 MB/s eta 0:00:00
# Downloading visions-0.8.1-py3-none-any.whl (105 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 kB 9.4 MB/s eta 0:00:00
# Downloading puremagic-1.29-py3-none-any.whl (43 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.3/43.3 kB 3.0 MB/s eta 0:00:00
# Downloading pywavelets-1.8.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 83.0 MB/s eta 0:00:00
# Building wheels for collected packages: htmlmin
#   Building wheel for htmlmin (setup.py) ... done
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27081 sha256=1aa36ea3a8b380337503992ca15116aeb29d0f0a9d7a3f611a2fc2e6262ea227
#   Stored in directory: /root/.cache/pip/wheels/8d/55/1a/19cd535375ed1ede0c996405ebffe34b196d78e2d9545723a2
# Successfully built htmlmin
# Installing collected packages: puremagic, htmlmin, PyWavelets, multimethod, dacite, imagehash, visions, phik, ydata-profiling
# Successfully installed PyWavelets-1.8.0 dacite-1.9.2 htmlmin-0.1.12 imagehash-4.3.1 multimethod-1.12 phik-0.12.4 puremagic-1.29 visions-0.8.1 ydata-profiling-4.16.1

# %%
from ydata_profiling import ProfileReport

profile = ProfileReport(df_copy, title="Pandas Profiling Report", explorative=True)
profile.to_file("profile_report.html")
# Out:
#             <div>
#                 <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
#                     Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#                 </p>
#             </div>
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/63 [00:00<?, ?it/s]
#   2%|▏         | 1/63 [00:00<00:06,  9.55it/s]
#   3%|▎         | 2/63 [00:00<00:18,  3.27it/s]
#   6%|▋         | 4/63 [00:00<00:12,  4.57it/s]
#  10%|▉         | 6/63 [00:01<00:12,  4.47it/s]
#  14%|█▍        | 9/63 [00:01<00:09,  5.70it/s]
#  17%|█▋        | 11/63 [00:02<00:10,  5.17it/s]
#  19%|█▉        | 12/63 [00:05<00:37,  1.37it/s]
#  33%|███▎      | 21/63 [00:06<00:11,  3.50it/s]
#  38%|███▊      | 24/63 [00:06<00:08,  4.34it/s]
#  41%|████▏     | 26/63 [00:06<00:07,  4.71it/s]
#  51%|█████     | 32/63 [00:06<00:04,  7.49it/s]
#  54%|█████▍    | 34/63 [00:07<00:03,  7.47it/s]
#  59%|█████▊    | 37/63 [00:07<00:02,  8.97it/s]
#  65%|██████▌   | 41/63 [00:07<00:01, 11.40it/s]
#  68%|██████▊   | 43/63 [00:07<00:01, 11.86it/s]
#  71%|███████▏  | 45/63 [00:09<00:05,  3.24it/s]
#  78%|███████▊  | 49/63 [00:10<00:03,  4.56it/s]
#  81%|████████  | 51/63 [00:10<00:02,  5.27it/s]
#  84%|████████▍ | 53/63 [00:10<00:01,  6.19it/s]
#  89%|████████▉ | 56/63 [00:10<00:00,  8.42it/s]
#  92%|█████████▏| 58/63 [00:10<00:00,  9.17it/s]
# 100%|██████████| 63/63 [00:10<00:00,  5.80it/s]
# /usr/local/lib/python3.11/dist-packages/ydata_profiling/model/missing.py:132: UserWarning: There was an attempt to generate the Heatmap missing values diagrams, but this failed.
#         To hide this warning, disable the calculation
#         (using `df.profile_report(missing_diagrams={"Heatmap": False}`)
#         If this is problematic for your use case, please report this as an issue:
#         https://github.com/ydataai/ydata-profiling/issues
#         (include the error message: 'max() arg is an empty sequence')
#   warnings.warn(
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# /usr/local/lib/python3.11/dist-packages/ydata_profiling/visualisation/plot.py:429: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   legend = ax.legend(
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
df_copy.to_excel("2017_data_Assuta_nomissings_for_stat_final_1105.xlsx", index=False)

# %% [markdown]
# Checking the amount of inconsistencies in the grouped data:

# %%
file_path = "/content/patients_one_row_per_id_correct_types_END2017.xlsx"
df = pd.read_excel(file_path)

# Parse relevant time columns
df['Closure Time'] = pd.to_datetime(df['Closure Time'], errors='coerce').dt.time
df['End of Surgery Time (Exit from OR)'] = pd.to_datetime(df['End of Surgery Time (Exit from OR)'], errors='coerce').dt.time

# Function to compute time difference (in minutes)
def compute_minutes_diff(t1, t2):
    try:
        if pd.isnull(t1) or pd.isnull(t2):
            return None
        dt1 = pd.to_datetime(str(t1))
        dt2 = pd.to_datetime(str(t2))
        return (dt2 - dt1).total_seconds() / 60
    except:
        return None

# Calculate difference and flag inconsistencies
df['Closure_to_Exit_Minutes'] = df.apply(
    lambda row: compute_minutes_diff(row['Closure Time'], row['End of Surgery Time (Exit from OR)']),
    axis=1
)
df['Time_Conflict'] = df['Closure_to_Exit_Minutes'] < 0

# Summary of conflicts
total_conflicts = df['Time_Conflict'].sum()
print(f"Total rows with conflict (Exit before Closure): {total_conflicts}")

# Analyze by room or date
if 'Planned Operating Room Number' in df.columns:
    print("\nTop problematic rooms:")
    print(df[df['Time_Conflict']].groupby('Planned Operating Room Number').size().sort_values(ascending=False).head(5))

if 'Planned Surgery Date' in df.columns:
    print("\nTop problematic dates:")
    print(df[df['Time_Conflict']].groupby('Planned Surgery Date').size().sort_values(ascending=False).head(5))

df[df['Time_Conflict']].to_excel("surgery_time_conflicts2017.xlsx", index=False)
# Out:
# <ipython-input-41-5cd75491bb3a>:5: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Closure Time'] = pd.to_datetime(df['Closure Time'], errors='coerce').dt.time
# <ipython-input-41-5cd75491bb3a>:6: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['End of Surgery Time (Exit from OR)'] = pd.to_datetime(df['End of Surgery Time (Exit from OR)'], errors='coerce').dt.time
# Total rows with conflict (Exit before Closure): 1495
#
# Top problematic rooms:
# Planned Operating Room Number
# 20026.0    159
# 20013.0    115
# 20006.0    101
# 20015.0     91
# 20010.0     85
# dtype: int64
#
# Top problematic dates:
# Planned Surgery Date
# 2017-03-15    13
# 2017-03-30    13
# 2017-04-27    13
# 2017-02-22    12
# 2017-10-31    12
# dtype: int64
